# %% [markdown]
# <a href="https://colab.research.google.com/github/lyeslehara1996/Matser_SI_DL/blob/main/code_ameliorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.optimizers import Adam,Adamax,Adagrad,SGD,RMSprop
import keras.metrics as metrics
from keras import backend as K
from keras.layers import Bidirectional, Dense, Embedding, Input, Lambda, LSTM,GRU, RepeatVector, TimeDistributed, Layer, Activation, Dropout
from keras.models import Model
import tensorflow as tf
import pandas as pd
import numpy as np
import os

from keras.callbacks import ModelCheckpoint
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from tensorflow import  keras
import pandas as pd 
import re 
import nltk


import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
from numpy import zeros
from keras.layers import Dropout

from nltk.tokenize import word_tokenize
from nltk.tokenize.toktok import ToktokTokenizer
from keras.preprocessing.text import Tokenizer
from nltk.tokenize import TweetTokenizer
import string as st
SAVEd = False


from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split

from nltk.corpus import stopwords
from keras.utils.np_utils import to_categorical
nltk.download('stopwords')
nltk.download('punkt')
""" Dataset"""

from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from tensorflow.python.framework.ops import disable_eager_execution

# import tensorflow as tf
from tensorflow.python.eager.context import eager_mode, graph_mode
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df=pd.read_excel("/content/drive/MyDrive/dossier_de_travail/SemEval2017A.xlsx")

df.drop("Unnamed: 3", axis=1, inplace=True)
df.drop("Unnamed: 4", axis=1, inplace=True)
df.drop("Unnamed: 5", axis=1, inplace=True)
df.drop("Unnamed: 6", axis=1, inplace=True)

df.head()


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20633 entries, 0 to 20632
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        20633 non-null  object
#  1   Polarity  20632 non-null  object
#  2   Comments  20632 non-null  object
# dtypes: object(3)
# memory usage: 483.7+ KB

# %%
#supprimer les lignes qui contient des valeur null 
df.Polarity.unique()
df.dropna(subset=['Polarity'], inplace=True)
df.Polarity.unique()
df.info()


plt.figure(figsize=(8,6))
df.Polarity.hist(xlabelsize=14)
plt.show()

#### transformet les mots en miniscule ######
df.Comments=df.Comments.str.lower()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20632 entries, 0 to 20632
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        20632 non-null  object
#  1   Polarity  20632 non-null  object
#  2   Comments  20632 non-null  object
# dtypes: object(3)
# memory usage: 644.8+ KB
#                    ID  ...                                           Comments
# 0  619950566786113024  ...  picturehouse's, pink floyd's, 'roger waters: t...
# 1  619969366986235008  ...  order go set a watchman in store or through ou...
# 2  619971047195044992  ...  if these runway renovations at the airport pre...
# 3  619974445185302016  ...  if you could ask an onstage interview question...
# 4  619987808317406976  ...  a portion of book sales from our harper lee/go...
#
# [5 rows x 3 columns]

# %%
###################STOP WORDS################
#STOP WORDS
#Tokenization of text

tokenizer=ToktokTokenizer()
#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')

#removing the stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text
#Apply function on review column
df['Comments']=df['Comments'].apply(remove_stopwords)

# %%
############supprission des caractere spiciaux Dans Commantaire #########
df['Comments'] = df['Comments'].apply(lambda x: re.sub(r'https?:\/\/\S+', ' ', str(x)))
df['Comments'] = df['Comments'].apply(lambda x: re.sub(r"www\.[a-z]?\.?(com)+|[a-z]+\.(com)", ' ', str(x)))
df['Comments'] = df['Comments'].apply(lambda x: re.sub(r'{link}', ' ', str(x)))
df['Comments'] = df['Comments'].apply(lambda x: re.sub(r'&[a-z]+;', ' ', str(x)))
df['Comments'] = df['Comments'].apply(lambda x: re.sub(r"[^a-z]", ' ', str(x)))
df['Comments'] = df['Comments'].apply(lambda x: re.sub(r'@mention', ' ', str(x)))
df['Comments'] = df['Comments'].apply(lambda x: " ".join(x.lower() for x in str(x).split()  if len(x)>3 ))

# %%
#######deviser en review and labels ######


reviews =  df[['Comments']]
labels =  df[['Polarity']]

corpus= []
for text in reviews['Comments']:
    words= [word.lower() for word in word_tokenize(text)]
    corpus.append(words)

num_words=len(corpus)
print(num_words)
# Out:
# 20632

# %%
####reviews sans ponctuation #######

revue_sans_ponctuation=[]
for sentence in reviews['Comments']:

    revue_sans_ponctuation.append(' '.join(Word.strip(st.punctuation) for Word in sentence.split()))

reviews_cleaned = np.asarray(revue_sans_ponctuation)
reviews_cleaned



review_array = np.asarray(revue_sans_ponctuation)
label_array = np.asarray(labels['Polarity'])

reviews_labels = np.stack((review_array, label_array), axis = 1)

reviews_labels
# Out:
# array([['picturehouse pink floyd roger waters walll opening sept making waves watch trailer rolling stone look',
#         'neutral'],
#        ['order watchman store website tuesday half price gsaw gsawatchmanbook',
#         'neutral'],
#        ['runway renovations airport prevent seeing taylor swift monday blood meaning',
#         'negative'],
#        ...,
#        ['hours arrived saudi arabia tuesday turkish president recep tayyip erdogan accused syria president mercilessly',
#         'neutral'],
#        ['vanityfair alex kardashian worth love kardashian conure',
#         'negative'],
#        ['guess even pandora knows justin bieber grown condom played',
#         'neutral']], dtype=object)

# %%
########Encoder les polarity  ##############
encoder = LabelEncoder()
encoder.fit(label_array)
encoded_labels = encoder.transform(label_array)
encoded_labels = to_categorical(encoded_labels)
encoded_labels
# Out:
# array([[0., 1., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.],
#        ...,
#        [0., 1., 0.],
#        [1., 0., 0.],
#        [0., 1., 0.]], dtype=float32)

# %%
##### Train and Test
review_train, review_test, label_train, label_test = train_test_split(reviews_cleaned, encoded_labels, test_size=0.20, random_state=42)
print(review_train.shape, label_train.shape)
print(review_test.shape, label_test.shape)

tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(review_train)

review_train = tokenizer.texts_to_sequences(review_train)
review_test = tokenizer.texts_to_sequences(review_test)

vocab_size = len(tokenizer.word_index) + 1
# Out:
# (16505,) (16505, 3)
# (4127,) (4127, 3)

# %%
embeddings_dictionary = dict()
glove_file = open('/content/drive/MyDrive/dossier_de_travail/glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary [word] = vector_dimensions
    
glove_file.close()

embedding_matrix = zeros((vocab_size, 100))
for word, index in tokenizer.word_index.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector
        
print(embedding_matrix[1].shape)
# Out:
# (100,)

# %%
X_train=review_train  
X_test=review_test
y_train=label_train   
y_test=label_test
MAX_LENGTH = 100
NUM_WORDS = vocab_size
X_train = pad_sequences(X_train, padding='post', maxlen=MAX_LENGTH)
X_test = pad_sequences(X_test, padding='post', maxlen=MAX_LENGTH)

train_index = np.random.choice(np.arange(X_train.shape[0]), 400, replace=False)     
test_index = np.random.choice(np.arange(X_test.shape[0]), 250, replace=False)      

X_train = X_train[train_index]
y_train = y_train[train_index]

X_test = X_test[test_index]
y_test = y_test[test_index]

temp = np.zeros((X_train.shape[0], MAX_LENGTH, NUM_WORDS))
temp[np.expand_dims(np.arange(X_train.shape[0]), axis=0).reshape(X_train.shape[0], 1), np.repeat(np.array([np.arange(MAX_LENGTH)]), X_train.shape[0], axis=0), X_train] = 1

Conversion_X_train = temp

temp = np.zeros((X_test.shape[0], MAX_LENGTH, NUM_WORDS))
temp[np.expand_dims(np.arange(X_test.shape[0]), axis=0).reshape(X_test.shape[0], 1), np.repeat(np.array([np.arange(MAX_LENGTH)]), X_test.shape[0], axis=0), X_test] = 1

Conversion_X_test = temp
print('X_train',X_train.shape)
print('y_train',y_train.shape)
print('X_test',X_test.shape)
print('y_test',y_test.shape)
print(Conversion_X_train.shape)
print(Conversion_X_test.shape)
# Out:
# X_train (400, 100)
# y_train (400, 3)
# X_test (250, 100)
# y_test (250, 3)
# (400, 100, 22814)
# (250, 100, 22814)

# %%
from keras.layers import Flatten, Activation, RepeatVector, Permute, Multiply, Lambda
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
class AttentionCouche(tf.keras.layers.Layer): 
    def __init__(self, **kwargs):   
        self.dim_mots = 200
        self.unite_par_seq =100 

        super(AttentionCouche, self).__init__( **kwargs)
        
    def build(self, input_shape):

        dim_mots = input_shape[-1] 
        unite_par_seq = input_shape[-2]
        num_units = 1
        
        self.w = self.add_weight(name='attention_weigth',shape=(input_shape[-1],1), initializer='normal')            
        self.b = self.add_weight(name='attention_bias',shape=(input_shape[-2],1), initializer='zero')
       
        
        super(AttentionCouche, self).build(input_shape)
        
    def call(self, x):
       e=K.tanh(K.dot(x,self.w)+self.b) 
       e = Flatten()(e) 
       a = Activation('softmax')(e)
       temp = RepeatVector(1600)(a) 
       temp = Permute([2,1])(temp) 
       output = Multiply()([x,temp]) 
       output = Lambda(lambda values: K.sum(values, axis=1))(output)
       return output
    def output_shep(self,input_shape):
      return (input_shape[0],input_shape[-1])
    def get_config(self):
      return super(AttentionCouche,self).get_config()

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
	
	
  #metrics=['acc',f1_m,precision_m, recall_m]

# %% [markdown]
# # Test_0
# Une Couche a 150 Neurones

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/Models_a_ameliorer'
MODEL_FILE_NAME = 'Test0.h5'
LR=0.0001

batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500

encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)

def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(150, return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Dense(300, activation='relu', name='dense_1')(h)
    
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])

    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    
    return (fct_loss, z)
     
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()

def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)
    
encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()

def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h = Bidirectional( LSTM(150, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 

autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_2 (Embedding)        (None, 100, 100)     2281400     ['input_5[0][0]']
#
#  bidirectional_6 (Bidirectional  (None, 100, 300)    301200      ['embedding_2[0][0]']
#  )
#
#  attention_couche_2 (AttentionC  (None, 300)         400         ['bidirectional_6[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          90300       ['attention_couche_2[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 2,793,700
# Trainable params: 2,793,700
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 200)]             0
#
#  dense_8 (Dense)             (None, 100)               20100
#
#  pred (Dense)                (None, 3)                 303
#
# =================================================================
# Total params: 20,403
# Trainable params: 20,403
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 200)]             0
#
#  repeat_vector_7 (RepeatVect  (None, 100, 200)         0
#  or)
#
#  bidirectional_7 (Bidirectio  (None, 100, 300)         421200
#  nal)
#
#  decoded_mean (TimeDistribut  (None, 100, 22814)       6867014
#  ed)
#
# =================================================================
# Total params: 7,288,214
# Trainable params: 7,288,214
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_2 (Embedding)        (None, 100, 100)     2281400     ['input_5[0][0]']
#
#  bidirectional_6 (Bidirectional  (None, 100, 300)    301200      ['embedding_2[0][0]']
#  )
#
#  attention_couche_2 (AttentionC  (None, 300)         400         ['bidirectional_6[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          90300       ['attention_couche_2[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  repeat_vector_8 (RepeatVector)  (None, 100, 200)    0           ['z[0][0]']
#
#  bidirectional_8 (Bidirectional  (None, 100, 300)    421200      ['repeat_vector_8[0][0]']
#  )
#
#  dense_11 (Dense)               (None, 100)          20100       ['z[0][0]']
#
#  decoded_mean (TimeDistributed)  (None, 100, 22814)  6867014     ['bidirectional_8[0][0]']
#
#  pred (Dense)                   (None, 3)            303         ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 10,102,317
# Trainable params: 10,102,317
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])
# Out:
# Train on 400 samples, validate on 250 samples
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7399 - decoded_mean_loss: 0.0484 - pred_loss: 0.6915 - decoded_mean_acc: 0.0000e+00 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 00001: val_pred_acc improved from -inf to 0.66667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 77s 194ms/sample - loss: 0.7399 - decoded_mean_loss: 0.0484 - pred_loss: 0.6915 - decoded_mean_acc: 0.0000e+00 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7347 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6866 - val_decoded_mean_acc: 0.0000e+00 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7331 - decoded_mean_loss: 0.0484 - pred_loss: 0.6846 - decoded_mean_acc: 0.0022 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00002: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 60s 151ms/sample - loss: 0.7331 - decoded_mean_loss: 0.0484 - pred_loss: 0.6846 - decoded_mean_acc: 0.0022 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7285 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6796 - val_decoded_mean_acc: 0.0203 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7257 - decoded_mean_loss: 0.0484 - pred_loss: 0.6773 - decoded_mean_acc: 0.0440 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00003: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 68s 171ms/sample - loss: 0.7257 - decoded_mean_loss: 0.0484 - pred_loss: 0.6773 - decoded_mean_acc: 0.0440 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7202 - val_decoded_mean_loss: 0.0485 - val_pred_loss: 0.6717 - val_decoded_mean_acc: 0.2904 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 4/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7175 - decoded_mean_loss: 0.0485 - pred_loss: 0.6690 - decoded_mean_acc: 0.2983 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00004: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 63s 157ms/sample - loss: 0.7175 - decoded_mean_loss: 0.0485 - pred_loss: 0.6690 - decoded_mean_acc: 0.2983 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7108 - val_decoded_mean_loss: 0.0485 - val_pred_loss: 0.6621 - val_decoded_mean_acc: 0.8481 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 5/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7085 - decoded_mean_loss: 0.0485 - pred_loss: 0.6599 - decoded_mean_acc: 0.7840 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00005: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 59s 149ms/sample - loss: 0.7085 - decoded_mean_loss: 0.0485 - pred_loss: 0.6599 - decoded_mean_acc: 0.7840 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.6989 - val_decoded_mean_loss: 0.0486 - val_pred_loss: 0.6492 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 6/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6955 - decoded_mean_loss: 0.0487 - pred_loss: 0.6469 - decoded_mean_acc: 0.9266 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00006: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 59s 148ms/sample - loss: 0.6955 - decoded_mean_loss: 0.0487 - pred_loss: 0.6469 - decoded_mean_acc: 0.9266 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.6852 - val_decoded_mean_loss: 0.0488 - val_pred_loss: 0.6348 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 7/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6816 - decoded_mean_loss: 0.0489 - pred_loss: 0.6328 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00007: val_pred_acc improved from 0.66667 to 0.66800, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 62s 156ms/sample - loss: 0.6816 - decoded_mean_loss: 0.0489 - pred_loss: 0.6328 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.6699 - val_decoded_mean_loss: 0.0491 - val_pred_loss: 0.6203 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6680 - val_pred_f1_m: 0.0194 - val_pred_precision_m: 0.5000 - val_pred_recall_m: 0.0100
# Epoch 8/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6685 - decoded_mean_loss: 0.0493 - pred_loss: 0.6192 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.0380 - pred_precision_m: 0.6944 - pred_recall_m: 0.0200
# Epoch 00008: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 60s 151ms/sample - loss: 0.6685 - decoded_mean_loss: 0.0493 - pred_loss: 0.6192 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.0380 - pred_precision_m: 0.6944 - pred_recall_m: 0.0200 - val_loss: 0.6560 - val_decoded_mean_loss: 0.0498 - val_pred_loss: 0.6029 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6653 - val_pred_f1_m: 0.1639 - val_pred_precision_m: 0.4850 - val_pred_recall_m: 0.1000
# Epoch 9/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6556 - decoded_mean_loss: 0.0499 - pred_loss: 0.6057 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.1834 - pred_precision_m: 0.4912 - pred_recall_m: 0.1150
# Epoch 00009: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 59s 148ms/sample - loss: 0.6556 - decoded_mean_loss: 0.0499 - pred_loss: 0.6057 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.1834 - pred_precision_m: 0.4912 - pred_recall_m: 0.1150 - val_loss: 0.6464 - val_decoded_mean_loss: 0.0508 - val_pred_loss: 0.5952 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6453 - val_pred_f1_m: 0.3133 - val_pred_precision_m: 0.4553 - val_pred_recall_m: 0.2400
# Epoch 10/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6472 - decoded_mean_loss: 0.0509 - pred_loss: 0.5963 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.3427 - pred_precision_m: 0.4773 - pred_recall_m: 0.2700
# Epoch 00010: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 60s 151ms/sample - loss: 0.6472 - decoded_mean_loss: 0.0509 - pred_loss: 0.5963 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.3427 - pred_precision_m: 0.4773 - pred_recall_m: 0.2700 - val_loss: 0.6452 - val_decoded_mean_loss: 0.0520 - val_pred_loss: 0.5951 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6613 - val_pred_f1_m: 0.4079 - val_pred_precision_m: 0.4893 - val_pred_recall_m: 0.3500
# Epoch 11/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6498 - decoded_mean_loss: 0.0520 - pred_loss: 0.5978 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6542 - pred_f1_m: 0.4129 - pred_precision_m: 0.4764 - pred_recall_m: 0.3650
# Epoch 00011: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 61s 152ms/sample - loss: 0.6498 - decoded_mean_loss: 0.0520 - pred_loss: 0.5978 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6542 - pred_f1_m: 0.4129 - pred_precision_m: 0.4764 - pred_recall_m: 0.3650 - val_loss: 0.6475 - val_decoded_mean_loss: 0.0526 - val_pred_loss: 0.5950 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.4471 - val_pred_precision_m: 0.5068 - val_pred_recall_m: 0.4000
# Epoch 12/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6480 - decoded_mean_loss: 0.0518 - pred_loss: 0.5962 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6542 - pred_f1_m: 0.4086 - pred_precision_m: 0.4751 - pred_recall_m: 0.3600
# Epoch 00012: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.6480 - decoded_mean_loss: 0.0518 - pred_loss: 0.5962 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6542 - pred_f1_m: 0.4086 - pred_precision_m: 0.4751 - pred_recall_m: 0.3600 - val_loss: 0.6452 - val_decoded_mean_loss: 0.0516 - val_pred_loss: 0.5827 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6627 - val_pred_f1_m: 0.4267 - val_pred_precision_m: 0.5023 - val_pred_recall_m: 0.3733
# Epoch 13/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6454 - decoded_mean_loss: 0.0508 - pred_loss: 0.5946 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6533 - pred_f1_m: 0.3696 - pred_precision_m: 0.4632 - pred_recall_m: 0.3100
# Epoch 00013: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 67s 167ms/sample - loss: 0.6454 - decoded_mean_loss: 0.0508 - pred_loss: 0.5946 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6533 - pred_f1_m: 0.3696 - pred_precision_m: 0.4632 - pred_recall_m: 0.3100 - val_loss: 0.6421 - val_decoded_mean_loss: 0.0504 - val_pred_loss: 0.5881 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6600 - val_pred_f1_m: 0.3297 - val_pred_precision_m: 0.4417 - val_pred_recall_m: 0.2633
# Epoch 14/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6430 - decoded_mean_loss: 0.0497 - pred_loss: 0.5933 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6633 - pred_f1_m: 0.3365 - pred_precision_m: 0.4891 - pred_recall_m: 0.2575
# Epoch 00014: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 60s 150ms/sample - loss: 0.6430 - decoded_mean_loss: 0.0497 - pred_loss: 0.5933 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6633 - pred_f1_m: 0.3365 - pred_precision_m: 0.4891 - pred_recall_m: 0.2575 - val_loss: 0.6410 - val_decoded_mean_loss: 0.0493 - val_pred_loss: 0.5911 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6533 - val_pred_f1_m: 0.2795 - val_pred_precision_m: 0.4479 - val_pred_recall_m: 0.2033
# Epoch 15/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6409 - decoded_mean_loss: 0.0488 - pred_loss: 0.5922 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6608 - pred_f1_m: 0.2418 - pred_precision_m: 0.4862 - pred_recall_m: 0.1625
# Epoch 00015: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.6409 - decoded_mean_loss: 0.0488 - pred_loss: 0.5922 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6608 - pred_f1_m: 0.2418 - pred_precision_m: 0.4862 - pred_recall_m: 0.1625 - val_loss: 0.6402 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.5922 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6587 - val_pred_f1_m: 0.2193 - val_pred_precision_m: 0.4405 - val_pred_recall_m: 0.1467
# Epoch 16/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6414 - decoded_mean_loss: 0.0479 - pred_loss: 0.5935 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6633 - pred_f1_m: 0.2169 - pred_precision_m: 0.4828 - pred_recall_m: 0.1400
# Epoch 00016: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.6414 - decoded_mean_loss: 0.0479 - pred_loss: 0.5935 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6633 - pred_f1_m: 0.2169 - pred_precision_m: 0.4828 - pred_recall_m: 0.1400 - val_loss: 0.6382 - val_decoded_mean_loss: 0.0476 - val_pred_loss: 0.5995 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6627 - val_pred_f1_m: 0.2582 - val_pred_precision_m: 0.4572 - val_pred_recall_m: 0.1800
# Epoch 17/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6380 - decoded_mean_loss: 0.0471 - pred_loss: 0.5909 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6708 - pred_f1_m: 0.2923 - pred_precision_m: 0.5108 - pred_recall_m: 0.2050
# Epoch 00017: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 58s 144ms/sample - loss: 0.6380 - decoded_mean_loss: 0.0471 - pred_loss: 0.5909 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6708 - pred_f1_m: 0.2923 - pred_precision_m: 0.5108 - pred_recall_m: 0.2050 - val_loss: 0.6369 - val_decoded_mean_loss: 0.0466 - val_pred_loss: 0.5963 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6573 - val_pred_f1_m: 0.2978 - val_pred_precision_m: 0.4642 - val_pred_recall_m: 0.2200
# Epoch 18/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6344 - decoded_mean_loss: 0.0461 - pred_loss: 0.5884 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.3244 - pred_precision_m: 0.5011 - pred_recall_m: 0.2400
# Epoch 00018: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 59s 148ms/sample - loss: 0.6344 - decoded_mean_loss: 0.0461 - pred_loss: 0.5884 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.3244 - pred_precision_m: 0.5011 - pred_recall_m: 0.2400 - val_loss: 0.6346 - val_decoded_mean_loss: 0.0456 - val_pred_loss: 0.5837 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6547 - val_pred_f1_m: 0.3268 - val_pred_precision_m: 0.4791 - val_pred_recall_m: 0.2500
# Epoch 19/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6342 - decoded_mean_loss: 0.0450 - pred_loss: 0.5892 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6600 - pred_f1_m: 0.3467 - pred_precision_m: 0.4786 - pred_recall_m: 0.2725
# Epoch 00019: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 61s 153ms/sample - loss: 0.6342 - decoded_mean_loss: 0.0450 - pred_loss: 0.5892 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6600 - pred_f1_m: 0.3467 - pred_precision_m: 0.4786 - pred_recall_m: 0.2725 - val_loss: 0.6330 - val_decoded_mean_loss: 0.0446 - val_pred_loss: 0.5897 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6587 - val_pred_f1_m: 0.3614 - val_pred_precision_m: 0.4656 - val_pred_recall_m: 0.2967
# Epoch 20/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6320 - decoded_mean_loss: 0.0440 - pred_loss: 0.5880 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6625 - pred_f1_m: 0.3836 - pred_precision_m: 0.4911 - pred_recall_m: 0.3150
# Epoch 00020: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 62s 154ms/sample - loss: 0.6320 - decoded_mean_loss: 0.0440 - pred_loss: 0.5880 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6625 - pred_f1_m: 0.3836 - pred_precision_m: 0.4911 - pred_recall_m: 0.3150 - val_loss: 0.6310 - val_decoded_mean_loss: 0.0435 - val_pred_loss: 0.5846 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.3812 - val_pred_precision_m: 0.4894 - val_pred_recall_m: 0.3133
# Epoch 21/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6294 - decoded_mean_loss: 0.0427 - pred_loss: 0.5867 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.3936 - pred_precision_m: 0.5013 - pred_recall_m: 0.3250
# Epoch 00021: val_pred_acc improved from 0.66800 to 0.67067, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 62s 154ms/sample - loss: 0.6294 - decoded_mean_loss: 0.0427 - pred_loss: 0.5867 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.3936 - pred_precision_m: 0.5013 - pred_recall_m: 0.3250 - val_loss: 0.6295 - val_decoded_mean_loss: 0.0422 - val_pred_loss: 0.5851 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6707 - val_pred_f1_m: 0.4151 - val_pred_precision_m: 0.5249 - val_pred_recall_m: 0.3433
# Epoch 22/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6268 - decoded_mean_loss: 0.0414 - pred_loss: 0.5854 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6692 - pred_f1_m: 0.3929 - pred_precision_m: 0.5110 - pred_recall_m: 0.3200
# Epoch 00022: val_pred_acc did not improve from 0.67067
# 400/400 [==============================] - 59s 148ms/sample - loss: 0.6268 - decoded_mean_loss: 0.0414 - pred_loss: 0.5854 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6692 - pred_f1_m: 0.3929 - pred_precision_m: 0.5110 - pred_recall_m: 0.3200 - val_loss: 0.6272 - val_decoded_mean_loss: 0.0409 - val_pred_loss: 0.5914 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6613 - val_pred_f1_m: 0.3749 - val_pred_precision_m: 0.4865 - val_pred_recall_m: 0.3067
# Epoch 23/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6260 - decoded_mean_loss: 0.0401 - pred_loss: 0.5860 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6625 - pred_f1_m: 0.3640 - pred_precision_m: 0.4893 - pred_recall_m: 0.2900
# Epoch 00023: val_pred_acc did not improve from 0.67067
# 400/400 [==============================] - 58s 146ms/sample - loss: 0.6260 - decoded_mean_loss: 0.0401 - pred_loss: 0.5860 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6625 - pred_f1_m: 0.3640 - pred_precision_m: 0.4893 - pred_recall_m: 0.2900 - val_loss: 0.6255 - val_decoded_mean_loss: 0.0395 - val_pred_loss: 0.5823 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6680 - val_pred_f1_m: 0.3852 - val_pred_precision_m: 0.5277 - val_pred_recall_m: 0.3033
# Epoch 24/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6230 - decoded_mean_loss: 0.0387 - pred_loss: 0.5842 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6633 - pred_f1_m: 0.3478 - pred_precision_m: 0.4892 - pred_recall_m: 0.2700
# Epoch 00024: val_pred_acc improved from 0.67067 to 0.67600, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 68s 171ms/sample - loss: 0.6230 - decoded_mean_loss: 0.0387 - pred_loss: 0.5842 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6633 - pred_f1_m: 0.3478 - pred_precision_m: 0.4892 - pred_recall_m: 0.2700 - val_loss: 0.6242 - val_decoded_mean_loss: 0.0383 - val_pred_loss: 0.5869 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6760 - val_pred_f1_m: 0.3735 - val_pred_precision_m: 0.5366 - val_pred_recall_m: 0.2867
# Epoch 25/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6175 - decoded_mean_loss: 0.0375 - pred_loss: 0.5800 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6792 - pred_f1_m: 0.3848 - pred_precision_m: 0.5361 - pred_recall_m: 0.3025
# Epoch 00025: val_pred_acc did not improve from 0.67600
# 400/400 [==============================] - 57s 143ms/sample - loss: 0.6175 - decoded_mean_loss: 0.0375 - pred_loss: 0.5800 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6792 - pred_f1_m: 0.3848 - pred_precision_m: 0.5361 - pred_recall_m: 0.3025 - val_loss: 0.6219 - val_decoded_mean_loss: 0.0371 - val_pred_loss: 0.5807 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6760 - val_pred_f1_m: 0.3696 - val_pred_precision_m: 0.5100 - val_pred_recall_m: 0.2900
# Epoch 26/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6156 - decoded_mean_loss: 0.0364 - pred_loss: 0.5792 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6792 - pred_f1_m: 0.4082 - pred_precision_m: 0.5396 - pred_recall_m: 0.3300
# Epoch 00026: val_pred_acc did not improve from 0.67600
# 400/400 [==============================] - 58s 146ms/sample - loss: 0.6156 - decoded_mean_loss: 0.0364 - pred_loss: 0.5792 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6792 - pred_f1_m: 0.4082 - pred_precision_m: 0.5396 - pred_recall_m: 0.3300 - val_loss: 0.6201 - val_decoded_mean_loss: 0.0362 - val_pred_loss: 0.5825 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6707 - val_pred_f1_m: 0.3810 - val_pred_precision_m: 0.5053 - val_pred_recall_m: 0.3067
# Epoch 27/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6129 - decoded_mean_loss: 0.0352 - pred_loss: 0.5778 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6808 - pred_f1_m: 0.4075 - pred_precision_m: 0.5347 - pred_recall_m: 0.3300
# Epoch 00027: val_pred_acc improved from 0.67600 to 0.68933, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 59s 149ms/sample - loss: 0.6129 - decoded_mean_loss: 0.0352 - pred_loss: 0.5778 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6808 - pred_f1_m: 0.4075 - pred_precision_m: 0.5347 - pred_recall_m: 0.3300 - val_loss: 0.6182 - val_decoded_mean_loss: 0.0348 - val_pred_loss: 0.5817 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6893 - val_pred_f1_m: 0.4208 - val_pred_precision_m: 0.5719 - val_pred_recall_m: 0.3333
# Epoch 28/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6076 - decoded_mean_loss: 0.0340 - pred_loss: 0.5735 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6733 - pred_f1_m: 0.3846 - pred_precision_m: 0.5177 - pred_recall_m: 0.3075
# Epoch 00028: val_pred_acc improved from 0.68933 to 0.69200, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 63s 158ms/sample - loss: 0.6076 - decoded_mean_loss: 0.0340 - pred_loss: 0.5735 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6733 - pred_f1_m: 0.3846 - pred_precision_m: 0.5177 - pred_recall_m: 0.3075 - val_loss: 0.6169 - val_decoded_mean_loss: 0.0335 - val_pred_loss: 0.5899 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.3933 - val_pred_precision_m: 0.5844 - val_pred_recall_m: 0.3000
# Epoch 29/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6043 - decoded_mean_loss: 0.0327 - pred_loss: 0.5715 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6933 - pred_f1_m: 0.4119 - pred_precision_m: 0.5732 - pred_recall_m: 0.3225
# Epoch 00029: val_pred_acc improved from 0.69200 to 0.69467, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 62s 156ms/sample - loss: 0.6043 - decoded_mean_loss: 0.0327 - pred_loss: 0.5715 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6933 - pred_f1_m: 0.4119 - pred_precision_m: 0.5732 - pred_recall_m: 0.3225 - val_loss: 0.6150 - val_decoded_mean_loss: 0.0324 - val_pred_loss: 0.5791 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6947 - val_pred_f1_m: 0.3871 - val_pred_precision_m: 0.5877 - val_pred_recall_m: 0.2900
# Epoch 30/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6029 - decoded_mean_loss: 0.0315 - pred_loss: 0.5713 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7100 - pred_f1_m: 0.4368 - pred_precision_m: 0.6235 - pred_recall_m: 0.3375
# Epoch 00030: val_pred_acc improved from 0.69467 to 0.70000, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 62s 155ms/sample - loss: 0.6029 - decoded_mean_loss: 0.0315 - pred_loss: 0.5713 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7100 - pred_f1_m: 0.4368 - pred_precision_m: 0.6235 - pred_recall_m: 0.3375 - val_loss: 0.6127 - val_decoded_mean_loss: 0.0312 - val_pred_loss: 0.5738 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.7000 - val_pred_f1_m: 0.4346 - val_pred_precision_m: 0.6155 - val_pred_recall_m: 0.3367
# Epoch 31/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5967 - decoded_mean_loss: 0.0302 - pred_loss: 0.5664 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7000 - pred_f1_m: 0.4241 - pred_precision_m: 0.5880 - pred_recall_m: 0.3325
# Epoch 00031: val_pred_acc improved from 0.70000 to 0.70000, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 60s 150ms/sample - loss: 0.5967 - decoded_mean_loss: 0.0302 - pred_loss: 0.5664 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7000 - pred_f1_m: 0.4241 - pred_precision_m: 0.5880 - pred_recall_m: 0.3325 - val_loss: 0.6109 - val_decoded_mean_loss: 0.0299 - val_pred_loss: 0.5829 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.7000 - val_pred_f1_m: 0.4212 - val_pred_precision_m: 0.5728 - val_pred_recall_m: 0.3333
# Epoch 32/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5885 - decoded_mean_loss: 0.0291 - pred_loss: 0.5594 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7067 - pred_f1_m: 0.4648 - pred_precision_m: 0.5957 - pred_recall_m: 0.3825
# Epoch 00032: val_pred_acc did not improve from 0.70000
# 400/400 [==============================] - 61s 151ms/sample - loss: 0.5885 - decoded_mean_loss: 0.0291 - pred_loss: 0.5594 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7067 - pred_f1_m: 0.4648 - pred_precision_m: 0.5957 - pred_recall_m: 0.3825 - val_loss: 0.6110 - val_decoded_mean_loss: 0.0291 - val_pred_loss: 0.5807 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6973 - val_pred_f1_m: 0.4432 - val_pred_precision_m: 0.5711 - val_pred_recall_m: 0.3633
# Epoch 33/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5815 - decoded_mean_loss: 0.0282 - pred_loss: 0.5533 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7142 - pred_f1_m: 0.4924 - pred_precision_m: 0.6067 - pred_recall_m: 0.4150
# Epoch 00033: val_pred_acc did not improve from 0.70000
# 400/400 [==============================] - 59s 146ms/sample - loss: 0.5815 - decoded_mean_loss: 0.0282 - pred_loss: 0.5533 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7142 - pred_f1_m: 0.4924 - pred_precision_m: 0.6067 - pred_recall_m: 0.4150 - val_loss: 0.6103 - val_decoded_mean_loss: 0.0281 - val_pred_loss: 0.5916 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6840 - val_pred_f1_m: 0.4445 - val_pred_precision_m: 0.5230 - val_pred_recall_m: 0.3867
# Epoch 34/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5808 - decoded_mean_loss: 0.0271 - pred_loss: 0.5537 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7075 - pred_f1_m: 0.4862 - pred_precision_m: 0.5839 - pred_recall_m: 0.4175
# Epoch 00034: val_pred_acc did not improve from 0.70000
# 400/400 [==============================] - 68s 170ms/sample - loss: 0.5808 - decoded_mean_loss: 0.0271 - pred_loss: 0.5537 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7075 - pred_f1_m: 0.4862 - pred_precision_m: 0.5839 - pred_recall_m: 0.4175 - val_loss: 0.6076 - val_decoded_mean_loss: 0.0269 - val_pred_loss: 0.5752 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6960 - val_pred_f1_m: 0.4528 - val_pred_precision_m: 0.5768 - val_pred_recall_m: 0.3733
# Epoch 35/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5723 - decoded_mean_loss: 0.0257 - pred_loss: 0.5466 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7208 - pred_f1_m: 0.4958 - pred_precision_m: 0.6234 - pred_recall_m: 0.4125
# Epoch 00035: val_pred_acc did not improve from 0.70000
# 400/400 [==============================] - 58s 146ms/sample - loss: 0.5723 - decoded_mean_loss: 0.0257 - pred_loss: 0.5466 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7208 - pred_f1_m: 0.4958 - pred_precision_m: 0.6234 - pred_recall_m: 0.4125 - val_loss: 0.6070 - val_decoded_mean_loss: 0.0258 - val_pred_loss: 0.5823 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6947 - val_pred_f1_m: 0.4456 - val_pred_precision_m: 0.5682 - val_pred_recall_m: 0.3667
# Epoch 36/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5652 - decoded_mean_loss: 0.0248 - pred_loss: 0.5404 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7225 - pred_f1_m: 0.5090 - pred_precision_m: 0.6167 - pred_recall_m: 0.4350
# Epoch 00036: val_pred_acc did not improve from 0.70000
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.5652 - decoded_mean_loss: 0.0248 - pred_loss: 0.5404 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7225 - pred_f1_m: 0.5090 - pred_precision_m: 0.6167 - pred_recall_m: 0.4350 - val_loss: 0.6085 - val_decoded_mean_loss: 0.0257 - val_pred_loss: 0.5788 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6973 - val_pred_f1_m: 0.5011 - val_pred_precision_m: 0.5822 - val_pred_recall_m: 0.4400
# Epoch 37/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5567 - decoded_mean_loss: 0.0245 - pred_loss: 0.5322 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7075 - pred_f1_m: 0.5123 - pred_precision_m: 0.5785 - pred_recall_m: 0.4600
# Epoch 00037: val_pred_acc did not improve from 0.70000
# 400/400 [==============================] - 59s 147ms/sample - loss: 0.5567 - decoded_mean_loss: 0.0245 - pred_loss: 0.5322 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7075 - pred_f1_m: 0.5123 - pred_precision_m: 0.5785 - pred_recall_m: 0.4600 - val_loss: 0.6101 - val_decoded_mean_loss: 0.0253 - val_pred_loss: 0.5828 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.4835 - val_pred_precision_m: 0.5416 - val_pred_recall_m: 0.4367
# Epoch 38/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5529 - decoded_mean_loss: 0.0241 - pred_loss: 0.5288 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7183 - pred_f1_m: 0.5224 - pred_precision_m: 0.6005 - pred_recall_m: 0.4625
# Epoch 00038: val_pred_acc improved from 0.70000 to 0.70267, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test0.h5
# 400/400 [==============================] - 63s 157ms/sample - loss: 0.5529 - decoded_mean_loss: 0.0241 - pred_loss: 0.5288 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7183 - pred_f1_m: 0.5224 - pred_precision_m: 0.6005 - pred_recall_m: 0.4625 - val_loss: 0.6060 - val_decoded_mean_loss: 0.0242 - val_pred_loss: 0.5916 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.7027 - val_pred_f1_m: 0.4772 - val_pred_precision_m: 0.5792 - val_pred_recall_m: 0.4067
# Epoch 39/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5364 - decoded_mean_loss: 0.0225 - pred_loss: 0.5139 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7475 - pred_f1_m: 0.5595 - pred_precision_m: 0.6711 - pred_recall_m: 0.4800
# Epoch 00039: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 60s 150ms/sample - loss: 0.5364 - decoded_mean_loss: 0.0225 - pred_loss: 0.5139 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7475 - pred_f1_m: 0.5595 - pred_precision_m: 0.6711 - pred_recall_m: 0.4800 - val_loss: 0.6075 - val_decoded_mean_loss: 0.0234 - val_pred_loss: 0.5922 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6813 - val_pred_f1_m: 0.4204 - val_pred_precision_m: 0.5310 - val_pred_recall_m: 0.3500
# Epoch 40/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5372 - decoded_mean_loss: 0.0220 - pred_loss: 0.5153 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7392 - pred_f1_m: 0.5461 - pred_precision_m: 0.6526 - pred_recall_m: 0.4700
# Epoch 00040: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 60s 151ms/sample - loss: 0.5372 - decoded_mean_loss: 0.0220 - pred_loss: 0.5153 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7392 - pred_f1_m: 0.5461 - pred_precision_m: 0.6526 - pred_recall_m: 0.4700 - val_loss: 0.6059 - val_decoded_mean_loss: 0.0238 - val_pred_loss: 0.5798 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.4820 - val_pred_precision_m: 0.5618 - val_pred_recall_m: 0.4233
# Epoch 41/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5319 - decoded_mean_loss: 0.0220 - pred_loss: 0.5099 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7350 - pred_f1_m: 0.5567 - pred_precision_m: 0.6324 - pred_recall_m: 0.4975
# Epoch 00041: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 58s 145ms/sample - loss: 0.5319 - decoded_mean_loss: 0.0220 - pred_loss: 0.5099 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7350 - pred_f1_m: 0.5567 - pred_precision_m: 0.6324 - pred_recall_m: 0.4975 - val_loss: 0.6018 - val_decoded_mean_loss: 0.0220 - val_pred_loss: 0.5963 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6787 - val_pred_f1_m: 0.4301 - val_pred_precision_m: 0.5020 - val_pred_recall_m: 0.3767
# Epoch 42/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5155 - decoded_mean_loss: 0.0208 - pred_loss: 0.4947 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7533 - pred_f1_m: 0.5860 - pred_precision_m: 0.6641 - pred_recall_m: 0.5250
# Epoch 00042: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 59s 149ms/sample - loss: 0.5155 - decoded_mean_loss: 0.0208 - pred_loss: 0.4947 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7533 - pred_f1_m: 0.5860 - pred_precision_m: 0.6641 - pred_recall_m: 0.5250 - val_loss: 0.6044 - val_decoded_mean_loss: 0.0206 - val_pred_loss: 0.5777 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6760 - val_pred_f1_m: 0.4575 - val_pred_precision_m: 0.5285 - val_pred_recall_m: 0.4033
# Epoch 43/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5179 - decoded_mean_loss: 0.0205 - pred_loss: 0.4974 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7467 - pred_f1_m: 0.5761 - pred_precision_m: 0.6523 - pred_recall_m: 0.5175
# Epoch 00043: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 59s 148ms/sample - loss: 0.5179 - decoded_mean_loss: 0.0205 - pred_loss: 0.4974 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7467 - pred_f1_m: 0.5761 - pred_precision_m: 0.6523 - pred_recall_m: 0.5175 - val_loss: 0.6064 - val_decoded_mean_loss: 0.0192 - val_pred_loss: 0.5994 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.4400 - val_pred_precision_m: 0.5008 - val_pred_recall_m: 0.3933
# Epoch 44/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5148 - decoded_mean_loss: 0.0171 - pred_loss: 0.4978 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7492 - pred_f1_m: 0.5778 - pred_precision_m: 0.6585 - pred_recall_m: 0.5150
# Epoch 00044: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 68s 170ms/sample - loss: 0.5148 - decoded_mean_loss: 0.0171 - pred_loss: 0.4978 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7492 - pred_f1_m: 0.5778 - pred_precision_m: 0.6585 - pred_recall_m: 0.5150 - val_loss: 0.6064 - val_decoded_mean_loss: 0.0169 - val_pred_loss: 0.5947 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6720 - val_pred_f1_m: 0.4408 - val_pred_precision_m: 0.5071 - val_pred_recall_m: 0.3900
# Epoch 45/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4872 - decoded_mean_loss: 0.0166 - pred_loss: 0.4706 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7733 - pred_f1_m: 0.6228 - pred_precision_m: 0.6985 - pred_recall_m: 0.5625
# Epoch 00045: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 58s 146ms/sample - loss: 0.4872 - decoded_mean_loss: 0.0166 - pred_loss: 0.4706 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7733 - pred_f1_m: 0.6228 - pred_precision_m: 0.6985 - pred_recall_m: 0.5625 - val_loss: 0.6045 - val_decoded_mean_loss: 0.0180 - val_pred_loss: 0.5805 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6853 - val_pred_f1_m: 0.4853 - val_pred_precision_m: 0.5314 - val_pred_recall_m: 0.4467
# Epoch 46/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4820 - decoded_mean_loss: 0.0172 - pred_loss: 0.4648 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0242 - decoded_mean_precision_m: 0.4844 - decoded_mean_recall_m: 0.0125 - pred_acc: 0.7600 - pred_f1_m: 0.6160 - pred_precision_m: 0.6599 - pred_recall_m: 0.5775
# Epoch 00046: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.4820 - decoded_mean_loss: 0.0172 - pred_loss: 0.4648 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.0242 - decoded_mean_precision_m: 0.4844 - decoded_mean_recall_m: 0.0125 - pred_acc: 0.7600 - pred_f1_m: 0.6160 - pred_precision_m: 0.6599 - pred_recall_m: 0.5775 - val_loss: 0.6127 - val_decoded_mean_loss: 0.0174 - val_pred_loss: 0.5990 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.2324 - val_decoded_mean_precision_m: 0.9674 - val_decoded_mean_recall_m: 0.1324 - val_pred_acc: 0.6747 - val_pred_f1_m: 0.4554 - val_pred_precision_m: 0.5074 - val_pred_recall_m: 0.4133
# Epoch 47/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4785 - decoded_mean_loss: 0.0165 - pred_loss: 0.4620 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.5425 - decoded_mean_precision_m: 0.9836 - decoded_mean_recall_m: 0.4199 - pred_acc: 0.7817 - pred_f1_m: 0.6524 - pred_precision_m: 0.6956 - pred_recall_m: 0.6150
# Epoch 00047: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 61s 151ms/sample - loss: 0.4785 - decoded_mean_loss: 0.0165 - pred_loss: 0.4620 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.5425 - decoded_mean_precision_m: 0.9836 - decoded_mean_recall_m: 0.4199 - pred_acc: 0.7817 - pred_f1_m: 0.6524 - pred_precision_m: 0.6956 - pred_recall_m: 0.6150 - val_loss: 0.6144 - val_decoded_mean_loss: 0.0166 - val_pred_loss: 0.5947 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.9017 - val_decoded_mean_precision_m: 0.9862 - val_decoded_mean_recall_m: 0.8305 - val_pred_acc: 0.6827 - val_pred_f1_m: 0.4757 - val_pred_precision_m: 0.5226 - val_pred_recall_m: 0.4367
# Epoch 48/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4676 - decoded_mean_loss: 0.0156 - pred_loss: 0.4520 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9059 - decoded_mean_precision_m: 0.9878 - decoded_mean_recall_m: 0.8367 - pred_acc: 0.7825 - pred_f1_m: 0.6483 - pred_precision_m: 0.7026 - pred_recall_m: 0.6025
# Epoch 00048: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.4676 - decoded_mean_loss: 0.0156 - pred_loss: 0.4520 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9059 - decoded_mean_precision_m: 0.9878 - decoded_mean_recall_m: 0.8367 - pred_acc: 0.7825 - pred_f1_m: 0.6483 - pred_precision_m: 0.7026 - pred_recall_m: 0.6025 - val_loss: 0.6191 - val_decoded_mean_loss: 0.0161 - val_pred_loss: 0.6215 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.9106 - val_decoded_mean_precision_m: 0.9835 - val_decoded_mean_recall_m: 0.8477 - val_pred_acc: 0.6800 - val_pred_f1_m: 0.4722 - val_pred_precision_m: 0.5141 - val_pred_recall_m: 0.4367
# Epoch 49/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4489 - decoded_mean_loss: 0.0153 - pred_loss: 0.4336 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9133 - decoded_mean_precision_m: 0.9850 - decoded_mean_recall_m: 0.8513 - pred_acc: 0.7858 - pred_f1_m: 0.6521 - pred_precision_m: 0.7108 - pred_recall_m: 0.6025
# Epoch 00049: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 60s 149ms/sample - loss: 0.4489 - decoded_mean_loss: 0.0153 - pred_loss: 0.4336 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9133 - decoded_mean_precision_m: 0.9850 - decoded_mean_recall_m: 0.8513 - pred_acc: 0.7858 - pred_f1_m: 0.6521 - pred_precision_m: 0.7108 - pred_recall_m: 0.6025 - val_loss: 0.6408 - val_decoded_mean_loss: 0.0181 - val_pred_loss: 0.6257 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.9174 - val_decoded_mean_precision_m: 0.9790 - val_decoded_mean_recall_m: 0.8630 - val_pred_acc: 0.6707 - val_pred_f1_m: 0.4880 - val_pred_precision_m: 0.5158 - val_pred_recall_m: 0.4633
# Epoch 50/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4444 - decoded_mean_loss: 0.0183 - pred_loss: 0.4261 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9183 - decoded_mean_precision_m: 0.9797 - decoded_mean_recall_m: 0.8641 - pred_acc: 0.7983 - pred_f1_m: 0.6832 - pred_precision_m: 0.7171 - pred_recall_m: 0.6525
# Epoch 00050: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 59s 148ms/sample - loss: 0.4444 - decoded_mean_loss: 0.0183 - pred_loss: 0.4261 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9183 - decoded_mean_precision_m: 0.9797 - decoded_mean_recall_m: 0.8641 - pred_acc: 0.7983 - pred_f1_m: 0.6832 - pred_precision_m: 0.7171 - pred_recall_m: 0.6525 - val_loss: 0.6521 - val_decoded_mean_loss: 0.0187 - val_pred_loss: 0.6098 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.9193 - val_decoded_mean_precision_m: 0.9771 - val_decoded_mean_recall_m: 0.8679 - val_pred_acc: 0.6733 - val_pred_f1_m: 0.4947 - val_pred_precision_m: 0.5222 - val_pred_recall_m: 0.4700
# Epoch 51/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4319 - decoded_mean_loss: 0.0179 - pred_loss: 0.4140 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9205 - decoded_mean_precision_m: 0.9791 - decoded_mean_recall_m: 0.8685 - pred_acc: 0.8017 - pred_f1_m: 0.6868 - pred_precision_m: 0.7249 - pred_recall_m: 0.6525
# Epoch 00051: val_pred_acc did not improve from 0.70267
# 400/400 [==============================] - 58s 145ms/sample - loss: 0.4319 - decoded_mean_loss: 0.0179 - pred_loss: 0.4140 - decoded_mean_acc: 0.9312 - decoded_mean_f1_m: 0.9205 - decoded_mean_precision_m: 0.9791 - decoded_mean_recall_m: 0.8685 - pred_acc: 0.8017 - pred_f1_m: 0.6868 - pred_precision_m: 0.7249 - pred_recall_m: 0.6525 - val_loss: 0.6377 - val_decoded_mean_loss: 0.0160 - val_pred_loss: 0.6134 - val_decoded_mean_acc: 0.9314 - val_decoded_mean_f1_m: 0.9182 - val_decoded_mean_precision_m: 0.9776 - val_decoded_mean_recall_m: 0.8657 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.4650 - val_pred_precision_m: 0.5020 - val_pred_recall_m: 0.4333
# Epoch 00051: early stopping

# %%
autoencoder.evaluate(x=X_test, y={'decoded_mean': Conversion_X_test, 'pred': y_test})
# Out:
# [0.6382361741065979,
#  0.01619596,
#  0.62150335,
#  0.93136,
#  0.91805303,
#  0.97761947,
#  0.8653486,
#  0.66533333,
#  0.46067712,
#  0.49902016,
#  0.42878607]

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# # **Test_1**
# Une Couche a 250 Neurones

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/Models_a_ameliorer'
MODEL_FILE_NAME = 'Test1.h5'
LR=0.0001

batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500

encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)

def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(250, return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Dense(300, activation='relu', name='dense_1')(h)
    
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])

    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    
    return (fct_loss, z)
     
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()

def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)
    
encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()

def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h =Bidirectional(  LSTM(250, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 

autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_1 (Embedding)        (None, 100, 100)     2281400     ['input_3[0][0]']
#
#  bidirectional_3 (Bidirectional  (None, 100, 500)    702000      ['embedding_1[0][0]']
#  )
#
#  attention_couche_1 (AttentionC  (None, 500)         600         ['bidirectional_3[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          150300      ['attention_couche_1[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 3,254,700
# Trainable params: 3,254,700
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 200)]             0
#
#  dense_4 (Dense)             (None, 100)               20100
#
#  pred (Dense)                (None, 3)                 303
#
# =================================================================
# Total params: 20,403
# Trainable params: 20,403
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 200)]             0
#
#  repeat_vector_4 (RepeatVect  (None, 100, 200)         0
#  or)
#
#  bidirectional_4 (Bidirectio  (None, 100, 500)         902000
#  nal)
#
#  decoded_mean (TimeDistribut  (None, 100, 22814)       11429814
#  ed)
#
# =================================================================
# Total params: 12,331,814
# Trainable params: 12,331,814
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_1 (Embedding)        (None, 100, 100)     2281400     ['input_3[0][0]']
#
#  bidirectional_3 (Bidirectional  (None, 100, 500)    702000      ['embedding_1[0][0]']
#  )
#
#  attention_couche_1 (AttentionC  (None, 500)         600         ['bidirectional_3[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          150300      ['attention_couche_1[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  repeat_vector_5 (RepeatVector)  (None, 100, 200)    0           ['z[0][0]']
#
#  bidirectional_5 (Bidirectional  (None, 100, 500)    902000      ['repeat_vector_5[0][0]']
#  )
#
#  dense_7 (Dense)                (None, 100)          20100       ['z[0][0]']
#
#  decoded_mean (TimeDistributed)  (None, 100, 22814)  11429814    ['bidirectional_5[0][0]']
#
#  pred (Dense)                   (None, 3)            303         ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 15,606,917
# Trainable params: 15,606,917
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])
# Out:
# Train on 400 samples, validate on 250 samples
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7372 - decoded_mean_loss: 0.0484 - pred_loss: 0.6888 - decoded_mean_acc: 0.0000e+00 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 00001: val_pred_acc improved from -inf to 0.66667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 83s 207ms/sample - loss: 0.7372 - decoded_mean_loss: 0.0484 - pred_loss: 0.6888 - decoded_mean_acc: 0.0000e+00 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7313 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6832 - val_decoded_mean_acc: 0.0080 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7287 - decoded_mean_loss: 0.0484 - pred_loss: 0.6802 - decoded_mean_acc: 0.0672 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00002: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 75s 187ms/sample - loss: 0.7287 - decoded_mean_loss: 0.0484 - pred_loss: 0.6802 - decoded_mean_acc: 0.0672 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7212 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6726 - val_decoded_mean_acc: 0.5636 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7178 - decoded_mean_loss: 0.0485 - pred_loss: 0.6693 - decoded_mean_acc: 0.5482 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00003: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 74s 186ms/sample - loss: 0.7178 - decoded_mean_loss: 0.0485 - pred_loss: 0.6693 - decoded_mean_acc: 0.5482 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7092 - val_decoded_mean_loss: 0.0485 - val_pred_loss: 0.6610 - val_decoded_mean_acc: 0.9296 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 4/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7063 - decoded_mean_loss: 0.0485 - pred_loss: 0.6577 - decoded_mean_acc: 0.9174 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00004: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 76s 189ms/sample - loss: 0.7063 - decoded_mean_loss: 0.0485 - pred_loss: 0.6577 - decoded_mean_acc: 0.9174 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.6937 - val_decoded_mean_loss: 0.0487 - val_pred_loss: 0.6454 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 5/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6906 - decoded_mean_loss: 0.0487 - pred_loss: 0.6418 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6658 - pred_f1_m: 0.0096 - pred_precision_m: 0.1250 - pred_recall_m: 0.0050
# Epoch 00005: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 75s 188ms/sample - loss: 0.6906 - decoded_mean_loss: 0.0487 - pred_loss: 0.6418 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6658 - pred_f1_m: 0.0096 - pred_precision_m: 0.1250 - pred_recall_m: 0.0050 - val_loss: 0.6767 - val_decoded_mean_loss: 0.0490 - val_pred_loss: 0.6321 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6653 - val_pred_f1_m: 0.0255 - val_pred_precision_m: 0.3111 - val_pred_recall_m: 0.0133
# Epoch 6/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6734 - decoded_mean_loss: 0.0491 - pred_loss: 0.6243 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.1247 - pred_precision_m: 0.5729 - pred_recall_m: 0.0725
# Epoch 00006: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 74s 184ms/sample - loss: 0.6734 - decoded_mean_loss: 0.0491 - pred_loss: 0.6243 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.1247 - pred_precision_m: 0.5729 - pred_recall_m: 0.0725 - val_loss: 0.6591 - val_decoded_mean_loss: 0.0497 - val_pred_loss: 0.6083 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6480 - val_pred_f1_m: 0.2431 - val_pred_precision_m: 0.4582 - val_pred_recall_m: 0.1667
# Epoch 7/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6595 - decoded_mean_loss: 0.0500 - pred_loss: 0.6095 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6617 - pred_f1_m: 0.3299 - pred_precision_m: 0.4836 - pred_recall_m: 0.2525
# Epoch 00007: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 82s 204ms/sample - loss: 0.6595 - decoded_mean_loss: 0.0500 - pred_loss: 0.6095 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6617 - pred_f1_m: 0.3299 - pred_precision_m: 0.4836 - pred_recall_m: 0.2525 - val_loss: 0.6502 - val_decoded_mean_loss: 0.0511 - val_pred_loss: 0.5960 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6613 - val_pred_f1_m: 0.4670 - val_pred_precision_m: 0.5067 - val_pred_recall_m: 0.4333
# Epoch 8/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6563 - decoded_mean_loss: 0.0514 - pred_loss: 0.6049 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6558 - pred_f1_m: 0.4514 - pred_precision_m: 0.4831 - pred_recall_m: 0.4250
# Epoch 00008: val_pred_acc improved from 0.66667 to 0.66800, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 78s 195ms/sample - loss: 0.6563 - decoded_mean_loss: 0.0514 - pred_loss: 0.6049 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6558 - pred_f1_m: 0.4514 - pred_precision_m: 0.4831 - pred_recall_m: 0.4250 - val_loss: 0.6522 - val_decoded_mean_loss: 0.0520 - val_pred_loss: 0.5999 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6680 - val_pred_f1_m: 0.4851 - val_pred_precision_m: 0.5018 - val_pred_recall_m: 0.4700
# Epoch 9/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6579 - decoded_mean_loss: 0.0514 - pred_loss: 0.6065 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4720 - pred_precision_m: 0.4879 - pred_recall_m: 0.4575
# Epoch 00009: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 75s 188ms/sample - loss: 0.6579 - decoded_mean_loss: 0.0514 - pred_loss: 0.6065 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4720 - pred_precision_m: 0.4879 - pred_recall_m: 0.4575 - val_loss: 0.6460 - val_decoded_mean_loss: 0.0508 - val_pred_loss: 0.5916 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.4887 - val_pred_precision_m: 0.5051 - val_pred_recall_m: 0.4733
# Epoch 10/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6529 - decoded_mean_loss: 0.0502 - pred_loss: 0.6027 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6567 - pred_f1_m: 0.4580 - pred_precision_m: 0.4840 - pred_recall_m: 0.4350
# Epoch 00010: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 75s 188ms/sample - loss: 0.6529 - decoded_mean_loss: 0.0502 - pred_loss: 0.6027 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6567 - pred_f1_m: 0.4580 - pred_precision_m: 0.4840 - pred_recall_m: 0.4350 - val_loss: 0.6429 - val_decoded_mean_loss: 0.0496 - val_pred_loss: 0.6000 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.4460 - val_pred_precision_m: 0.4714 - val_pred_recall_m: 0.4233
# Epoch 11/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6516 - decoded_mean_loss: 0.0492 - pred_loss: 0.6024 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4488 - pred_precision_m: 0.4861 - pred_recall_m: 0.4175
# Epoch 00011: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 75s 187ms/sample - loss: 0.6516 - decoded_mean_loss: 0.0492 - pred_loss: 0.6024 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4488 - pred_precision_m: 0.4861 - pred_recall_m: 0.4175 - val_loss: 0.6414 - val_decoded_mean_loss: 0.0486 - val_pred_loss: 0.5958 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6587 - val_pred_f1_m: 0.4441 - val_pred_precision_m: 0.4798 - val_pred_recall_m: 0.4133
# Epoch 12/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6493 - decoded_mean_loss: 0.0481 - pred_loss: 0.6012 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6567 - pred_f1_m: 0.4403 - pred_precision_m: 0.4822 - pred_recall_m: 0.4050
# Epoch 00012: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 74s 184ms/sample - loss: 0.6493 - decoded_mean_loss: 0.0481 - pred_loss: 0.6012 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6567 - pred_f1_m: 0.4403 - pred_precision_m: 0.4822 - pred_recall_m: 0.4050 - val_loss: 0.6389 - val_decoded_mean_loss: 0.0475 - val_pred_loss: 0.5910 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.4480 - val_pred_precision_m: 0.4808 - val_pred_recall_m: 0.4200
# Epoch 13/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6461 - decoded_mean_loss: 0.0469 - pred_loss: 0.5993 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6592 - pred_f1_m: 0.4550 - pred_precision_m: 0.4875 - pred_recall_m: 0.4275
# Epoch 00013: val_pred_acc did not improve from 0.66800
# 400/400 [==============================] - 74s 186ms/sample - loss: 0.6461 - decoded_mean_loss: 0.0469 - pred_loss: 0.5993 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6592 - pred_f1_m: 0.4550 - pred_precision_m: 0.4875 - pred_recall_m: 0.4275 - val_loss: 0.6349 - val_decoded_mean_loss: 0.0460 - val_pred_loss: 0.5842 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.5024 - val_pred_precision_m: 0.5158 - val_pred_recall_m: 0.4900
# Epoch 14/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6425 - decoded_mean_loss: 0.0453 - pred_loss: 0.5972 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4770 - pred_precision_m: 0.4869 - pred_recall_m: 0.4675
# Epoch 00014: val_pred_acc improved from 0.66800 to 0.67733, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 76s 191ms/sample - loss: 0.6425 - decoded_mean_loss: 0.0453 - pred_loss: 0.5972 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4770 - pred_precision_m: 0.4869 - pred_recall_m: 0.4675 - val_loss: 0.6312 - val_decoded_mean_loss: 0.0443 - val_pred_loss: 0.5824 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5333 - val_pred_precision_m: 0.5333 - val_pred_recall_m: 0.5333
# Epoch 15/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6401 - decoded_mean_loss: 0.0434 - pred_loss: 0.5967 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.5006 - pred_precision_m: 0.5012 - pred_recall_m: 0.5000
# Epoch 00015: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 84s 210ms/sample - loss: 0.6401 - decoded_mean_loss: 0.0434 - pred_loss: 0.5967 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.5006 - pred_precision_m: 0.5012 - pred_recall_m: 0.5000 - val_loss: 0.6285 - val_decoded_mean_loss: 0.0422 - val_pred_loss: 0.5806 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6760 - val_pred_f1_m: 0.5308 - val_pred_precision_m: 0.5316 - val_pred_recall_m: 0.5300
# Epoch 16/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6375 - decoded_mean_loss: 0.0413 - pred_loss: 0.5962 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000
# Epoch 00016: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 74s 185ms/sample - loss: 0.6375 - decoded_mean_loss: 0.0413 - pred_loss: 0.5962 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000 - val_loss: 0.6257 - val_decoded_mean_loss: 0.0400 - val_pred_loss: 0.5906 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5033 - val_pred_precision_m: 0.5033 - val_pred_recall_m: 0.5033
# Epoch 17/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6344 - decoded_mean_loss: 0.0390 - pred_loss: 0.5954 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.4954 - pred_precision_m: 0.4983 - pred_recall_m: 0.4925
# Epoch 00017: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 73s 183ms/sample - loss: 0.6344 - decoded_mean_loss: 0.0390 - pred_loss: 0.5954 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.4954 - pred_precision_m: 0.4983 - pred_recall_m: 0.4925 - val_loss: 0.6233 - val_decoded_mean_loss: 0.0375 - val_pred_loss: 0.5819 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6693 - val_pred_f1_m: 0.5025 - val_pred_precision_m: 0.5084 - val_pred_recall_m: 0.4967
# Epoch 18/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6307 - decoded_mean_loss: 0.0367 - pred_loss: 0.5940 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.4963 - pred_precision_m: 0.5002 - pred_recall_m: 0.4925
# Epoch 00018: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 74s 184ms/sample - loss: 0.6307 - decoded_mean_loss: 0.0367 - pred_loss: 0.5940 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.4963 - pred_precision_m: 0.5002 - pred_recall_m: 0.4925 - val_loss: 0.6207 - val_decoded_mean_loss: 0.0355 - val_pred_loss: 0.5914 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5000 - val_pred_precision_m: 0.5000 - val_pred_recall_m: 0.5000
# Epoch 19/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6275 - decoded_mean_loss: 0.0347 - pred_loss: 0.5928 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.4994 - pred_precision_m: 0.5013 - pred_recall_m: 0.4975
# Epoch 00019: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 75s 188ms/sample - loss: 0.6275 - decoded_mean_loss: 0.0347 - pred_loss: 0.5928 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.4994 - pred_precision_m: 0.5013 - pred_recall_m: 0.4975 - val_loss: 0.6181 - val_decoded_mean_loss: 0.0336 - val_pred_loss: 0.5797 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5233 - val_pred_precision_m: 0.5233 - val_pred_recall_m: 0.5233
# Epoch 20/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6239 - decoded_mean_loss: 0.0327 - pred_loss: 0.5912 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000
# Epoch 00020: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 74s 186ms/sample - loss: 0.6239 - decoded_mean_loss: 0.0327 - pred_loss: 0.5912 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000 - val_loss: 0.6136 - val_decoded_mean_loss: 0.0315 - val_pred_loss: 0.5821 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5100 - val_pred_precision_m: 0.5100 - val_pred_recall_m: 0.5100
# Epoch 21/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6218 - decoded_mean_loss: 0.0306 - pred_loss: 0.5912 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000
# Epoch 00021: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 74s 185ms/sample - loss: 0.6218 - decoded_mean_loss: 0.0306 - pred_loss: 0.5912 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000 - val_loss: 0.6110 - val_decoded_mean_loss: 0.0291 - val_pred_loss: 0.5776 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5267 - val_pred_precision_m: 0.5267 - val_pred_recall_m: 0.5267
# Epoch 22/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6179 - decoded_mean_loss: 0.0282 - pred_loss: 0.5897 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000
# Epoch 00022: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 74s 185ms/sample - loss: 0.6179 - decoded_mean_loss: 0.0282 - pred_loss: 0.5897 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000 - val_loss: 0.6073 - val_decoded_mean_loss: 0.0268 - val_pred_loss: 0.5788 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5133 - val_pred_precision_m: 0.5133 - val_pred_recall_m: 0.5133
# Epoch 23/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6124 - decoded_mean_loss: 0.0258 - pred_loss: 0.5866 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000
# Epoch 00023: val_pred_acc did not improve from 0.67733
# 400/400 [==============================] - 83s 207ms/sample - loss: 0.6124 - decoded_mean_loss: 0.0258 - pred_loss: 0.5866 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.5000 - pred_precision_m: 0.5000 - pred_recall_m: 0.5000 - val_loss: 0.6040 - val_decoded_mean_loss: 0.0244 - val_pred_loss: 0.5763 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5267 - val_pred_precision_m: 0.5267 - val_pred_recall_m: 0.5267
# Epoch 24/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6086 - decoded_mean_loss: 0.0235 - pred_loss: 0.5851 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6692 - pred_f1_m: 0.5019 - pred_precision_m: 0.5039 - pred_recall_m: 0.5000
# Epoch 00024: val_pred_acc improved from 0.67733 to 0.67867, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 79s 197ms/sample - loss: 0.6086 - decoded_mean_loss: 0.0235 - pred_loss: 0.5851 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6692 - pred_f1_m: 0.5019 - pred_precision_m: 0.5039 - pred_recall_m: 0.5000 - val_loss: 0.5992 - val_decoded_mean_loss: 0.0222 - val_pred_loss: 0.5774 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6787 - val_pred_f1_m: 0.5208 - val_pred_precision_m: 0.5215 - val_pred_recall_m: 0.5200
# Epoch 25/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6039 - decoded_mean_loss: 0.0213 - pred_loss: 0.5826 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6683 - pred_f1_m: 0.5000 - pred_precision_m: 0.5026 - pred_recall_m: 0.4975
# Epoch 00025: val_pred_acc did not improve from 0.67867
# 400/400 [==============================] - 78s 196ms/sample - loss: 0.6039 - decoded_mean_loss: 0.0213 - pred_loss: 0.5826 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6683 - pred_f1_m: 0.5000 - pred_precision_m: 0.5026 - pred_recall_m: 0.4975 - val_loss: 0.5932 - val_decoded_mean_loss: 0.0201 - val_pred_loss: 0.5775 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5067 - val_pred_precision_m: 0.5067 - val_pred_recall_m: 0.5067
# Epoch 26/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5989 - decoded_mean_loss: 0.0191 - pred_loss: 0.5799 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6683 - pred_f1_m: 0.5012 - pred_precision_m: 0.5023 - pred_recall_m: 0.5000
# Epoch 00026: val_pred_acc improved from 0.67867 to 0.68133, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 80s 199ms/sample - loss: 0.5989 - decoded_mean_loss: 0.0191 - pred_loss: 0.5799 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6683 - pred_f1_m: 0.5012 - pred_precision_m: 0.5023 - pred_recall_m: 0.5000 - val_loss: 0.5883 - val_decoded_mean_loss: 0.0177 - val_pred_loss: 0.5658 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6813 - val_pred_f1_m: 0.5268 - val_pred_precision_m: 0.5303 - val_pred_recall_m: 0.5233
# Epoch 27/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5906 - decoded_mean_loss: 0.0169 - pred_loss: 0.5738 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6742 - pred_f1_m: 0.5044 - pred_precision_m: 0.5116 - pred_recall_m: 0.4975
# Epoch 00027: val_pred_acc did not improve from 0.68133
# 400/400 [==============================] - 79s 197ms/sample - loss: 0.5906 - decoded_mean_loss: 0.0169 - pred_loss: 0.5738 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6742 - pred_f1_m: 0.5044 - pred_precision_m: 0.5116 - pred_recall_m: 0.4975 - val_loss: 0.5807 - val_decoded_mean_loss: 0.0157 - val_pred_loss: 0.5634 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6773 - val_pred_f1_m: 0.5064 - val_pred_precision_m: 0.5132 - val_pred_recall_m: 0.5000
# Epoch 28/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5789 - decoded_mean_loss: 0.0149 - pred_loss: 0.5639 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6833 - pred_f1_m: 0.5057 - pred_precision_m: 0.5287 - pred_recall_m: 0.4850
# Epoch 00028: val_pred_acc improved from 0.68133 to 0.68533, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 80s 200ms/sample - loss: 0.5789 - decoded_mean_loss: 0.0149 - pred_loss: 0.5639 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6833 - pred_f1_m: 0.5057 - pred_precision_m: 0.5287 - pred_recall_m: 0.4850 - val_loss: 0.5694 - val_decoded_mean_loss: 0.0141 - val_pred_loss: 0.5585 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6853 - val_pred_f1_m: 0.4921 - val_pred_precision_m: 0.5126 - val_pred_recall_m: 0.4733
# Epoch 29/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5613 - decoded_mean_loss: 0.0140 - pred_loss: 0.5473 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7125 - pred_f1_m: 0.5395 - pred_precision_m: 0.5791 - pred_recall_m: 0.5050
# Epoch 00029: val_pred_acc improved from 0.68533 to 0.70933, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 78s 195ms/sample - loss: 0.5613 - decoded_mean_loss: 0.0140 - pred_loss: 0.5473 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.7125 - pred_f1_m: 0.5395 - pred_precision_m: 0.5791 - pred_recall_m: 0.5050 - val_loss: 0.5519 - val_decoded_mean_loss: 0.0149 - val_pred_loss: 0.5367 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.1293 - val_decoded_mean_precision_m: 0.9903 - val_decoded_mean_recall_m: 0.0693 - val_pred_acc: 0.7093 - val_pred_f1_m: 0.5436 - val_pred_precision_m: 0.5694 - val_pred_recall_m: 0.5200
# Epoch 30/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5491 - decoded_mean_loss: 0.0146 - pred_loss: 0.5345 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.7058 - decoded_mean_precision_m: 0.9971 - decoded_mean_recall_m: 0.6279 - pred_acc: 0.7183 - pred_f1_m: 0.5646 - pred_precision_m: 0.5829 - pred_recall_m: 0.5475
# Epoch 00030: val_pred_acc improved from 0.70933 to 0.71467, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 92s 229ms/sample - loss: 0.5491 - decoded_mean_loss: 0.0146 - pred_loss: 0.5345 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.7058 - decoded_mean_precision_m: 0.9971 - decoded_mean_recall_m: 0.6279 - pred_acc: 0.7183 - pred_f1_m: 0.5646 - pred_precision_m: 0.5829 - pred_recall_m: 0.5475 - val_loss: 0.5657 - val_decoded_mean_loss: 0.0146 - val_pred_loss: 0.5513 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9053 - val_decoded_mean_precision_m: 0.9919 - val_decoded_mean_recall_m: 0.8327 - val_pred_acc: 0.7147 - val_pred_f1_m: 0.5655 - val_pred_precision_m: 0.5782 - val_pred_recall_m: 0.5533
# Epoch 31/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5416 - decoded_mean_loss: 0.0150 - pred_loss: 0.5266 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9105 - decoded_mean_precision_m: 0.9909 - decoded_mean_recall_m: 0.8421 - pred_acc: 0.7258 - pred_f1_m: 0.5820 - pred_precision_m: 0.5920 - pred_recall_m: 0.5725
# Epoch 00031: val_pred_acc did not improve from 0.71467
# 400/400 [==============================] - 78s 194ms/sample - loss: 0.5416 - decoded_mean_loss: 0.0150 - pred_loss: 0.5266 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9105 - decoded_mean_precision_m: 0.9909 - decoded_mean_recall_m: 0.8421 - pred_acc: 0.7258 - pred_f1_m: 0.5820 - pred_precision_m: 0.5920 - pred_recall_m: 0.5725 - val_loss: 0.5493 - val_decoded_mean_loss: 0.0151 - val_pred_loss: 0.5379 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9153 - val_decoded_mean_precision_m: 0.9865 - val_decoded_mean_recall_m: 0.8537 - val_pred_acc: 0.7133 - val_pred_f1_m: 0.5546 - val_pred_precision_m: 0.5663 - val_pred_recall_m: 0.5433
# Epoch 32/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5273 - decoded_mean_loss: 0.0134 - pred_loss: 0.5138 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9167 - decoded_mean_precision_m: 0.9874 - decoded_mean_recall_m: 0.8555 - pred_acc: 0.7383 - pred_f1_m: 0.5993 - pred_precision_m: 0.6118 - pred_recall_m: 0.5875
# Epoch 00032: val_pred_acc improved from 0.71467 to 0.72267, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 77s 191ms/sample - loss: 0.5273 - decoded_mean_loss: 0.0134 - pred_loss: 0.5138 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9167 - decoded_mean_precision_m: 0.9874 - decoded_mean_recall_m: 0.8555 - pred_acc: 0.7383 - pred_f1_m: 0.5993 - pred_precision_m: 0.6118 - pred_recall_m: 0.5875 - val_loss: 0.5503 - val_decoded_mean_loss: 0.0111 - val_pred_loss: 0.5352 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9171 - val_decoded_mean_precision_m: 0.9869 - val_decoded_mean_recall_m: 0.8566 - val_pred_acc: 0.7227 - val_pred_f1_m: 0.5782 - val_pred_precision_m: 0.5943 - val_pred_recall_m: 0.5633
# Epoch 33/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5305 - decoded_mean_loss: 0.0108 - pred_loss: 0.5197 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9175 - decoded_mean_precision_m: 0.9873 - decoded_mean_recall_m: 0.8570 - pred_acc: 0.7400 - pred_f1_m: 0.5880 - pred_precision_m: 0.6224 - pred_recall_m: 0.5575
# Epoch 00033: val_pred_acc improved from 0.72267 to 0.73733, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test1.h5
# 400/400 [==============================] - 78s 195ms/sample - loss: 0.5305 - decoded_mean_loss: 0.0108 - pred_loss: 0.5197 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9175 - decoded_mean_precision_m: 0.9873 - decoded_mean_recall_m: 0.8570 - pred_acc: 0.7400 - pred_f1_m: 0.5880 - pred_precision_m: 0.6224 - pred_recall_m: 0.5575 - val_loss: 0.5431 - val_decoded_mean_loss: 0.0103 - val_pred_loss: 0.5263 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9168 - val_decoded_mean_precision_m: 0.9850 - val_decoded_mean_recall_m: 0.8574 - val_pred_acc: 0.7373 - val_pred_f1_m: 0.5906 - val_pred_precision_m: 0.6335 - val_pred_recall_m: 0.5533
# Epoch 34/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5206 - decoded_mean_loss: 0.0104 - pred_loss: 0.5101 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9192 - decoded_mean_precision_m: 0.9861 - decoded_mean_recall_m: 0.8609 - pred_acc: 0.7517 - pred_f1_m: 0.6106 - pred_precision_m: 0.6388 - pred_recall_m: 0.5850
# Epoch 00034: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 75s 187ms/sample - loss: 0.5206 - decoded_mean_loss: 0.0104 - pred_loss: 0.5101 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9192 - decoded_mean_precision_m: 0.9861 - decoded_mean_recall_m: 0.8609 - pred_acc: 0.7517 - pred_f1_m: 0.6106 - pred_precision_m: 0.6388 - pred_recall_m: 0.5850 - val_loss: 0.5415 - val_decoded_mean_loss: 0.0109 - val_pred_loss: 0.5304 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9206 - val_decoded_mean_precision_m: 0.9832 - val_decoded_mean_recall_m: 0.8655 - val_pred_acc: 0.7320 - val_pred_f1_m: 0.5695 - val_pred_precision_m: 0.6025 - val_pred_recall_m: 0.5400
# Epoch 35/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5153 - decoded_mean_loss: 0.0123 - pred_loss: 0.5030 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9231 - decoded_mean_precision_m: 0.9816 - decoded_mean_recall_m: 0.8713 - pred_acc: 0.7342 - pred_f1_m: 0.5896 - pred_precision_m: 0.6079 - pred_recall_m: 0.5725
# Epoch 00035: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 85s 212ms/sample - loss: 0.5153 - decoded_mean_loss: 0.0123 - pred_loss: 0.5030 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9231 - decoded_mean_precision_m: 0.9816 - decoded_mean_recall_m: 0.8713 - pred_acc: 0.7342 - pred_f1_m: 0.5896 - pred_precision_m: 0.6079 - pred_recall_m: 0.5725 - val_loss: 0.5483 - val_decoded_mean_loss: 0.0119 - val_pred_loss: 0.5305 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9233 - val_decoded_mean_precision_m: 0.9794 - val_decoded_mean_recall_m: 0.8732 - val_pred_acc: 0.7253 - val_pred_f1_m: 0.5691 - val_pred_precision_m: 0.6019 - val_pred_recall_m: 0.5400
# Epoch 36/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5164 - decoded_mean_loss: 0.0113 - pred_loss: 0.5051 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9236 - decoded_mean_precision_m: 0.9813 - decoded_mean_recall_m: 0.8724 - pred_acc: 0.7442 - pred_f1_m: 0.5965 - pred_precision_m: 0.6285 - pred_recall_m: 0.5675
# Epoch 00036: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 77s 193ms/sample - loss: 0.5164 - decoded_mean_loss: 0.0113 - pred_loss: 0.5051 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9236 - decoded_mean_precision_m: 0.9813 - decoded_mean_recall_m: 0.8724 - pred_acc: 0.7442 - pred_f1_m: 0.5965 - pred_precision_m: 0.6285 - pred_recall_m: 0.5675 - val_loss: 0.5504 - val_decoded_mean_loss: 0.0100 - val_pred_loss: 0.5444 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9206 - val_decoded_mean_precision_m: 0.9828 - val_decoded_mean_recall_m: 0.8658 - val_pred_acc: 0.7227 - val_pred_f1_m: 0.5567 - val_pred_precision_m: 0.6036 - val_pred_recall_m: 0.5167
# Epoch 37/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5124 - decoded_mean_loss: 0.0105 - pred_loss: 0.5019 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9224 - decoded_mean_precision_m: 0.9831 - decoded_mean_recall_m: 0.8687 - pred_acc: 0.7583 - pred_f1_m: 0.6049 - pred_precision_m: 0.6654 - pred_recall_m: 0.5550
# Epoch 00037: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 74s 185ms/sample - loss: 0.5124 - decoded_mean_loss: 0.0105 - pred_loss: 0.5019 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9224 - decoded_mean_precision_m: 0.9831 - decoded_mean_recall_m: 0.8687 - pred_acc: 0.7583 - pred_f1_m: 0.6049 - pred_precision_m: 0.6654 - pred_recall_m: 0.5550 - val_loss: 0.5544 - val_decoded_mean_loss: 0.0107 - val_pred_loss: 0.5418 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9218 - val_decoded_mean_precision_m: 0.9810 - val_decoded_mean_recall_m: 0.8694 - val_pred_acc: 0.7040 - val_pred_f1_m: 0.5285 - val_pred_precision_m: 0.5742 - val_pred_recall_m: 0.4900
# Epoch 38/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4872 - decoded_mean_loss: 0.0114 - pred_loss: 0.4758 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9246 - decoded_mean_precision_m: 0.9810 - decoded_mean_recall_m: 0.8744 - pred_acc: 0.7642 - pred_f1_m: 0.6280 - pred_precision_m: 0.6620 - pred_recall_m: 0.5975
# Epoch 00038: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 82s 205ms/sample - loss: 0.4872 - decoded_mean_loss: 0.0114 - pred_loss: 0.4758 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9246 - decoded_mean_precision_m: 0.9810 - decoded_mean_recall_m: 0.8744 - pred_acc: 0.7642 - pred_f1_m: 0.6280 - pred_precision_m: 0.6620 - pred_recall_m: 0.5975 - val_loss: 0.5488 - val_decoded_mean_loss: 0.0124 - val_pred_loss: 0.5366 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9258 - val_decoded_mean_precision_m: 0.9792 - val_decoded_mean_recall_m: 0.8780 - val_pred_acc: 0.7213 - val_pred_f1_m: 0.5511 - val_pred_precision_m: 0.5864 - val_pred_recall_m: 0.5200
# Epoch 39/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4940 - decoded_mean_loss: 0.0132 - pred_loss: 0.4808 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9268 - decoded_mean_precision_m: 0.9780 - decoded_mean_recall_m: 0.8807 - pred_acc: 0.7592 - pred_f1_m: 0.6241 - pred_precision_m: 0.6504 - pred_recall_m: 0.6000
# Epoch 00039: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 75s 188ms/sample - loss: 0.4940 - decoded_mean_loss: 0.0132 - pred_loss: 0.4808 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9268 - decoded_mean_precision_m: 0.9780 - decoded_mean_recall_m: 0.8807 - pred_acc: 0.7592 - pred_f1_m: 0.6241 - pred_precision_m: 0.6504 - pred_recall_m: 0.6000 - val_loss: 0.5568 - val_decoded_mean_loss: 0.0125 - val_pred_loss: 0.5519 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9264 - val_decoded_mean_precision_m: 0.9784 - val_decoded_mean_recall_m: 0.8797 - val_pred_acc: 0.7213 - val_pred_f1_m: 0.5476 - val_pred_precision_m: 0.5703 - val_pred_recall_m: 0.5267
# Epoch 40/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4961 - decoded_mean_loss: 0.0122 - pred_loss: 0.4839 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9267 - decoded_mean_precision_m: 0.9795 - decoded_mean_recall_m: 0.8792 - pred_acc: 0.7508 - pred_f1_m: 0.6071 - pred_precision_m: 0.6402 - pred_recall_m: 0.5775
# Epoch 00040: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 76s 189ms/sample - loss: 0.4961 - decoded_mean_loss: 0.0122 - pred_loss: 0.4839 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9267 - decoded_mean_precision_m: 0.9795 - decoded_mean_recall_m: 0.8792 - pred_acc: 0.7508 - pred_f1_m: 0.6071 - pred_precision_m: 0.6402 - pred_recall_m: 0.5775 - val_loss: 0.5620 - val_decoded_mean_loss: 0.0104 - val_pred_loss: 0.5417 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9255 - val_decoded_mean_precision_m: 0.9808 - val_decoded_mean_recall_m: 0.8762 - val_pred_acc: 0.7213 - val_pred_f1_m: 0.5695 - val_pred_precision_m: 0.6070 - val_pred_recall_m: 0.5367
# Epoch 41/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4845 - decoded_mean_loss: 0.0108 - pred_loss: 0.4737 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9264 - decoded_mean_precision_m: 0.9810 - decoded_mean_recall_m: 0.8776 - pred_acc: 0.7775 - pred_f1_m: 0.6453 - pred_precision_m: 0.6883 - pred_recall_m: 0.6075
# Epoch 00041: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 76s 191ms/sample - loss: 0.4845 - decoded_mean_loss: 0.0108 - pred_loss: 0.4737 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9264 - decoded_mean_precision_m: 0.9810 - decoded_mean_recall_m: 0.8776 - pred_acc: 0.7775 - pred_f1_m: 0.6453 - pred_precision_m: 0.6883 - pred_recall_m: 0.6075 - val_loss: 0.5530 - val_decoded_mean_loss: 0.0102 - val_pred_loss: 0.5444 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9246 - val_decoded_mean_precision_m: 0.9808 - val_decoded_mean_recall_m: 0.8744 - val_pred_acc: 0.7093 - val_pred_f1_m: 0.5364 - val_pred_precision_m: 0.5743 - val_pred_recall_m: 0.5033
# Epoch 42/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4835 - decoded_mean_loss: 0.0106 - pred_loss: 0.4729 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9267 - decoded_mean_precision_m: 0.9808 - decoded_mean_recall_m: 0.8783 - pred_acc: 0.7650 - pred_f1_m: 0.6271 - pred_precision_m: 0.6664 - pred_recall_m: 0.5925
# Epoch 00042: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 76s 189ms/sample - loss: 0.4835 - decoded_mean_loss: 0.0106 - pred_loss: 0.4729 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9267 - decoded_mean_precision_m: 0.9808 - decoded_mean_recall_m: 0.8783 - pred_acc: 0.7650 - pred_f1_m: 0.6271 - pred_precision_m: 0.6664 - pred_recall_m: 0.5925 - val_loss: 0.5435 - val_decoded_mean_loss: 0.0104 - val_pred_loss: 0.5220 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9265 - val_decoded_mean_precision_m: 0.9786 - val_decoded_mean_recall_m: 0.8797 - val_pred_acc: 0.7200 - val_pred_f1_m: 0.5623 - val_pred_precision_m: 0.5990 - val_pred_recall_m: 0.5300
# Epoch 43/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4798 - decoded_mean_loss: 0.0111 - pred_loss: 0.4687 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9280 - decoded_mean_precision_m: 0.9786 - decoded_mean_recall_m: 0.8824 - pred_acc: 0.7833 - pred_f1_m: 0.6596 - pred_precision_m: 0.6960 - pred_recall_m: 0.6275
# Epoch 00043: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 75s 187ms/sample - loss: 0.4798 - decoded_mean_loss: 0.0111 - pred_loss: 0.4687 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9280 - decoded_mean_precision_m: 0.9786 - decoded_mean_recall_m: 0.8824 - pred_acc: 0.7833 - pred_f1_m: 0.6596 - pred_precision_m: 0.6960 - pred_recall_m: 0.6275 - val_loss: 0.5429 - val_decoded_mean_loss: 0.0114 - val_pred_loss: 0.5305 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9271 - val_decoded_mean_precision_m: 0.9769 - val_decoded_mean_recall_m: 0.8821 - val_pred_acc: 0.6987 - val_pred_f1_m: 0.5165 - val_pred_precision_m: 0.5419 - val_pred_recall_m: 0.4933
# Epoch 44/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4685 - decoded_mean_loss: 0.0120 - pred_loss: 0.4565 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9296 - decoded_mean_precision_m: 0.9783 - decoded_mean_recall_m: 0.8856 - pred_acc: 0.7692 - pred_f1_m: 0.6428 - pred_precision_m: 0.6646 - pred_recall_m: 0.6225
# Epoch 00044: val_pred_acc did not improve from 0.73733
# 400/400 [==============================] - 75s 187ms/sample - loss: 0.4685 - decoded_mean_loss: 0.0120 - pred_loss: 0.4565 - decoded_mean_acc: 0.9318 - decoded_mean_f1_m: 0.9296 - decoded_mean_precision_m: 0.9783 - decoded_mean_recall_m: 0.8856 - pred_acc: 0.7692 - pred_f1_m: 0.6428 - pred_precision_m: 0.6646 - pred_recall_m: 0.6225 - val_loss: 0.5483 - val_decoded_mean_loss: 0.0118 - val_pred_loss: 0.5414 - val_decoded_mean_acc: 0.9301 - val_decoded_mean_f1_m: 0.9294 - val_decoded_mean_precision_m: 0.9779 - val_decoded_mean_recall_m: 0.8855 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.5054 - val_pred_precision_m: 0.5260 - val_pred_recall_m: 0.4867
# Epoch 00044: early stopping

# %%
autoencoder.evaluate(x=X_test, y={'decoded_mean': Conversion_X_test, 'pred': y_test})
# Out:
# [0.5904012184143066,
#  0.011171671,
#  0.580675,
#  0.93136,
#  0.9289369,
#  0.97533906,
#  0.8867549,
#  0.7,
#  0.5377101,
#  0.5529651,
#  0.5234375]

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()


plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# # Test 2:
# avec une couche cache avec 500 Neurones

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/Models_a_ameliorer'
MODEL_FILE_NAME = 'Test_2.h5'
LR=0.0001

batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500

encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)
def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(500, return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Dense(300, activation='relu', name='dense_1')(h)
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])

    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    
    return (fct_loss, z)
     
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()
def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)

encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()
def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h =Bidirectional(LSTM(500, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 

autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_2 (Embedding)        (None, 100, 100)     2281400     ['input_4[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 100, 1000)   2404000     ['embedding_2[0][0]']
#  )
#
#  attention_couche_2 (AttentionC  (None, 1000)        1100        ['bidirectional_2[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          300300      ['attention_couche_2[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 5,107,200
# Trainable params: 5,107,200
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 200)]             0
#
#  dense_4 (Dense)             (None, 100)               20100
#
#  pred (Dense)                (None, 3)                 303
#
# =================================================================
# Total params: 20,403
# Trainable params: 20,403
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 200)]             0
#
#  repeat_vector_5 (RepeatVect  (None, 100, 200)         0
#  or)
#
#  bidirectional_3 (Bidirectio  (None, 100, 1000)        2804000
#  nal)
#
#  decoded_mean (TimeDistribut  (None, 100, 22814)       22836814
#  ed)
#
# =================================================================
# Total params: 25,640,814
# Trainable params: 25,640,814
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_2 (Embedding)        (None, 100, 100)     2281400     ['input_4[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 100, 1000)   2404000     ['embedding_2[0][0]']
#  )
#
#  attention_couche_2 (AttentionC  (None, 1000)        1100        ['bidirectional_2[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          300300      ['attention_couche_2[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  repeat_vector_6 (RepeatVector)  (None, 100, 200)    0           ['z[0][0]']
#
#  bidirectional_4 (Bidirectional  (None, 100, 1000)   2804000     ['repeat_vector_6[0][0]']
#  )
#
#  dense_7 (Dense)                (None, 100)          20100       ['z[0][0]']
#
#  decoded_mean (TimeDistributed)  (None, 100, 22814)  22836814    ['bidirectional_4[0][0]']
#
#  pred (Dense)                   (None, 3)            303         ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 30,768,417
# Trainable params: 30,768,417
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])
# Out:
# Train on 400 samples, validate on 250 samples
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7354 - decoded_mean_loss: 0.0484 - pred_loss: 0.6870 - decoded_mean_acc: 0.0046 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 00001: val_pred_acc improved from -inf to 0.66667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_2.h5
# 400/400 [==============================] - 126s 314ms/sample - loss: 0.7354 - decoded_mean_loss: 0.0484 - pred_loss: 0.6870 - decoded_mean_acc: 0.0046 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7291 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6806 - val_decoded_mean_acc: 0.0851 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7232 - decoded_mean_loss: 0.0484 - pred_loss: 0.6748 - decoded_mean_acc: 0.3592 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00002: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 109s 274ms/sample - loss: 0.7232 - decoded_mean_loss: 0.0484 - pred_loss: 0.6748 - decoded_mean_acc: 0.3592 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7138 - val_decoded_mean_loss: 0.0485 - val_pred_loss: 0.6646 - val_decoded_mean_acc: 0.9283 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7045 - decoded_mean_loss: 0.0486 - pred_loss: 0.6559 - decoded_mean_acc: 0.9211 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6658 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00003: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 110s 275ms/sample - loss: 0.7045 - decoded_mean_loss: 0.0486 - pred_loss: 0.6559 - decoded_mean_acc: 0.9211 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6658 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.6930 - val_decoded_mean_loss: 0.0488 - val_pred_loss: 0.6437 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6627 - val_pred_f1_m: 0.0129 - val_pred_precision_m: 0.2500 - val_pred_recall_m: 0.0067
# Epoch 4/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6794 - decoded_mean_loss: 0.0490 - pred_loss: 0.6303 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.0883 - pred_precision_m: 0.6446 - pred_recall_m: 0.0500
# Epoch 00004: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 110s 276ms/sample - loss: 0.6794 - decoded_mean_loss: 0.0490 - pred_loss: 0.6303 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.0883 - pred_precision_m: 0.6446 - pred_recall_m: 0.0500 - val_loss: 0.6689 - val_decoded_mean_loss: 0.0497 - val_pred_loss: 0.6163 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6467 - val_pred_f1_m: 0.2328 - val_pred_precision_m: 0.4362 - val_pred_recall_m: 0.1600
# Epoch 5/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6504 - decoded_mean_loss: 0.0506 - pred_loss: 0.5998 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.3426 - pred_precision_m: 0.5025 - pred_recall_m: 0.2700
# Epoch 00005: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 110s 275ms/sample - loss: 0.6504 - decoded_mean_loss: 0.0506 - pred_loss: 0.5998 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.3426 - pred_precision_m: 0.5025 - pred_recall_m: 0.2700 - val_loss: 0.6569 - val_decoded_mean_loss: 0.0535 - val_pred_loss: 0.6062 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6600 - val_pred_f1_m: 0.4504 - val_pred_precision_m: 0.4770 - val_pred_recall_m: 0.4267
# Epoch 6/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6436 - decoded_mean_loss: 0.0549 - pred_loss: 0.5887 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6775 - pred_f1_m: 0.4970 - pred_precision_m: 0.5197 - pred_recall_m: 0.4775
# Epoch 00006: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 124s 310ms/sample - loss: 0.6436 - decoded_mean_loss: 0.0549 - pred_loss: 0.5887 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6775 - pred_f1_m: 0.4970 - pred_precision_m: 0.5197 - pred_recall_m: 0.4775 - val_loss: 0.6647 - val_decoded_mean_loss: 0.0559 - val_pred_loss: 0.5972 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6587 - val_pred_f1_m: 0.4945 - val_pred_precision_m: 0.5061 - val_pred_recall_m: 0.4833
# Epoch 7/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6409 - decoded_mean_loss: 0.0538 - pred_loss: 0.5871 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6750 - pred_f1_m: 0.4854 - pred_precision_m: 0.5141 - pred_recall_m: 0.4600
# Epoch 00007: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 114s 284ms/sample - loss: 0.6409 - decoded_mean_loss: 0.0538 - pred_loss: 0.5871 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6750 - pred_f1_m: 0.4854 - pred_precision_m: 0.5141 - pred_recall_m: 0.4600 - val_loss: 0.6490 - val_decoded_mean_loss: 0.0516 - val_pred_loss: 0.5944 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6573 - val_pred_f1_m: 0.4487 - val_pred_precision_m: 0.4907 - val_pred_recall_m: 0.4133
# Epoch 8/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6328 - decoded_mean_loss: 0.0505 - pred_loss: 0.5823 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.4430 - pred_precision_m: 0.5147 - pred_recall_m: 0.3900
# Epoch 00008: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 112s 280ms/sample - loss: 0.6328 - decoded_mean_loss: 0.0505 - pred_loss: 0.5823 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.4430 - pred_precision_m: 0.5147 - pred_recall_m: 0.3900 - val_loss: 0.6443 - val_decoded_mean_loss: 0.0491 - val_pred_loss: 0.5933 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6547 - val_pred_f1_m: 0.4263 - val_pred_precision_m: 0.4968 - val_pred_recall_m: 0.3733
# Epoch 9/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6288 - decoded_mean_loss: 0.0479 - pred_loss: 0.5809 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6808 - pred_f1_m: 0.4502 - pred_precision_m: 0.5285 - pred_recall_m: 0.3925
# Epoch 00009: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 112s 281ms/sample - loss: 0.6288 - decoded_mean_loss: 0.0479 - pred_loss: 0.5809 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6808 - pred_f1_m: 0.4502 - pred_precision_m: 0.5285 - pred_recall_m: 0.3925 - val_loss: 0.6401 - val_decoded_mean_loss: 0.0457 - val_pred_loss: 0.5935 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6573 - val_pred_f1_m: 0.4081 - val_pred_precision_m: 0.4714 - val_pred_recall_m: 0.3600
# Epoch 10/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6217 - decoded_mean_loss: 0.0439 - pred_loss: 0.5777 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6783 - pred_f1_m: 0.4631 - pred_precision_m: 0.5207 - pred_recall_m: 0.4175
# Epoch 00010: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 116s 289ms/sample - loss: 0.6217 - decoded_mean_loss: 0.0439 - pred_loss: 0.5777 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6783 - pred_f1_m: 0.4631 - pred_precision_m: 0.5207 - pred_recall_m: 0.4175 - val_loss: 0.6330 - val_decoded_mean_loss: 0.0412 - val_pred_loss: 0.5921 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6560 - val_pred_f1_m: 0.4453 - val_pred_precision_m: 0.4827 - val_pred_recall_m: 0.4133
# Epoch 11/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6167 - decoded_mean_loss: 0.0393 - pred_loss: 0.5773 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6750 - pred_f1_m: 0.4814 - pred_precision_m: 0.5151 - pred_recall_m: 0.4525
# Epoch 00011: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 122s 305ms/sample - loss: 0.6167 - decoded_mean_loss: 0.0393 - pred_loss: 0.5773 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6750 - pred_f1_m: 0.4814 - pred_precision_m: 0.5151 - pred_recall_m: 0.4525 - val_loss: 0.6293 - val_decoded_mean_loss: 0.0369 - val_pred_loss: 0.5963 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6613 - val_pred_f1_m: 0.4873 - val_pred_precision_m: 0.4948 - val_pred_recall_m: 0.4800
# Epoch 12/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6083 - decoded_mean_loss: 0.0350 - pred_loss: 0.5734 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6742 - pred_f1_m: 0.5055 - pred_precision_m: 0.5112 - pred_recall_m: 0.5000
# Epoch 00012: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 113s 282ms/sample - loss: 0.6083 - decoded_mean_loss: 0.0350 - pred_loss: 0.5734 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6742 - pred_f1_m: 0.5055 - pred_precision_m: 0.5112 - pred_recall_m: 0.5000 - val_loss: 0.6231 - val_decoded_mean_loss: 0.0322 - val_pred_loss: 0.5905 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6587 - val_pred_f1_m: 0.4898 - val_pred_precision_m: 0.4931 - val_pred_recall_m: 0.4867
# Epoch 13/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6006 - decoded_mean_loss: 0.0301 - pred_loss: 0.5705 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.5081 - pred_precision_m: 0.5139 - pred_recall_m: 0.5025
# Epoch 00013: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 113s 282ms/sample - loss: 0.6006 - decoded_mean_loss: 0.0301 - pred_loss: 0.5705 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.5081 - pred_precision_m: 0.5139 - pred_recall_m: 0.5025 - val_loss: 0.6141 - val_decoded_mean_loss: 0.0271 - val_pred_loss: 0.5865 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6613 - val_pred_f1_m: 0.4728 - val_pred_precision_m: 0.4828 - val_pred_recall_m: 0.4633
# Epoch 14/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5942 - decoded_mean_loss: 0.0249 - pred_loss: 0.5693 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6783 - pred_f1_m: 0.5042 - pred_precision_m: 0.5193 - pred_recall_m: 0.4900
# Epoch 00014: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 112s 280ms/sample - loss: 0.5942 - decoded_mean_loss: 0.0249 - pred_loss: 0.5693 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6783 - pred_f1_m: 0.5042 - pred_precision_m: 0.5193 - pred_recall_m: 0.4900 - val_loss: 0.6065 - val_decoded_mean_loss: 0.0221 - val_pred_loss: 0.5861 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6627 - val_pred_f1_m: 0.4794 - val_pred_precision_m: 0.4929 - val_pred_recall_m: 0.4667
# Epoch 15/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5850 - decoded_mean_loss: 0.0201 - pred_loss: 0.5649 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6800 - pred_f1_m: 0.5012 - pred_precision_m: 0.5216 - pred_recall_m: 0.4825
# Epoch 00015: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 113s 281ms/sample - loss: 0.5850 - decoded_mean_loss: 0.0201 - pred_loss: 0.5649 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6800 - pred_f1_m: 0.5012 - pred_precision_m: 0.5216 - pred_recall_m: 0.4825 - val_loss: 0.5981 - val_decoded_mean_loss: 0.0176 - val_pred_loss: 0.5761 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.4903 - val_pred_precision_m: 0.5050 - val_pred_recall_m: 0.4767
# Epoch 16/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5750 - decoded_mean_loss: 0.0158 - pred_loss: 0.5592 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6842 - pred_f1_m: 0.5106 - pred_precision_m: 0.5274 - pred_recall_m: 0.4950
# Epoch 00016: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 111s 278ms/sample - loss: 0.5750 - decoded_mean_loss: 0.0158 - pred_loss: 0.5592 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6842 - pred_f1_m: 0.5106 - pred_precision_m: 0.5274 - pred_recall_m: 0.4950 - val_loss: 0.5907 - val_decoded_mean_loss: 0.0138 - val_pred_loss: 0.5747 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.8702 - val_decoded_mean_precision_m: 0.9977 - val_decoded_mean_recall_m: 0.7717 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.5059 - val_pred_precision_m: 0.5156 - val_pred_recall_m: 0.4967
# Epoch 17/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5676 - decoded_mean_loss: 0.0126 - pred_loss: 0.5550 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.8891 - decoded_mean_precision_m: 0.9949 - decoded_mean_recall_m: 0.8038 - pred_acc: 0.6825 - pred_f1_m: 0.5191 - pred_precision_m: 0.5261 - pred_recall_m: 0.5125
# Epoch 00017: val_pred_acc improved from 0.66667 to 0.68000, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_2.h5
# 400/400 [==============================] - 127s 316ms/sample - loss: 0.5676 - decoded_mean_loss: 0.0126 - pred_loss: 0.5550 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.8891 - decoded_mean_precision_m: 0.9949 - decoded_mean_recall_m: 0.8038 - pred_acc: 0.6825 - pred_f1_m: 0.5191 - pred_precision_m: 0.5261 - pred_recall_m: 0.5125 - val_loss: 0.5841 - val_decoded_mean_loss: 0.0113 - val_pred_loss: 0.5682 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9054 - val_decoded_mean_precision_m: 0.9903 - val_decoded_mean_recall_m: 0.8339 - val_pred_acc: 0.6800 - val_pred_f1_m: 0.5149 - val_pred_precision_m: 0.5270 - val_pred_recall_m: 0.5033
# Epoch 18/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5599 - decoded_mean_loss: 0.0103 - pred_loss: 0.5496 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9075 - decoded_mean_precision_m: 0.9893 - decoded_mean_recall_m: 0.8383 - pred_acc: 0.7117 - pred_f1_m: 0.5461 - pred_precision_m: 0.5753 - pred_recall_m: 0.5200
# Epoch 00018: val_pred_acc improved from 0.68000 to 0.71467, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_2.h5
# 400/400 [==============================] - 117s 293ms/sample - loss: 0.5599 - decoded_mean_loss: 0.0103 - pred_loss: 0.5496 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9075 - decoded_mean_precision_m: 0.9893 - decoded_mean_recall_m: 0.8383 - pred_acc: 0.7117 - pred_f1_m: 0.5461 - pred_precision_m: 0.5753 - pred_recall_m: 0.5200 - val_loss: 0.5739 - val_decoded_mean_loss: 0.0099 - val_pred_loss: 0.5636 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9119 - val_decoded_mean_precision_m: 0.9855 - val_decoded_mean_recall_m: 0.8485 - val_pred_acc: 0.7147 - val_pred_f1_m: 0.5386 - val_pred_precision_m: 0.5751 - val_pred_recall_m: 0.5067
# Epoch 19/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5511 - decoded_mean_loss: 0.0096 - pred_loss: 0.5416 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9144 - decoded_mean_precision_m: 0.9857 - decoded_mean_recall_m: 0.8527 - pred_acc: 0.7158 - pred_f1_m: 0.5544 - pred_precision_m: 0.5813 - pred_recall_m: 0.5300
# Epoch 00019: val_pred_acc did not improve from 0.71467
# 400/400 [==============================] - 111s 277ms/sample - loss: 0.5511 - decoded_mean_loss: 0.0096 - pred_loss: 0.5416 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9144 - decoded_mean_precision_m: 0.9857 - decoded_mean_recall_m: 0.8527 - pred_acc: 0.7158 - pred_f1_m: 0.5544 - pred_precision_m: 0.5813 - pred_recall_m: 0.5300 - val_loss: 0.5710 - val_decoded_mean_loss: 0.0101 - val_pred_loss: 0.5598 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9164 - val_decoded_mean_precision_m: 0.9804 - val_decoded_mean_recall_m: 0.8602 - val_pred_acc: 0.7013 - val_pred_f1_m: 0.5498 - val_pred_precision_m: 0.5637 - val_pred_recall_m: 0.5367
# Epoch 20/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5346 - decoded_mean_loss: 0.0103 - pred_loss: 0.5243 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9189 - decoded_mean_precision_m: 0.9820 - decoded_mean_recall_m: 0.8635 - pred_acc: 0.7300 - pred_f1_m: 0.5771 - pred_precision_m: 0.6042 - pred_recall_m: 0.5525
# Epoch 00020: val_pred_acc did not improve from 0.71467
# 400/400 [==============================] - 110s 275ms/sample - loss: 0.5346 - decoded_mean_loss: 0.0103 - pred_loss: 0.5243 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9189 - decoded_mean_precision_m: 0.9820 - decoded_mean_recall_m: 0.8635 - pred_acc: 0.7300 - pred_f1_m: 0.5771 - pred_precision_m: 0.6042 - pred_recall_m: 0.5525 - val_loss: 0.5653 - val_decoded_mean_loss: 0.0120 - val_pred_loss: 0.5579 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9199 - val_decoded_mean_precision_m: 0.9786 - val_decoded_mean_recall_m: 0.8679 - val_pred_acc: 0.7147 - val_pred_f1_m: 0.5551 - val_pred_precision_m: 0.5710 - val_pred_recall_m: 0.5400
# Epoch 21/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5253 - decoded_mean_loss: 0.0121 - pred_loss: 0.5132 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9215 - decoded_mean_precision_m: 0.9789 - decoded_mean_recall_m: 0.8705 - pred_acc: 0.7308 - pred_f1_m: 0.5852 - pred_precision_m: 0.6013 - pred_recall_m: 0.5700
# Epoch 00021: val_pred_acc improved from 0.71467 to 0.72000, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_2.h5
# 400/400 [==============================] - 116s 290ms/sample - loss: 0.5253 - decoded_mean_loss: 0.0121 - pred_loss: 0.5132 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9215 - decoded_mean_precision_m: 0.9789 - decoded_mean_recall_m: 0.8705 - pred_acc: 0.7308 - pred_f1_m: 0.5852 - pred_precision_m: 0.6013 - pred_recall_m: 0.5700 - val_loss: 0.5701 - val_decoded_mean_loss: 0.0122 - val_pred_loss: 0.5531 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9201 - val_decoded_mean_precision_m: 0.9756 - val_decoded_mean_recall_m: 0.8705 - val_pred_acc: 0.7200 - val_pred_f1_m: 0.5709 - val_pred_precision_m: 0.5979 - val_pred_recall_m: 0.5467
# Epoch 22/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5083 - decoded_mean_loss: 0.0119 - pred_loss: 0.4964 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9226 - decoded_mean_precision_m: 0.9789 - decoded_mean_recall_m: 0.8723 - pred_acc: 0.7542 - pred_f1_m: 0.6157 - pred_precision_m: 0.6438 - pred_recall_m: 0.5900
# Epoch 00022: val_pred_acc did not improve from 0.72000
# 400/400 [==============================] - 123s 307ms/sample - loss: 0.5083 - decoded_mean_loss: 0.0119 - pred_loss: 0.4964 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9226 - decoded_mean_precision_m: 0.9789 - decoded_mean_recall_m: 0.8723 - pred_acc: 0.7542 - pred_f1_m: 0.6157 - pred_precision_m: 0.6438 - pred_recall_m: 0.5900 - val_loss: 0.5703 - val_decoded_mean_loss: 0.0112 - val_pred_loss: 0.5583 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9209 - val_decoded_mean_precision_m: 0.9750 - val_decoded_mean_recall_m: 0.8724 - val_pred_acc: 0.7173 - val_pred_f1_m: 0.5699 - val_pred_precision_m: 0.5912 - val_pred_recall_m: 0.5500
# Epoch 23/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5163 - decoded_mean_loss: 0.0108 - pred_loss: 0.5055 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9233 - decoded_mean_precision_m: 0.9775 - decoded_mean_recall_m: 0.8748 - pred_acc: 0.7458 - pred_f1_m: 0.6033 - pred_precision_m: 0.6288 - pred_recall_m: 0.5800
# Epoch 00023: val_pred_acc improved from 0.72000 to 0.72533, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_2.h5
# 400/400 [==============================] - 118s 296ms/sample - loss: 0.5163 - decoded_mean_loss: 0.0108 - pred_loss: 0.5055 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9233 - decoded_mean_precision_m: 0.9775 - decoded_mean_recall_m: 0.8748 - pred_acc: 0.7458 - pred_f1_m: 0.6033 - pred_precision_m: 0.6288 - pred_recall_m: 0.5800 - val_loss: 0.5697 - val_decoded_mean_loss: 0.0109 - val_pred_loss: 0.5498 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9217 - val_decoded_mean_precision_m: 0.9744 - val_decoded_mean_recall_m: 0.8744 - val_pred_acc: 0.7253 - val_pred_f1_m: 0.5856 - val_pred_precision_m: 0.6061 - val_pred_recall_m: 0.5667
# Epoch 24/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5010 - decoded_mean_loss: 0.0107 - pred_loss: 0.4902 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9243 - decoded_mean_precision_m: 0.9773 - decoded_mean_recall_m: 0.8769 - pred_acc: 0.7542 - pred_f1_m: 0.6157 - pred_precision_m: 0.6440 - pred_recall_m: 0.5900
# Epoch 00024: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 114s 286ms/sample - loss: 0.5010 - decoded_mean_loss: 0.0107 - pred_loss: 0.4902 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9243 - decoded_mean_precision_m: 0.9773 - decoded_mean_recall_m: 0.8769 - pred_acc: 0.7542 - pred_f1_m: 0.6157 - pred_precision_m: 0.6440 - pred_recall_m: 0.5900 - val_loss: 0.5717 - val_decoded_mean_loss: 0.0114 - val_pred_loss: 0.5621 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9231 - val_decoded_mean_precision_m: 0.9735 - val_decoded_mean_recall_m: 0.8776 - val_pred_acc: 0.7147 - val_pred_f1_m: 0.5511 - val_pred_precision_m: 0.5740 - val_pred_recall_m: 0.5300
# Epoch 25/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5125 - decoded_mean_loss: 0.0116 - pred_loss: 0.5009 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9257 - decoded_mean_precision_m: 0.9761 - decoded_mean_recall_m: 0.8803 - pred_acc: 0.7508 - pred_f1_m: 0.6098 - pred_precision_m: 0.6403 - pred_recall_m: 0.5825
# Epoch 00025: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 114s 285ms/sample - loss: 0.5125 - decoded_mean_loss: 0.0116 - pred_loss: 0.5009 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9257 - decoded_mean_precision_m: 0.9761 - decoded_mean_recall_m: 0.8803 - pred_acc: 0.7508 - pred_f1_m: 0.6098 - pred_precision_m: 0.6403 - pred_recall_m: 0.5825 - val_loss: 0.5759 - val_decoded_mean_loss: 0.0117 - val_pred_loss: 0.5608 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9242 - val_decoded_mean_precision_m: 0.9734 - val_decoded_mean_recall_m: 0.8798 - val_pred_acc: 0.7200 - val_pred_f1_m: 0.5598 - val_pred_precision_m: 0.5814 - val_pred_recall_m: 0.5400
# Epoch 26/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4946 - decoded_mean_loss: 0.0117 - pred_loss: 0.4829 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9266 - decoded_mean_precision_m: 0.9772 - decoded_mean_recall_m: 0.8810 - pred_acc: 0.7675 - pred_f1_m: 0.6365 - pred_precision_m: 0.6655 - pred_recall_m: 0.6100
# Epoch 00026: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 114s 286ms/sample - loss: 0.4946 - decoded_mean_loss: 0.0117 - pred_loss: 0.4829 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9266 - decoded_mean_precision_m: 0.9772 - decoded_mean_recall_m: 0.8810 - pred_acc: 0.7675 - pred_f1_m: 0.6365 - pred_precision_m: 0.6655 - pred_recall_m: 0.6100 - val_loss: 0.5758 - val_decoded_mean_loss: 0.0125 - val_pred_loss: 0.5559 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9253 - val_decoded_mean_precision_m: 0.9744 - val_decoded_mean_recall_m: 0.8809 - val_pred_acc: 0.7147 - val_pred_f1_m: 0.5750 - val_pred_precision_m: 0.5947 - val_pred_recall_m: 0.5567
# Epoch 27/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4972 - decoded_mean_loss: 0.0119 - pred_loss: 0.4853 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9268 - decoded_mean_precision_m: 0.9770 - decoded_mean_recall_m: 0.8816 - pred_acc: 0.7650 - pred_f1_m: 0.6301 - pred_precision_m: 0.6638 - pred_recall_m: 0.6000
# Epoch 00027: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 124s 311ms/sample - loss: 0.4972 - decoded_mean_loss: 0.0119 - pred_loss: 0.4853 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9268 - decoded_mean_precision_m: 0.9770 - decoded_mean_recall_m: 0.8816 - pred_acc: 0.7650 - pred_f1_m: 0.6301 - pred_precision_m: 0.6638 - pred_recall_m: 0.6000 - val_loss: 0.5827 - val_decoded_mean_loss: 0.0117 - val_pred_loss: 0.5651 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9257 - val_decoded_mean_precision_m: 0.9749 - val_decoded_mean_recall_m: 0.8812 - val_pred_acc: 0.7027 - val_pred_f1_m: 0.5455 - val_pred_precision_m: 0.5743 - val_pred_recall_m: 0.5200
# Epoch 28/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4821 - decoded_mean_loss: 0.0115 - pred_loss: 0.4706 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9276 - decoded_mean_precision_m: 0.9774 - decoded_mean_recall_m: 0.8826 - pred_acc: 0.7658 - pred_f1_m: 0.6338 - pred_precision_m: 0.6633 - pred_recall_m: 0.6075
# Epoch 00028: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 112s 281ms/sample - loss: 0.4821 - decoded_mean_loss: 0.0115 - pred_loss: 0.4706 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9276 - decoded_mean_precision_m: 0.9774 - decoded_mean_recall_m: 0.8826 - pred_acc: 0.7658 - pred_f1_m: 0.6338 - pred_precision_m: 0.6633 - pred_recall_m: 0.6075 - val_loss: 0.5802 - val_decoded_mean_loss: 0.0123 - val_pred_loss: 0.5743 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9269 - val_decoded_mean_precision_m: 0.9755 - val_decoded_mean_recall_m: 0.8829 - val_pred_acc: 0.7067 - val_pred_f1_m: 0.5341 - val_pred_precision_m: 0.5616 - val_pred_recall_m: 0.5100
# Epoch 29/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4755 - decoded_mean_loss: 0.0120 - pred_loss: 0.4635 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9287 - decoded_mean_precision_m: 0.9778 - decoded_mean_recall_m: 0.8842 - pred_acc: 0.7725 - pred_f1_m: 0.6433 - pred_precision_m: 0.6743 - pred_recall_m: 0.6150
# Epoch 00029: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 114s 285ms/sample - loss: 0.4755 - decoded_mean_loss: 0.0120 - pred_loss: 0.4635 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9287 - decoded_mean_precision_m: 0.9778 - decoded_mean_recall_m: 0.8842 - pred_acc: 0.7725 - pred_f1_m: 0.6433 - pred_precision_m: 0.6743 - pred_recall_m: 0.6150 - val_loss: 0.5964 - val_decoded_mean_loss: 0.0126 - val_pred_loss: 0.5681 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9271 - val_decoded_mean_precision_m: 0.9753 - val_decoded_mean_recall_m: 0.8834 - val_pred_acc: 0.7120 - val_pred_f1_m: 0.5575 - val_pred_precision_m: 0.5845 - val_pred_recall_m: 0.5333
# Epoch 30/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4816 - decoded_mean_loss: 0.0124 - pred_loss: 0.4692 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9288 - decoded_mean_precision_m: 0.9785 - decoded_mean_recall_m: 0.8839 - pred_acc: 0.7583 - pred_f1_m: 0.6216 - pred_precision_m: 0.6509 - pred_recall_m: 0.5950
# Epoch 00030: val_pred_acc did not improve from 0.72533
# 400/400 [==============================] - 113s 283ms/sample - loss: 0.4816 - decoded_mean_loss: 0.0124 - pred_loss: 0.4692 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9288 - decoded_mean_precision_m: 0.9785 - decoded_mean_recall_m: 0.8839 - pred_acc: 0.7583 - pred_f1_m: 0.6216 - pred_precision_m: 0.6509 - pred_recall_m: 0.5950 - val_loss: 0.5921 - val_decoded_mean_loss: 0.0129 - val_pred_loss: 0.5682 - val_decoded_mean_acc: 0.9291 - val_decoded_mean_f1_m: 0.9261 - val_decoded_mean_precision_m: 0.9785 - val_decoded_mean_recall_m: 0.8791 - val_pred_acc: 0.7120 - val_pred_f1_m: 0.5601 - val_pred_precision_m: 0.5859 - val_pred_recall_m: 0.5367
# Epoch 00030: early stopping

# %%
autoencoder.evaluate(x=X_test, y={'decoded_mean': Conversion_X_test, 'pred': y_test})
# Out:
# [0.5920356988906861,
#  0.01316102,
#  0.5780112,
#  0.92912,
#  0.9259091,
#  0.97752154,
#  0.8794862,
#  0.71333337,
#  0.54712224,
#  0.57369125,
#  0.5234375]

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# # **Test_3**:
#  Une couche avec 750 Neurones

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/Models_a_ameliorer'
MODEL_FILE_NAME = 'Test_3.h5'
LR=0.0001

batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500

encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)
def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(750, return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Dense(300, activation='relu', name='dense_1')(h)
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])

    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    
    return (fct_loss, z)
     
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()
def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)

encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()
def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h =Bidirectional(LSTM(750, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 

autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/initializers/initializers_v1.py:278: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/initializers/initializers_v1.py:160: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  embedding (Embedding)          (None, 100, 100)     2281400     ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 100, 1500)    5106000     ['embedding[0][0]']
#
#  attention_couche (AttentionCou  (None, 1500)        1600        ['bidirectional[0][0]']
#  che)
#
#  dense_1 (Dense)                (None, 300)          450300      ['attention_couche[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 7,959,700
# Trainable params: 7,959,700
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  dense (Dense)               (None, 100)               20100
#
#  pred (Dense)                (None, 3)                 303
#
# =================================================================
# Total params: 20,403
# Trainable params: 20,403
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  repeat_vector_1 (RepeatVect  (None, 100, 200)         0
#  or)
#
#  bidirectional_1 (Bidirectio  (None, 100, 1500)        5706000
#  nal)
#
#  decoded_mean (TimeDistribut  (None, 100, 22814)       34243814
#  ed)
#
# =================================================================
# Total params: 39,949,814
# Trainable params: 39,949,814
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  embedding (Embedding)          (None, 100, 100)     2281400     ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 100, 1500)    5106000     ['embedding[0][0]']
#
#  attention_couche (AttentionCou  (None, 1500)        1600        ['bidirectional[0][0]']
#  che)
#
#  dense_1 (Dense)                (None, 300)          450300      ['attention_couche[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  repeat_vector_2 (RepeatVector)  (None, 100, 200)    0           ['z[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 100, 1500)   5706000     ['repeat_vector_2[0][0]']
#  )
#
#  dense_3 (Dense)                (None, 100)          20100       ['z[0][0]']
#
#  decoded_mean (TimeDistributed)  (None, 100, 22814)  34243814    ['bidirectional_2[0][0]']
#
#  pred (Dense)                   (None, 3)            303         ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 47,929,917
# Trainable params: 47,929,917
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])
# Out:
# Train on 400 samples, validate on 250 samples
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7366 - decoded_mean_loss: 0.0484 - pred_loss: 0.6883 - decoded_mean_acc: 0.0315 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 00001: val_pred_acc improved from -inf to 0.66667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 158s 396ms/sample - loss: 0.7366 - decoded_mean_loss: 0.0484 - pred_loss: 0.6883 - decoded_mean_acc: 0.0315 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7267 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6784 - val_decoded_mean_acc: 0.5808 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7206 - decoded_mean_loss: 0.0484 - pred_loss: 0.6722 - decoded_mean_acc: 0.7023 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00002: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 151s 379ms/sample - loss: 0.7206 - decoded_mean_loss: 0.0484 - pred_loss: 0.6722 - decoded_mean_acc: 0.7023 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7053 - val_decoded_mean_loss: 0.0485 - val_pred_loss: 0.6559 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6987 - decoded_mean_loss: 0.0487 - pred_loss: 0.6501 - decoded_mean_acc: 0.9316 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6617 - pred_f1_m: 0.0185 - pred_precision_m: 0.1583 - pred_recall_m: 0.0100
# Epoch 00003: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 153s 382ms/sample - loss: 0.6987 - decoded_mean_loss: 0.0487 - pred_loss: 0.6501 - decoded_mean_acc: 0.9316 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6617 - pred_f1_m: 0.0185 - pred_precision_m: 0.1583 - pred_recall_m: 0.0100 - val_loss: 0.6719 - val_decoded_mean_loss: 0.0491 - val_pred_loss: 0.6240 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.1940 - val_pred_precision_m: 0.5094 - val_pred_recall_m: 0.1200
# Epoch 4/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6677 - decoded_mean_loss: 0.0502 - pred_loss: 0.6175 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6733 - pred_f1_m: 0.3164 - pred_precision_m: 0.5036 - pred_recall_m: 0.2500
# Epoch 00004: val_pred_acc improved from 0.66667 to 0.68000, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 176s 439ms/sample - loss: 0.6677 - decoded_mean_loss: 0.0502 - pred_loss: 0.6175 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6733 - pred_f1_m: 0.3164 - pred_precision_m: 0.5036 - pred_recall_m: 0.2500 - val_loss: 0.6462 - val_decoded_mean_loss: 0.0536 - val_pred_loss: 0.5895 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6800 - val_pred_f1_m: 0.5089 - val_pred_precision_m: 0.5257 - val_pred_recall_m: 0.4933
# Epoch 5/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6723 - decoded_mean_loss: 0.0542 - pred_loss: 0.6181 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.4936 - pred_precision_m: 0.5027 - pred_recall_m: 0.4850
# Epoch 00005: val_pred_acc improved from 0.68000 to 0.68133, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 169s 421ms/sample - loss: 0.6723 - decoded_mean_loss: 0.0542 - pred_loss: 0.6181 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6675 - pred_f1_m: 0.4936 - pred_precision_m: 0.5027 - pred_recall_m: 0.4850 - val_loss: 0.6391 - val_decoded_mean_loss: 0.0515 - val_pred_loss: 0.5867 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6813 - val_pred_f1_m: 0.5025 - val_pred_precision_m: 0.5241 - val_pred_recall_m: 0.4833
# Epoch 6/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6577 - decoded_mean_loss: 0.0504 - pred_loss: 0.6073 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.4520 - pred_precision_m: 0.4985 - pred_recall_m: 0.4150
# Epoch 00006: val_pred_acc improved from 0.68133 to 0.68667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 171s 427ms/sample - loss: 0.6577 - decoded_mean_loss: 0.0504 - pred_loss: 0.6073 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.4520 - pred_precision_m: 0.4985 - pred_recall_m: 0.4150 - val_loss: 0.6411 - val_decoded_mean_loss: 0.0489 - val_pred_loss: 0.5946 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6867 - val_pred_f1_m: 0.4425 - val_pred_precision_m: 0.5307 - val_pred_recall_m: 0.3800
# Epoch 7/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6559 - decoded_mean_loss: 0.0482 - pred_loss: 0.6077 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6717 - pred_f1_m: 0.3867 - pred_precision_m: 0.5145 - pred_recall_m: 0.3100
# Epoch 00007: val_pred_acc did not improve from 0.68667
# 400/400 [==============================] - 162s 404ms/sample - loss: 0.6559 - decoded_mean_loss: 0.0482 - pred_loss: 0.6077 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6717 - pred_f1_m: 0.3867 - pred_precision_m: 0.5145 - pred_recall_m: 0.3100 - val_loss: 0.6391 - val_decoded_mean_loss: 0.0468 - val_pred_loss: 0.5917 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6787 - val_pred_f1_m: 0.4024 - val_pred_precision_m: 0.5254 - val_pred_recall_m: 0.3267
# Epoch 8/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6490 - decoded_mean_loss: 0.0453 - pred_loss: 0.6038 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6792 - pred_f1_m: 0.4033 - pred_precision_m: 0.5336 - pred_recall_m: 0.3250
# Epoch 00008: val_pred_acc did not improve from 0.68667
# 400/400 [==============================] - 163s 408ms/sample - loss: 0.6490 - decoded_mean_loss: 0.0453 - pred_loss: 0.6038 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6792 - pred_f1_m: 0.4033 - pred_precision_m: 0.5336 - pred_recall_m: 0.3250 - val_loss: 0.6249 - val_decoded_mean_loss: 0.0415 - val_pred_loss: 0.5834 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6813 - val_pred_f1_m: 0.4500 - val_pred_precision_m: 0.5264 - val_pred_recall_m: 0.3933
# Epoch 9/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6382 - decoded_mean_loss: 0.0390 - pred_loss: 0.5993 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.4882 - pred_precision_m: 0.5186 - pred_recall_m: 0.4650
# Epoch 00009: val_pred_acc improved from 0.68667 to 0.69333, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 169s 423ms/sample - loss: 0.6382 - decoded_mean_loss: 0.0390 - pred_loss: 0.5993 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.4882 - pred_precision_m: 0.5186 - pred_recall_m: 0.4650 - val_loss: 0.6100 - val_decoded_mean_loss: 0.0344 - val_pred_loss: 0.5744 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6933 - val_pred_f1_m: 0.5467 - val_pred_precision_m: 0.5467 - val_pred_recall_m: 0.5467
# Epoch 10/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6281 - decoded_mean_loss: 0.0309 - pred_loss: 0.5972 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6717 - pred_f1_m: 0.5039 - pred_precision_m: 0.5079 - pred_recall_m: 0.5000
# Epoch 00010: val_pred_acc did not improve from 0.69333
# 400/400 [==============================] - 161s 403ms/sample - loss: 0.6281 - decoded_mean_loss: 0.0309 - pred_loss: 0.5972 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6717 - pred_f1_m: 0.5039 - pred_precision_m: 0.5079 - pred_recall_m: 0.5000 - val_loss: 0.6042 - val_decoded_mean_loss: 0.0256 - val_pred_loss: 0.5825 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6853 - val_pred_f1_m: 0.5003 - val_pred_precision_m: 0.5227 - val_pred_recall_m: 0.4800
# Epoch 11/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6172 - decoded_mean_loss: 0.0228 - pred_loss: 0.5944 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6742 - pred_f1_m: 0.4913 - pred_precision_m: 0.5117 - pred_recall_m: 0.4725
# Epoch 00011: val_pred_acc did not improve from 0.69333
# 400/400 [==============================] - 161s 403ms/sample - loss: 0.6172 - decoded_mean_loss: 0.0228 - pred_loss: 0.5944 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6742 - pred_f1_m: 0.4913 - pred_precision_m: 0.5117 - pred_recall_m: 0.4725 - val_loss: 0.5941 - val_decoded_mean_loss: 0.0182 - val_pred_loss: 0.5672 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6893 - val_pred_f1_m: 0.5352 - val_pred_precision_m: 0.5591 - val_pred_recall_m: 0.5133
# Epoch 12/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6067 - decoded_mean_loss: 0.0156 - pred_loss: 0.5911 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.1757 - decoded_mean_precision_m: 0.2500 - decoded_mean_recall_m: 0.1355 - pred_acc: 0.6758 - pred_f1_m: 0.5007 - pred_precision_m: 0.5148 - pred_recall_m: 0.4875
# Epoch 00012: val_pred_acc did not improve from 0.69333
# 400/400 [==============================] - 167s 416ms/sample - loss: 0.6067 - decoded_mean_loss: 0.0156 - pred_loss: 0.5911 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.1757 - decoded_mean_precision_m: 0.2500 - decoded_mean_recall_m: 0.1355 - pred_acc: 0.6758 - pred_f1_m: 0.5007 - pred_precision_m: 0.5148 - pred_recall_m: 0.4875 - val_loss: 0.5834 - val_decoded_mean_loss: 0.0119 - val_pred_loss: 0.5713 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.8621 - val_decoded_mean_precision_m: 0.9994 - val_decoded_mean_recall_m: 0.7580 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.5437 - val_pred_precision_m: 0.5474 - val_pred_recall_m: 0.5400
# Epoch 13/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5985 - decoded_mean_loss: 0.0107 - pred_loss: 0.5878 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.8849 - decoded_mean_precision_m: 0.9968 - decoded_mean_recall_m: 0.7960 - pred_acc: 0.6717 - pred_f1_m: 0.5063 - pred_precision_m: 0.5077 - pred_recall_m: 0.5050
# Epoch 00013: val_pred_acc did not improve from 0.69333
# 400/400 [==============================] - 165s 412ms/sample - loss: 0.5985 - decoded_mean_loss: 0.0107 - pred_loss: 0.5878 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.8849 - decoded_mean_precision_m: 0.9968 - decoded_mean_recall_m: 0.7960 - pred_acc: 0.6717 - pred_f1_m: 0.5063 - pred_precision_m: 0.5077 - pred_recall_m: 0.5050 - val_loss: 0.5778 - val_decoded_mean_loss: 0.0090 - val_pred_loss: 0.5685 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9075 - val_decoded_mean_precision_m: 0.9924 - val_decoded_mean_recall_m: 0.8359 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.5409 - val_pred_precision_m: 0.5418 - val_pred_recall_m: 0.5400
# Epoch 14/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5924 - decoded_mean_loss: 0.0084 - pred_loss: 0.5839 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9116 - decoded_mean_precision_m: 0.9903 - decoded_mean_recall_m: 0.8444 - pred_acc: 0.6742 - pred_f1_m: 0.5070 - pred_precision_m: 0.5117 - pred_recall_m: 0.5025
# Epoch 00014: val_pred_acc improved from 0.69333 to 0.69867, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 172s 430ms/sample - loss: 0.5924 - decoded_mean_loss: 0.0084 - pred_loss: 0.5839 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9116 - decoded_mean_precision_m: 0.9903 - decoded_mean_recall_m: 0.8444 - pred_acc: 0.6742 - pred_f1_m: 0.5070 - pred_precision_m: 0.5117 - pred_recall_m: 0.5025 - val_loss: 0.5751 - val_decoded_mean_loss: 0.0077 - val_pred_loss: 0.5741 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9169 - val_decoded_mean_precision_m: 0.9861 - val_decoded_mean_recall_m: 0.8568 - val_pred_acc: 0.6987 - val_pred_f1_m: 0.5175 - val_pred_precision_m: 0.5288 - val_pred_recall_m: 0.5067
# Epoch 15/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5875 - decoded_mean_loss: 0.0074 - pred_loss: 0.5801 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9191 - decoded_mean_precision_m: 0.9854 - decoded_mean_recall_m: 0.8612 - pred_acc: 0.6917 - pred_f1_m: 0.5122 - pred_precision_m: 0.5427 - pred_recall_m: 0.4850
# Epoch 00015: val_pred_acc did not improve from 0.69867
# 400/400 [==============================] - 163s 407ms/sample - loss: 0.5875 - decoded_mean_loss: 0.0074 - pred_loss: 0.5801 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9191 - decoded_mean_precision_m: 0.9854 - decoded_mean_recall_m: 0.8612 - pred_acc: 0.6917 - pred_f1_m: 0.5122 - pred_precision_m: 0.5427 - pred_recall_m: 0.4850 - val_loss: 0.5719 - val_decoded_mean_loss: 0.0075 - val_pred_loss: 0.5726 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9226 - val_decoded_mean_precision_m: 0.9817 - val_decoded_mean_recall_m: 0.8702 - val_pred_acc: 0.6973 - val_pred_f1_m: 0.4933 - val_pred_precision_m: 0.5233 - val_pred_recall_m: 0.4667
# Epoch 16/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5792 - decoded_mean_loss: 0.0075 - pred_loss: 0.5717 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9243 - decoded_mean_precision_m: 0.9810 - decoded_mean_recall_m: 0.8738 - pred_acc: 0.6883 - pred_f1_m: 0.4970 - pred_precision_m: 0.5376 - pred_recall_m: 0.4625
# Epoch 00016: val_pred_acc did not improve from 0.69867
# 400/400 [==============================] - 162s 406ms/sample - loss: 0.5792 - decoded_mean_loss: 0.0075 - pred_loss: 0.5717 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9243 - decoded_mean_precision_m: 0.9810 - decoded_mean_recall_m: 0.8738 - pred_acc: 0.6883 - pred_f1_m: 0.4970 - pred_precision_m: 0.5376 - pred_recall_m: 0.4625 - val_loss: 0.5662 - val_decoded_mean_loss: 0.0088 - val_pred_loss: 0.5547 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9274 - val_decoded_mean_precision_m: 0.9761 - val_decoded_mean_recall_m: 0.8833 - val_pred_acc: 0.6960 - val_pred_f1_m: 0.5249 - val_pred_precision_m: 0.5491 - val_pred_recall_m: 0.5033
# Epoch 17/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5742 - decoded_mean_loss: 0.0098 - pred_loss: 0.5644 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9277 - decoded_mean_precision_m: 0.9757 - decoded_mean_recall_m: 0.8842 - pred_acc: 0.6958 - pred_f1_m: 0.5047 - pred_precision_m: 0.5488 - pred_recall_m: 0.4675
# Epoch 00017: val_pred_acc improved from 0.69867 to 0.70533, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 171s 427ms/sample - loss: 0.5742 - decoded_mean_loss: 0.0098 - pred_loss: 0.5644 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9277 - decoded_mean_precision_m: 0.9757 - decoded_mean_recall_m: 0.8842 - pred_acc: 0.6958 - pred_f1_m: 0.5047 - pred_precision_m: 0.5488 - pred_recall_m: 0.4675 - val_loss: 0.5713 - val_decoded_mean_loss: 0.0093 - val_pred_loss: 0.5605 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9277 - val_decoded_mean_precision_m: 0.9758 - val_decoded_mean_recall_m: 0.8841 - val_pred_acc: 0.7053 - val_pred_f1_m: 0.4934 - val_pred_precision_m: 0.5729 - val_pred_recall_m: 0.4333
# Epoch 18/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5641 - decoded_mean_loss: 0.0083 - pred_loss: 0.5559 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9279 - decoded_mean_precision_m: 0.9790 - decoded_mean_recall_m: 0.8819 - pred_acc: 0.7092 - pred_f1_m: 0.4823 - pred_precision_m: 0.5917 - pred_recall_m: 0.4075
# Epoch 00018: val_pred_acc did not improve from 0.70533
# 400/400 [==============================] - 167s 417ms/sample - loss: 0.5641 - decoded_mean_loss: 0.0083 - pred_loss: 0.5559 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9279 - decoded_mean_precision_m: 0.9790 - decoded_mean_recall_m: 0.8819 - pred_acc: 0.7092 - pred_f1_m: 0.4823 - pred_precision_m: 0.5917 - pred_recall_m: 0.4075 - val_loss: 0.5749 - val_decoded_mean_loss: 0.0083 - val_pred_loss: 0.5717 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9287 - val_decoded_mean_precision_m: 0.9768 - val_decoded_mean_recall_m: 0.8851 - val_pred_acc: 0.7053 - val_pred_f1_m: 0.4538 - val_pred_precision_m: 0.5720 - val_pred_recall_m: 0.3767
# Epoch 19/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5608 - decoded_mean_loss: 0.0084 - pred_loss: 0.5524 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9305 - decoded_mean_precision_m: 0.9768 - decoded_mean_recall_m: 0.8883 - pred_acc: 0.7092 - pred_f1_m: 0.4889 - pred_precision_m: 0.5850 - pred_recall_m: 0.4225
# Epoch 00019: val_pred_acc did not improve from 0.70533
# 400/400 [==============================] - 165s 413ms/sample - loss: 0.5608 - decoded_mean_loss: 0.0084 - pred_loss: 0.5524 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9305 - decoded_mean_precision_m: 0.9768 - decoded_mean_recall_m: 0.8883 - pred_acc: 0.7092 - pred_f1_m: 0.4889 - pred_precision_m: 0.5850 - pred_recall_m: 0.4225 - val_loss: 0.5653 - val_decoded_mean_loss: 0.0117 - val_pred_loss: 0.5588 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9334 - val_decoded_mean_precision_m: 0.9717 - val_decoded_mean_recall_m: 0.8980 - val_pred_acc: 0.7013 - val_pred_f1_m: 0.5146 - val_pred_precision_m: 0.5519 - val_pred_recall_m: 0.4833
# Epoch 20/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5631 - decoded_mean_loss: 0.0100 - pred_loss: 0.5531 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9324 - decoded_mean_precision_m: 0.9744 - decoded_mean_recall_m: 0.8938 - pred_acc: 0.7058 - pred_f1_m: 0.5034 - pred_precision_m: 0.5813 - pred_recall_m: 0.4450
# Epoch 00020: val_pred_acc improved from 0.70533 to 0.71733, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 166s 416ms/sample - loss: 0.5631 - decoded_mean_loss: 0.0100 - pred_loss: 0.5531 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9324 - decoded_mean_precision_m: 0.9744 - decoded_mean_recall_m: 0.8938 - pred_acc: 0.7058 - pred_f1_m: 0.5034 - pred_precision_m: 0.5813 - pred_recall_m: 0.4450 - val_loss: 0.5616 - val_decoded_mean_loss: 0.0080 - val_pred_loss: 0.5519 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9312 - val_decoded_mean_precision_m: 0.9768 - val_decoded_mean_recall_m: 0.8896 - val_pred_acc: 0.7173 - val_pred_f1_m: 0.4756 - val_pred_precision_m: 0.6198 - val_pred_recall_m: 0.3867
# Epoch 21/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5607 - decoded_mean_loss: 0.0077 - pred_loss: 0.5529 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9327 - decoded_mean_precision_m: 0.9783 - decoded_mean_recall_m: 0.8912 - pred_acc: 0.7200 - pred_f1_m: 0.5003 - pred_precision_m: 0.6196 - pred_recall_m: 0.4200
# Epoch 00021: val_pred_acc did not improve from 0.71733
# 400/400 [==============================] - 167s 418ms/sample - loss: 0.5607 - decoded_mean_loss: 0.0077 - pred_loss: 0.5529 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9327 - decoded_mean_precision_m: 0.9783 - decoded_mean_recall_m: 0.8912 - pred_acc: 0.7200 - pred_f1_m: 0.5003 - pred_precision_m: 0.6196 - pred_recall_m: 0.4200 - val_loss: 0.5528 - val_decoded_mean_loss: 0.0089 - val_pred_loss: 0.5442 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9349 - val_decoded_mean_precision_m: 0.9749 - val_decoded_mean_recall_m: 0.8981 - val_pred_acc: 0.7053 - val_pred_f1_m: 0.5095 - val_pred_precision_m: 0.5731 - val_pred_recall_m: 0.4600
# Epoch 22/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5449 - decoded_mean_loss: 0.0101 - pred_loss: 0.5347 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9350 - decoded_mean_precision_m: 0.9748 - decoded_mean_recall_m: 0.8984 - pred_acc: 0.7075 - pred_f1_m: 0.5171 - pred_precision_m: 0.5718 - pred_recall_m: 0.4725
# Epoch 00022: val_pred_acc did not improve from 0.71733
# 400/400 [==============================] - 168s 419ms/sample - loss: 0.5449 - decoded_mean_loss: 0.0101 - pred_loss: 0.5347 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9350 - decoded_mean_precision_m: 0.9748 - decoded_mean_recall_m: 0.8984 - pred_acc: 0.7075 - pred_f1_m: 0.5171 - pred_precision_m: 0.5718 - pred_recall_m: 0.4725 - val_loss: 0.5586 - val_decoded_mean_loss: 0.0115 - val_pred_loss: 0.5566 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9344 - val_decoded_mean_precision_m: 0.9736 - val_decoded_mean_recall_m: 0.8982 - val_pred_acc: 0.7013 - val_pred_f1_m: 0.5043 - val_pred_precision_m: 0.5492 - val_pred_recall_m: 0.4667
# Epoch 23/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5450 - decoded_mean_loss: 0.0097 - pred_loss: 0.5353 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9345 - decoded_mean_precision_m: 0.9798 - decoded_mean_recall_m: 0.8931 - pred_acc: 0.7158 - pred_f1_m: 0.5198 - pred_precision_m: 0.5954 - pred_recall_m: 0.4625
# Epoch 00023: val_pred_acc did not improve from 0.71733
# 400/400 [==============================] - 174s 434ms/sample - loss: 0.5450 - decoded_mean_loss: 0.0097 - pred_loss: 0.5353 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9345 - decoded_mean_precision_m: 0.9798 - decoded_mean_recall_m: 0.8931 - pred_acc: 0.7158 - pred_f1_m: 0.5198 - pred_precision_m: 0.5954 - pred_recall_m: 0.4625 - val_loss: 0.5508 - val_decoded_mean_loss: 0.0082 - val_pred_loss: 0.5436 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9345 - val_decoded_mean_precision_m: 0.9807 - val_decoded_mean_recall_m: 0.8925 - val_pred_acc: 0.7080 - val_pred_f1_m: 0.4781 - val_pred_precision_m: 0.5970 - val_pred_recall_m: 0.4000
# Epoch 24/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5284 - decoded_mean_loss: 0.0091 - pred_loss: 0.5192 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9362 - decoded_mean_precision_m: 0.9804 - decoded_mean_recall_m: 0.8959 - pred_acc: 0.7375 - pred_f1_m: 0.5561 - pred_precision_m: 0.6401 - pred_recall_m: 0.4925
# Epoch 00024: val_pred_acc improved from 0.71733 to 0.71733, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 181s 453ms/sample - loss: 0.5284 - decoded_mean_loss: 0.0091 - pred_loss: 0.5192 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9362 - decoded_mean_precision_m: 0.9804 - decoded_mean_recall_m: 0.8959 - pred_acc: 0.7375 - pred_f1_m: 0.5561 - pred_precision_m: 0.6401 - pred_recall_m: 0.4925 - val_loss: 0.5476 - val_decoded_mean_loss: 0.0113 - val_pred_loss: 0.5238 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9370 - val_decoded_mean_precision_m: 0.9767 - val_decoded_mean_recall_m: 0.9005 - val_pred_acc: 0.7173 - val_pred_f1_m: 0.5657 - val_pred_precision_m: 0.6111 - val_pred_recall_m: 0.5267
# Epoch 25/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5231 - decoded_mean_loss: 0.0101 - pred_loss: 0.5130 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9376 - decoded_mean_precision_m: 0.9813 - decoded_mean_recall_m: 0.8975 - pred_acc: 0.7342 - pred_f1_m: 0.5522 - pred_precision_m: 0.6284 - pred_recall_m: 0.4950
# Epoch 00025: val_pred_acc did not improve from 0.71733
# 400/400 [==============================] - 169s 422ms/sample - loss: 0.5231 - decoded_mean_loss: 0.0101 - pred_loss: 0.5130 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9376 - decoded_mean_precision_m: 0.9813 - decoded_mean_recall_m: 0.8975 - pred_acc: 0.7342 - pred_f1_m: 0.5522 - pred_precision_m: 0.6284 - pred_recall_m: 0.4950 - val_loss: 0.5512 - val_decoded_mean_loss: 0.0092 - val_pred_loss: 0.5435 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9378 - val_decoded_mean_precision_m: 0.9831 - val_decoded_mean_recall_m: 0.8965 - val_pred_acc: 0.7133 - val_pred_f1_m: 0.5068 - val_pred_precision_m: 0.5976 - val_pred_recall_m: 0.4400
# Epoch 26/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5317 - decoded_mean_loss: 0.0096 - pred_loss: 0.5221 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9386 - decoded_mean_precision_m: 0.9836 - decoded_mean_recall_m: 0.8975 - pred_acc: 0.7383 - pred_f1_m: 0.5574 - pred_precision_m: 0.6402 - pred_recall_m: 0.4950
# Epoch 00026: val_pred_acc improved from 0.71733 to 0.72533, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 176s 439ms/sample - loss: 0.5317 - decoded_mean_loss: 0.0096 - pred_loss: 0.5221 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9386 - decoded_mean_precision_m: 0.9836 - decoded_mean_recall_m: 0.8975 - pred_acc: 0.7383 - pred_f1_m: 0.5574 - pred_precision_m: 0.6402 - pred_recall_m: 0.4950 - val_loss: 0.5337 - val_decoded_mean_loss: 0.0106 - val_pred_loss: 0.5247 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9406 - val_decoded_mean_precision_m: 0.9808 - val_decoded_mean_recall_m: 0.9036 - val_pred_acc: 0.7253 - val_pred_f1_m: 0.5436 - val_pred_precision_m: 0.5912 - val_pred_recall_m: 0.5033
# Epoch 27/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5192 - decoded_mean_loss: 0.0101 - pred_loss: 0.5091 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9403 - decoded_mean_precision_m: 0.9834 - decoded_mean_recall_m: 0.9008 - pred_acc: 0.7392 - pred_f1_m: 0.5726 - pred_precision_m: 0.6304 - pred_recall_m: 0.5250
# Epoch 00027: val_pred_acc improved from 0.72533 to 0.74000, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 173s 433ms/sample - loss: 0.5192 - decoded_mean_loss: 0.0101 - pred_loss: 0.5091 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9403 - decoded_mean_precision_m: 0.9834 - decoded_mean_recall_m: 0.9008 - pred_acc: 0.7392 - pred_f1_m: 0.5726 - pred_precision_m: 0.6304 - pred_recall_m: 0.5250 - val_loss: 0.5364 - val_decoded_mean_loss: 0.0095 - val_pred_loss: 0.5218 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9401 - val_decoded_mean_precision_m: 0.9861 - val_decoded_mean_recall_m: 0.8982 - val_pred_acc: 0.7400 - val_pred_f1_m: 0.5814 - val_pred_precision_m: 0.6494 - val_pred_recall_m: 0.5267
# Epoch 28/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5036 - decoded_mean_loss: 0.0114 - pred_loss: 0.4922 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9403 - decoded_mean_precision_m: 0.9864 - decoded_mean_recall_m: 0.8983 - pred_acc: 0.7492 - pred_f1_m: 0.5991 - pred_precision_m: 0.6413 - pred_recall_m: 0.5625
# Epoch 00028: val_pred_acc improved from 0.74000 to 0.74267, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 177s 442ms/sample - loss: 0.5036 - decoded_mean_loss: 0.0114 - pred_loss: 0.4922 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9403 - decoded_mean_precision_m: 0.9864 - decoded_mean_recall_m: 0.8983 - pred_acc: 0.7492 - pred_f1_m: 0.5991 - pred_precision_m: 0.6413 - pred_recall_m: 0.5625 - val_loss: 0.5571 - val_decoded_mean_loss: 0.0131 - val_pred_loss: 0.5455 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9408 - val_decoded_mean_precision_m: 0.9833 - val_decoded_mean_recall_m: 0.9019 - val_pred_acc: 0.7427 - val_pred_f1_m: 0.5887 - val_pred_precision_m: 0.6206 - val_pred_recall_m: 0.5600
# Epoch 29/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4974 - decoded_mean_loss: 0.0131 - pred_loss: 0.4843 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9409 - decoded_mean_precision_m: 0.9857 - decoded_mean_recall_m: 0.9000 - pred_acc: 0.7608 - pred_f1_m: 0.6212 - pred_precision_m: 0.6563 - pred_recall_m: 0.5900
# Epoch 00029: val_pred_acc did not improve from 0.74267
# 400/400 [==============================] - 168s 420ms/sample - loss: 0.4974 - decoded_mean_loss: 0.0131 - pred_loss: 0.4843 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9409 - decoded_mean_precision_m: 0.9857 - decoded_mean_recall_m: 0.9000 - pred_acc: 0.7608 - pred_f1_m: 0.6212 - pred_precision_m: 0.6563 - pred_recall_m: 0.5900 - val_loss: 0.5287 - val_decoded_mean_loss: 0.0101 - val_pred_loss: 0.5218 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9400 - val_decoded_mean_precision_m: 0.9894 - val_decoded_mean_recall_m: 0.8953 - val_pred_acc: 0.7227 - val_pred_f1_m: 0.5536 - val_pred_precision_m: 0.5923 - val_pred_recall_m: 0.5200
# Epoch 30/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5079 - decoded_mean_loss: 0.0093 - pred_loss: 0.4986 - decoded_mean_acc: 0.9316 - decoded_mean_f1_m: 0.9390 - decoded_mean_precision_m: 0.9912 - decoded_mean_recall_m: 0.8921 - pred_acc: 0.7525 - pred_f1_m: 0.5966 - pred_precision_m: 0.6519 - pred_recall_m: 0.5500
# Epoch 00030: val_pred_acc improved from 0.74267 to 0.74667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_3.h5
# 400/400 [==============================] - 175s 438ms/sample - loss: 0.5079 - decoded_mean_loss: 0.0093 - pred_loss: 0.4986 - decoded_mean_acc: 0.9316 - decoded_mean_f1_m: 0.9390 - decoded_mean_precision_m: 0.9912 - decoded_mean_recall_m: 0.8921 - pred_acc: 0.7525 - pred_f1_m: 0.5966 - pred_precision_m: 0.6519 - pred_recall_m: 0.5500 - val_loss: 0.5328 - val_decoded_mean_loss: 0.0082 - val_pred_loss: 0.5225 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9420 - val_decoded_mean_precision_m: 0.9886 - val_decoded_mean_recall_m: 0.8996 - val_pred_acc: 0.7467 - val_pred_f1_m: 0.6039 - val_pred_precision_m: 0.6423 - val_pred_recall_m: 0.5700
# Epoch 31/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4926 - decoded_mean_loss: 0.0113 - pred_loss: 0.4813 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9430 - decoded_mean_precision_m: 0.9870 - decoded_mean_recall_m: 0.9028 - pred_acc: 0.7550 - pred_f1_m: 0.6072 - pred_precision_m: 0.6533 - pred_recall_m: 0.5675
# Epoch 00031: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 172s 431ms/sample - loss: 0.4926 - decoded_mean_loss: 0.0113 - pred_loss: 0.4813 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9430 - decoded_mean_precision_m: 0.9870 - decoded_mean_recall_m: 0.9028 - pred_acc: 0.7550 - pred_f1_m: 0.6072 - pred_precision_m: 0.6533 - pred_recall_m: 0.5675 - val_loss: 0.5558 - val_decoded_mean_loss: 0.0101 - val_pred_loss: 0.5453 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9431 - val_decoded_mean_precision_m: 0.9870 - val_decoded_mean_recall_m: 0.9030 - val_pred_acc: 0.7307 - val_pred_f1_m: 0.5735 - val_pred_precision_m: 0.6116 - val_pred_recall_m: 0.5400
# Epoch 32/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4778 - decoded_mean_loss: 0.0095 - pred_loss: 0.4683 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9429 - decoded_mean_precision_m: 0.9908 - decoded_mean_recall_m: 0.8995 - pred_acc: 0.7717 - pred_f1_m: 0.6261 - pred_precision_m: 0.6912 - pred_recall_m: 0.5725
# Epoch 00032: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 175s 436ms/sample - loss: 0.4778 - decoded_mean_loss: 0.0095 - pred_loss: 0.4683 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9429 - decoded_mean_precision_m: 0.9908 - decoded_mean_recall_m: 0.8995 - pred_acc: 0.7717 - pred_f1_m: 0.6261 - pred_precision_m: 0.6912 - pred_recall_m: 0.5725 - val_loss: 0.5253 - val_decoded_mean_loss: 0.0095 - val_pred_loss: 0.5156 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9446 - val_decoded_mean_precision_m: 0.9901 - val_decoded_mean_recall_m: 0.9032 - val_pred_acc: 0.7400 - val_pred_f1_m: 0.5895 - val_pred_precision_m: 0.6359 - val_pred_recall_m: 0.5500
# Epoch 33/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4864 - decoded_mean_loss: 0.0126 - pred_loss: 0.4738 - decoded_mean_acc: 0.9316 - decoded_mean_f1_m: 0.9442 - decoded_mean_precision_m: 0.9895 - decoded_mean_recall_m: 0.9029 - pred_acc: 0.7692 - pred_f1_m: 0.6322 - pred_precision_m: 0.6757 - pred_recall_m: 0.5950
# Epoch 00033: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 166s 414ms/sample - loss: 0.4864 - decoded_mean_loss: 0.0126 - pred_loss: 0.4738 - decoded_mean_acc: 0.9316 - decoded_mean_f1_m: 0.9442 - decoded_mean_precision_m: 0.9895 - decoded_mean_recall_m: 0.9029 - pred_acc: 0.7692 - pred_f1_m: 0.6322 - pred_precision_m: 0.6757 - pred_recall_m: 0.5950 - val_loss: 0.5418 - val_decoded_mean_loss: 0.0140 - val_pred_loss: 0.5460 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9472 - val_decoded_mean_precision_m: 0.9888 - val_decoded_mean_recall_m: 0.9089 - val_pred_acc: 0.7267 - val_pred_f1_m: 0.5630 - val_pred_precision_m: 0.5922 - val_pred_recall_m: 0.5367
# Epoch 34/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4823 - decoded_mean_loss: 0.0127 - pred_loss: 0.4696 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9473 - decoded_mean_precision_m: 0.9904 - decoded_mean_recall_m: 0.9078 - pred_acc: 0.7683 - pred_f1_m: 0.6359 - pred_precision_m: 0.6674 - pred_recall_m: 0.6075
# Epoch 00034: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 166s 414ms/sample - loss: 0.4823 - decoded_mean_loss: 0.0127 - pred_loss: 0.4696 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9473 - decoded_mean_precision_m: 0.9904 - decoded_mean_recall_m: 0.9078 - pred_acc: 0.7683 - pred_f1_m: 0.6359 - pred_precision_m: 0.6674 - pred_recall_m: 0.6075 - val_loss: 0.5230 - val_decoded_mean_loss: 0.0097 - val_pred_loss: 0.5163 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9490 - val_decoded_mean_precision_m: 0.9903 - val_decoded_mean_recall_m: 0.9110 - val_pred_acc: 0.7387 - val_pred_f1_m: 0.5728 - val_pred_precision_m: 0.6361 - val_pred_recall_m: 0.5233
# Epoch 35/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4570 - decoded_mean_loss: 0.0109 - pred_loss: 0.4461 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9492 - decoded_mean_precision_m: 0.9900 - decoded_mean_recall_m: 0.9117 - pred_acc: 0.7892 - pred_f1_m: 0.6615 - pred_precision_m: 0.7095 - pred_recall_m: 0.6200
# Epoch 00035: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 169s 422ms/sample - loss: 0.4570 - decoded_mean_loss: 0.0109 - pred_loss: 0.4461 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9492 - decoded_mean_precision_m: 0.9900 - decoded_mean_recall_m: 0.9117 - pred_acc: 0.7892 - pred_f1_m: 0.6615 - pred_precision_m: 0.7095 - pred_recall_m: 0.6200 - val_loss: 0.5508 - val_decoded_mean_loss: 0.0123 - val_pred_loss: 0.5369 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9513 - val_decoded_mean_precision_m: 0.9876 - val_decoded_mean_recall_m: 0.9175 - val_pred_acc: 0.7360 - val_pred_f1_m: 0.5892 - val_pred_precision_m: 0.6138 - val_pred_recall_m: 0.5667
# Epoch 36/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4562 - decoded_mean_loss: 0.0155 - pred_loss: 0.4406 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9521 - decoded_mean_precision_m: 0.9874 - decoded_mean_recall_m: 0.9192 - pred_acc: 0.7783 - pred_f1_m: 0.6550 - pred_precision_m: 0.6796 - pred_recall_m: 0.6325
# Epoch 00036: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 163s 407ms/sample - loss: 0.4562 - decoded_mean_loss: 0.0155 - pred_loss: 0.4406 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9521 - decoded_mean_precision_m: 0.9874 - decoded_mean_recall_m: 0.9192 - pred_acc: 0.7783 - pred_f1_m: 0.6550 - pred_precision_m: 0.6796 - pred_recall_m: 0.6325 - val_loss: 0.5486 - val_decoded_mean_loss: 0.0131 - val_pred_loss: 0.5406 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9527 - val_decoded_mean_precision_m: 0.9889 - val_decoded_mean_recall_m: 0.9191 - val_pred_acc: 0.7320 - val_pred_f1_m: 0.5856 - val_pred_precision_m: 0.6143 - val_pred_recall_m: 0.5600
# Epoch 37/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4691 - decoded_mean_loss: 0.0131 - pred_loss: 0.4560 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9525 - decoded_mean_precision_m: 0.9916 - decoded_mean_recall_m: 0.9164 - pred_acc: 0.7917 - pred_f1_m: 0.6750 - pred_precision_m: 0.7025 - pred_recall_m: 0.6500
# Epoch 00037: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 162s 405ms/sample - loss: 0.4691 - decoded_mean_loss: 0.0131 - pred_loss: 0.4560 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9525 - decoded_mean_precision_m: 0.9916 - decoded_mean_recall_m: 0.9164 - pred_acc: 0.7917 - pred_f1_m: 0.6750 - pred_precision_m: 0.7025 - pred_recall_m: 0.6500 - val_loss: 0.5420 - val_decoded_mean_loss: 0.0101 - val_pred_loss: 0.5181 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9522 - val_decoded_mean_precision_m: 0.9913 - val_decoded_mean_recall_m: 0.9160 - val_pred_acc: 0.7253 - val_pred_f1_m: 0.5752 - val_pred_precision_m: 0.6155 - val_pred_recall_m: 0.5400
# Epoch 38/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4555 - decoded_mean_loss: 0.0115 - pred_loss: 0.4440 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9529 - decoded_mean_precision_m: 0.9916 - decoded_mean_recall_m: 0.9172 - pred_acc: 0.7742 - pred_f1_m: 0.6373 - pred_precision_m: 0.6862 - pred_recall_m: 0.5950
# Epoch 00038: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 163s 407ms/sample - loss: 0.4555 - decoded_mean_loss: 0.0115 - pred_loss: 0.4440 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9529 - decoded_mean_precision_m: 0.9916 - decoded_mean_recall_m: 0.9172 - pred_acc: 0.7742 - pred_f1_m: 0.6373 - pred_precision_m: 0.6862 - pred_recall_m: 0.5950 - val_loss: 0.5434 - val_decoded_mean_loss: 0.0122 - val_pred_loss: 0.5241 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9530 - val_decoded_mean_precision_m: 0.9899 - val_decoded_mean_recall_m: 0.9187 - val_pred_acc: 0.7413 - val_pred_f1_m: 0.5895 - val_pred_precision_m: 0.6184 - val_pred_recall_m: 0.5633
# Epoch 39/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4275 - decoded_mean_loss: 0.0119 - pred_loss: 0.4156 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9526 - decoded_mean_precision_m: 0.9912 - decoded_mean_recall_m: 0.9169 - pred_acc: 0.8133 - pred_f1_m: 0.7073 - pred_precision_m: 0.7400 - pred_recall_m: 0.6775
# Epoch 00039: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 176s 440ms/sample - loss: 0.4275 - decoded_mean_loss: 0.0119 - pred_loss: 0.4156 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9526 - decoded_mean_precision_m: 0.9912 - decoded_mean_recall_m: 0.9169 - pred_acc: 0.8133 - pred_f1_m: 0.7073 - pred_precision_m: 0.7400 - pred_recall_m: 0.6775 - val_loss: 0.5354 - val_decoded_mean_loss: 0.0133 - val_pred_loss: 0.5071 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9533 - val_decoded_mean_precision_m: 0.9902 - val_decoded_mean_recall_m: 0.9190 - val_pred_acc: 0.7413 - val_pred_f1_m: 0.6112 - val_pred_precision_m: 0.6340 - val_pred_recall_m: 0.5900
# Epoch 40/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4323 - decoded_mean_loss: 0.0169 - pred_loss: 0.4154 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9535 - decoded_mean_precision_m: 0.9897 - decoded_mean_recall_m: 0.9198 - pred_acc: 0.7967 - pred_f1_m: 0.6824 - pred_precision_m: 0.7123 - pred_recall_m: 0.6550
# Epoch 00040: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 170s 426ms/sample - loss: 0.4323 - decoded_mean_loss: 0.0169 - pred_loss: 0.4154 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9535 - decoded_mean_precision_m: 0.9897 - decoded_mean_recall_m: 0.9198 - pred_acc: 0.7967 - pred_f1_m: 0.6824 - pred_precision_m: 0.7123 - pred_recall_m: 0.6550 - val_loss: 0.5615 - val_decoded_mean_loss: 0.0137 - val_pred_loss: 0.5572 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9532 - val_decoded_mean_precision_m: 0.9914 - val_decoded_mean_recall_m: 0.9178 - val_pred_acc: 0.7160 - val_pred_f1_m: 0.5628 - val_pred_precision_m: 0.5838 - val_pred_recall_m: 0.5433
# Epoch 41/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4406 - decoded_mean_loss: 0.0140 - pred_loss: 0.4266 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9525 - decoded_mean_precision_m: 0.9924 - decoded_mean_recall_m: 0.9158 - pred_acc: 0.7825 - pred_f1_m: 0.6604 - pred_precision_m: 0.6880 - pred_recall_m: 0.6350
# Epoch 00041: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 168s 420ms/sample - loss: 0.4406 - decoded_mean_loss: 0.0140 - pred_loss: 0.4266 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9525 - decoded_mean_precision_m: 0.9924 - decoded_mean_recall_m: 0.9158 - pred_acc: 0.7825 - pred_f1_m: 0.6604 - pred_precision_m: 0.6880 - pred_recall_m: 0.6350 - val_loss: 0.5516 - val_decoded_mean_loss: 0.0130 - val_pred_loss: 0.5331 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9527 - val_decoded_mean_precision_m: 0.9911 - val_decoded_mean_recall_m: 0.9171 - val_pred_acc: 0.7200 - val_pred_f1_m: 0.5743 - val_pred_precision_m: 0.5897 - val_pred_recall_m: 0.5600
# Epoch 42/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4386 - decoded_mean_loss: 0.0159 - pred_loss: 0.4227 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9531 - decoded_mean_precision_m: 0.9904 - decoded_mean_recall_m: 0.9186 - pred_acc: 0.8008 - pred_f1_m: 0.6919 - pred_precision_m: 0.7155 - pred_recall_m: 0.6700
# Epoch 00042: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 185s 461ms/sample - loss: 0.4386 - decoded_mean_loss: 0.0159 - pred_loss: 0.4227 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9531 - decoded_mean_precision_m: 0.9904 - decoded_mean_recall_m: 0.9186 - pred_acc: 0.8008 - pred_f1_m: 0.6919 - pred_precision_m: 0.7155 - pred_recall_m: 0.6700 - val_loss: 0.5479 - val_decoded_mean_loss: 0.0106 - val_pred_loss: 0.5414 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9517 - val_decoded_mean_precision_m: 0.9916 - val_decoded_mean_recall_m: 0.9149 - val_pred_acc: 0.7227 - val_pred_f1_m: 0.5608 - val_pred_precision_m: 0.5954 - val_pred_recall_m: 0.5300
# Epoch 43/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4257 - decoded_mean_loss: 0.0108 - pred_loss: 0.4149 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9520 - decoded_mean_precision_m: 0.9934 - decoded_mean_recall_m: 0.9139 - pred_acc: 0.8075 - pred_f1_m: 0.6926 - pred_precision_m: 0.7389 - pred_recall_m: 0.6525
# Epoch 00043: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 163s 407ms/sample - loss: 0.4257 - decoded_mean_loss: 0.0108 - pred_loss: 0.4149 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9520 - decoded_mean_precision_m: 0.9934 - decoded_mean_recall_m: 0.9139 - pred_acc: 0.8075 - pred_f1_m: 0.6926 - pred_precision_m: 0.7389 - pred_recall_m: 0.6525 - val_loss: 0.5402 - val_decoded_mean_loss: 0.0097 - val_pred_loss: 0.5319 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9519 - val_decoded_mean_precision_m: 0.9932 - val_decoded_mean_recall_m: 0.9140 - val_pred_acc: 0.7267 - val_pred_f1_m: 0.5697 - val_pred_precision_m: 0.6114 - val_pred_recall_m: 0.5333
# Epoch 44/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4244 - decoded_mean_loss: 0.0116 - pred_loss: 0.4128 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9526 - decoded_mean_precision_m: 0.9930 - decoded_mean_recall_m: 0.9154 - pred_acc: 0.8092 - pred_f1_m: 0.7015 - pred_precision_m: 0.7331 - pred_recall_m: 0.6725
# Epoch 00044: val_pred_acc did not improve from 0.74667
# 400/400 [==============================] - 166s 415ms/sample - loss: 0.4244 - decoded_mean_loss: 0.0116 - pred_loss: 0.4128 - decoded_mean_acc: 0.9317 - decoded_mean_f1_m: 0.9526 - decoded_mean_precision_m: 0.9930 - decoded_mean_recall_m: 0.9154 - pred_acc: 0.8092 - pred_f1_m: 0.7015 - pred_precision_m: 0.7331 - pred_recall_m: 0.6725 - val_loss: 0.5799 - val_decoded_mean_loss: 0.0139 - val_pred_loss: 0.5673 - val_decoded_mean_acc: 0.9329 - val_decoded_mean_f1_m: 0.9528 - val_decoded_mean_precision_m: 0.9910 - val_decoded_mean_recall_m: 0.9175 - val_pred_acc: 0.7267 - val_pred_f1_m: 0.5747 - val_pred_precision_m: 0.6020 - val_pred_recall_m: 0.5500
# Epoch 00044: early stopping

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# # Test_4
# Une Couche avec 850 unite

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/Models_a_ameliorer'
MODEL_FILE_NAME = 'Test_4.h5'
LR=0.0001
batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500
encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)
def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(800,return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Dense(300, activation='relu', name='dense_1')(h)
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])
    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    return (fct_loss, z) 
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()
def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)

encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()
def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h = Bidirectional(  LSTM(800, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 

autoencoder.compile(optimizer=Adam(learning_rate=LR), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/initializers/initializers_v1.py:278: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/initializers/initializers_v1.py:160: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  embedding (Embedding)          (None, 100, 100)     2281400     ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 100, 1600)    5766400     ['embedding[0][0]']
#
#  attention_couche (AttentionCou  (None, 1600)        1700        ['bidirectional[0][0]']
#  che)
#
#  dense_1 (Dense)                (None, 300)          480300      ['attention_couche[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 8,650,200
# Trainable params: 8,650,200
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  dense (Dense)               (None, 100)               20100
#
#  pred (Dense)                (None, 3)                 303
#
# =================================================================
# Total params: 20,403
# Trainable params: 20,403
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  repeat_vector_1 (RepeatVect  (None, 100, 200)         0
#  or)
#
#  bidirectional_1 (Bidirectio  (None, 100, 1600)        6406400
#  nal)
#
#  decoded_mean (TimeDistribut  (None, 100, 22814)       36525214
#  ed)
#
# =================================================================
# Total params: 42,931,614
# Trainable params: 42,931,614
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  embedding (Embedding)          (None, 100, 100)     2281400     ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 100, 1600)    5766400     ['embedding[0][0]']
#
#  attention_couche (AttentionCou  (None, 1600)        1700        ['bidirectional[0][0]']
#  che)
#
#  dense_1 (Dense)                (None, 300)          480300      ['attention_couche[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  repeat_vector_2 (RepeatVector)  (None, 100, 200)    0           ['z[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 100, 1600)   6406400     ['repeat_vector_2[0][0]']
#  )
#
#  dense_3 (Dense)                (None, 100)          20100       ['z[0][0]']
#
#  decoded_mean (TimeDistributed)  (None, 100, 22814)  36525214    ['bidirectional_2[0][0]']
#
#  pred (Dense)                   (None, 3)            303         ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 51,602,217
# Trainable params: 51,602,217
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])
# Out:
# Train on 400 samples, validate on 250 samples
# Epoch 1/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7350 - decoded_mean_loss: 0.0484 - pred_loss: 0.6866 - decoded_mean_acc: 0.0414 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 00001: val_pred_acc improved from -inf to 0.66667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 180s 451ms/sample - loss: 0.7350 - decoded_mean_loss: 0.0484 - pred_loss: 0.6866 - decoded_mean_acc: 0.0414 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7252 - val_decoded_mean_loss: 0.0484 - val_pred_loss: 0.6770 - val_decoded_mean_acc: 0.7448 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 2/100
# 400/400 [==============================] - ETA: 0s - loss: 0.7171 - decoded_mean_loss: 0.0485 - pred_loss: 0.6686 - decoded_mean_acc: 0.7694 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00
# Epoch 00002: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 177s 443ms/sample - loss: 0.7171 - decoded_mean_loss: 0.0485 - pred_loss: 0.6686 - decoded_mean_acc: 0.7694 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0000e+00 - pred_precision_m: 0.0000e+00 - pred_recall_m: 0.0000e+00 - val_loss: 0.7038 - val_decoded_mean_loss: 0.0486 - val_pred_loss: 0.6544 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.0000e+00 - val_pred_precision_m: 0.0000e+00 - val_pred_recall_m: 0.0000e+00
# Epoch 3/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6896 - decoded_mean_loss: 0.0489 - pred_loss: 0.6408 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0240 - pred_precision_m: 0.4583 - pred_recall_m: 0.0125
# Epoch 00003: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 197s 492ms/sample - loss: 0.6896 - decoded_mean_loss: 0.0489 - pred_loss: 0.6408 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6667 - pred_f1_m: 0.0240 - pred_precision_m: 0.4583 - pred_recall_m: 0.0125 - val_loss: 0.6774 - val_decoded_mean_loss: 0.0498 - val_pred_loss: 0.6280 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6440 - val_pred_f1_m: 0.1664 - val_pred_precision_m: 0.3835 - val_pred_recall_m: 0.1067
# Epoch 4/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6662 - decoded_mean_loss: 0.0513 - pred_loss: 0.6148 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.3193 - pred_precision_m: 0.4834 - pred_recall_m: 0.2525
# Epoch 00004: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 174s 434ms/sample - loss: 0.6662 - decoded_mean_loss: 0.0513 - pred_loss: 0.6148 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6650 - pred_f1_m: 0.3193 - pred_precision_m: 0.4834 - pred_recall_m: 0.2525 - val_loss: 0.6805 - val_decoded_mean_loss: 0.0547 - val_pred_loss: 0.6240 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.4597 - val_pred_precision_m: 0.4942 - val_pred_recall_m: 0.4300
# Epoch 5/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6620 - decoded_mean_loss: 0.0534 - pred_loss: 0.6086 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6617 - pred_f1_m: 0.4453 - pred_precision_m: 0.4912 - pred_recall_m: 0.4075
# Epoch 00005: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 180s 450ms/sample - loss: 0.6620 - decoded_mean_loss: 0.0534 - pred_loss: 0.6086 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6617 - pred_f1_m: 0.4453 - pred_precision_m: 0.4912 - pred_recall_m: 0.4075 - val_loss: 0.6673 - val_decoded_mean_loss: 0.0518 - val_pred_loss: 0.6214 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6453 - val_pred_f1_m: 0.3823 - val_pred_precision_m: 0.4377 - val_pred_recall_m: 0.3400
# Epoch 6/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6523 - decoded_mean_loss: 0.0504 - pred_loss: 0.6019 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.4062 - pred_precision_m: 0.5270 - pred_recall_m: 0.3325
# Epoch 00006: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 186s 465ms/sample - loss: 0.6523 - decoded_mean_loss: 0.0504 - pred_loss: 0.6019 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6758 - pred_f1_m: 0.4062 - pred_precision_m: 0.5270 - pred_recall_m: 0.3325 - val_loss: 0.6616 - val_decoded_mean_loss: 0.0491 - val_pred_loss: 0.6137 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6560 - val_pred_f1_m: 0.3482 - val_pred_precision_m: 0.4617 - val_pred_recall_m: 0.2800
# Epoch 7/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6496 - decoded_mean_loss: 0.0481 - pred_loss: 0.6015 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6700 - pred_f1_m: 0.3670 - pred_precision_m: 0.5083 - pred_recall_m: 0.2875
# Epoch 00007: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 177s 443ms/sample - loss: 0.6496 - decoded_mean_loss: 0.0481 - pred_loss: 0.6015 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6700 - pred_f1_m: 0.3670 - pred_precision_m: 0.5083 - pred_recall_m: 0.2875 - val_loss: 0.6553 - val_decoded_mean_loss: 0.0459 - val_pred_loss: 0.6111 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6493 - val_pred_f1_m: 0.3439 - val_pred_precision_m: 0.4468 - val_pred_recall_m: 0.2800
# Epoch 8/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6416 - decoded_mean_loss: 0.0435 - pred_loss: 0.5981 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6725 - pred_f1_m: 0.4202 - pred_precision_m: 0.5088 - pred_recall_m: 0.3625
# Epoch 00008: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 181s 452ms/sample - loss: 0.6416 - decoded_mean_loss: 0.0435 - pred_loss: 0.5981 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6725 - pred_f1_m: 0.4202 - pred_precision_m: 0.5088 - pred_recall_m: 0.3625 - val_loss: 0.6447 - val_decoded_mean_loss: 0.0389 - val_pred_loss: 0.6031 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6613 - val_pred_f1_m: 0.4827 - val_pred_precision_m: 0.4961 - val_pred_recall_m: 0.4700
# Epoch 9/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6295 - decoded_mean_loss: 0.0353 - pred_loss: 0.5942 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4716 - pred_precision_m: 0.4866 - pred_recall_m: 0.4575
# Epoch 00009: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 185s 462ms/sample - loss: 0.6295 - decoded_mean_loss: 0.0353 - pred_loss: 0.5942 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6583 - pred_f1_m: 0.4716 - pred_precision_m: 0.4866 - pred_recall_m: 0.4575 - val_loss: 0.6326 - val_decoded_mean_loss: 0.0297 - val_pred_loss: 0.6087 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6627 - val_pred_f1_m: 0.4664 - val_pred_precision_m: 0.4884 - val_pred_recall_m: 0.4467
# Epoch 10/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6182 - decoded_mean_loss: 0.0263 - pred_loss: 0.5918 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6625 - pred_f1_m: 0.4719 - pred_precision_m: 0.4932 - pred_recall_m: 0.4525
# Epoch 00010: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 178s 445ms/sample - loss: 0.6182 - decoded_mean_loss: 0.0263 - pred_loss: 0.5918 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6625 - pred_f1_m: 0.4719 - pred_precision_m: 0.4932 - pred_recall_m: 0.4525 - val_loss: 0.6208 - val_decoded_mean_loss: 0.0213 - val_pred_loss: 0.5986 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0000e+00 - val_decoded_mean_precision_m: 0.0000e+00 - val_decoded_mean_recall_m: 0.0000e+00 - val_pred_acc: 0.6640 - val_pred_f1_m: 0.4836 - val_pred_precision_m: 0.5058 - val_pred_recall_m: 0.4633
# Epoch 11/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6082 - decoded_mean_loss: 0.0183 - pred_loss: 0.5899 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6725 - pred_f1_m: 0.4906 - pred_precision_m: 0.5104 - pred_recall_m: 0.4725
# Epoch 00011: val_pred_acc did not improve from 0.66667
# 400/400 [==============================] - 186s 465ms/sample - loss: 0.6082 - decoded_mean_loss: 0.0183 - pred_loss: 0.5899 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.0000e+00 - decoded_mean_precision_m: 0.0000e+00 - decoded_mean_recall_m: 0.0000e+00 - pred_acc: 0.6725 - pred_f1_m: 0.4906 - pred_precision_m: 0.5104 - pred_recall_m: 0.4725 - val_loss: 0.6103 - val_decoded_mean_loss: 0.0138 - val_pred_loss: 0.5960 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.0146 - val_decoded_mean_precision_m: 0.6667 - val_decoded_mean_recall_m: 0.0074 - val_pred_acc: 0.6627 - val_pred_f1_m: 0.4739 - val_pred_precision_m: 0.4889 - val_pred_recall_m: 0.4600
# Epoch 12/100
# 400/400 [==============================] - ETA: 0s - loss: 0.6003 - decoded_mean_loss: 0.0120 - pred_loss: 0.5882 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.6571 - decoded_mean_precision_m: 0.9982 - decoded_mean_recall_m: 0.5847 - pred_acc: 0.6667 - pred_f1_m: 0.4939 - pred_precision_m: 0.5007 - pred_recall_m: 0.4875
# Epoch 00012: val_pred_acc improved from 0.66667 to 0.66667, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 219s 547ms/sample - loss: 0.6003 - decoded_mean_loss: 0.0120 - pred_loss: 0.5882 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.6571 - decoded_mean_precision_m: 0.9982 - decoded_mean_recall_m: 0.5847 - pred_acc: 0.6667 - pred_f1_m: 0.4939 - pred_precision_m: 0.5007 - pred_recall_m: 0.4875 - val_loss: 0.6022 - val_decoded_mean_loss: 0.0097 - val_pred_loss: 0.5948 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.8984 - val_decoded_mean_precision_m: 0.9932 - val_decoded_mean_recall_m: 0.8201 - val_pred_acc: 0.6667 - val_pred_f1_m: 0.4818 - val_pred_precision_m: 0.4907 - val_pred_recall_m: 0.4733
# Epoch 13/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5921 - decoded_mean_loss: 0.0086 - pred_loss: 0.5834 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9052 - decoded_mean_precision_m: 0.9924 - decoded_mean_recall_m: 0.8322 - pred_acc: 0.6883 - pred_f1_m: 0.4812 - pred_precision_m: 0.5452 - pred_recall_m: 0.4350
# Epoch 00013: val_pred_acc improved from 0.66667 to 0.69200, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 207s 518ms/sample - loss: 0.5921 - decoded_mean_loss: 0.0086 - pred_loss: 0.5834 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9052 - decoded_mean_precision_m: 0.9924 - decoded_mean_recall_m: 0.8322 - pred_acc: 0.6883 - pred_f1_m: 0.4812 - pred_precision_m: 0.5452 - pred_recall_m: 0.4350 - val_loss: 0.5979 - val_decoded_mean_loss: 0.0079 - val_pred_loss: 0.5876 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9124 - val_decoded_mean_precision_m: 0.9869 - val_decoded_mean_recall_m: 0.8483 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.4567 - val_pred_precision_m: 0.5655 - val_pred_recall_m: 0.3833
# Epoch 14/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5880 - decoded_mean_loss: 0.0077 - pred_loss: 0.5803 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9167 - decoded_mean_precision_m: 0.9859 - decoded_mean_recall_m: 0.8566 - pred_acc: 0.7008 - pred_f1_m: 0.5018 - pred_precision_m: 0.5646 - pred_recall_m: 0.4525
# Epoch 00014: val_pred_acc did not improve from 0.69200
# 400/400 [==============================] - 187s 466ms/sample - loss: 0.5880 - decoded_mean_loss: 0.0077 - pred_loss: 0.5803 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9167 - decoded_mean_precision_m: 0.9859 - decoded_mean_recall_m: 0.8566 - pred_acc: 0.7008 - pred_f1_m: 0.5018 - pred_precision_m: 0.5646 - pred_recall_m: 0.4525 - val_loss: 0.5911 - val_decoded_mean_loss: 0.0082 - val_pred_loss: 0.5946 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9217 - val_decoded_mean_precision_m: 0.9802 - val_decoded_mean_recall_m: 0.8698 - val_pred_acc: 0.6800 - val_pred_f1_m: 0.4799 - val_pred_precision_m: 0.4978 - val_pred_recall_m: 0.4633
# Epoch 15/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5832 - decoded_mean_loss: 0.0077 - pred_loss: 0.5755 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9236 - decoded_mean_precision_m: 0.9809 - decoded_mean_recall_m: 0.8727 - pred_acc: 0.6858 - pred_f1_m: 0.5057 - pred_precision_m: 0.5354 - pred_recall_m: 0.4800
# Epoch 00015: val_pred_acc improved from 0.69200 to 0.70533, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 191s 478ms/sample - loss: 0.5832 - decoded_mean_loss: 0.0077 - pred_loss: 0.5755 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9236 - decoded_mean_precision_m: 0.9809 - decoded_mean_recall_m: 0.8727 - pred_acc: 0.6858 - pred_f1_m: 0.5057 - pred_precision_m: 0.5354 - pred_recall_m: 0.4800 - val_loss: 0.5825 - val_decoded_mean_loss: 0.0075 - val_pred_loss: 0.5770 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9245 - val_decoded_mean_precision_m: 0.9777 - val_decoded_mean_recall_m: 0.8769 - val_pred_acc: 0.7053 - val_pred_f1_m: 0.5013 - val_pred_precision_m: 0.5585 - val_pred_recall_m: 0.4567
# Epoch 16/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5744 - decoded_mean_loss: 0.0079 - pred_loss: 0.5665 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9270 - decoded_mean_precision_m: 0.9770 - decoded_mean_recall_m: 0.8820 - pred_acc: 0.7025 - pred_f1_m: 0.5241 - pred_precision_m: 0.5635 - pred_recall_m: 0.4900
# Epoch 00016: val_pred_acc improved from 0.70533 to 0.73333, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 191s 477ms/sample - loss: 0.5744 - decoded_mean_loss: 0.0079 - pred_loss: 0.5665 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9270 - decoded_mean_precision_m: 0.9770 - decoded_mean_recall_m: 0.8820 - pred_acc: 0.7025 - pred_f1_m: 0.5241 - pred_precision_m: 0.5635 - pred_recall_m: 0.4900 - val_loss: 0.5687 - val_decoded_mean_loss: 0.0080 - val_pred_loss: 0.5625 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9275 - val_decoded_mean_precision_m: 0.9755 - val_decoded_mean_recall_m: 0.8839 - val_pred_acc: 0.7333 - val_pred_f1_m: 0.5575 - val_pred_precision_m: 0.6108 - val_pred_recall_m: 0.5133
# Epoch 17/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5524 - decoded_mean_loss: 0.0086 - pred_loss: 0.5438 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9287 - decoded_mean_precision_m: 0.9769 - decoded_mean_recall_m: 0.8850 - pred_acc: 0.7192 - pred_f1_m: 0.5430 - pred_precision_m: 0.5947 - pred_recall_m: 0.5000
# Epoch 00017: val_pred_acc did not improve from 0.73333
# 400/400 [==============================] - 190s 475ms/sample - loss: 0.5524 - decoded_mean_loss: 0.0086 - pred_loss: 0.5438 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9287 - decoded_mean_precision_m: 0.9769 - decoded_mean_recall_m: 0.8850 - pred_acc: 0.7192 - pred_f1_m: 0.5430 - pred_precision_m: 0.5947 - pred_recall_m: 0.5000 - val_loss: 0.5662 - val_decoded_mean_loss: 0.0104 - val_pred_loss: 0.5457 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9286 - val_decoded_mean_precision_m: 0.9725 - val_decoded_mean_recall_m: 0.8885 - val_pred_acc: 0.7333 - val_pred_f1_m: 0.5950 - val_pred_precision_m: 0.6184 - val_pred_recall_m: 0.5733
# Epoch 18/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5378 - decoded_mean_loss: 0.0103 - pred_loss: 0.5276 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9311 - decoded_mean_precision_m: 0.9742 - decoded_mean_recall_m: 0.8917 - pred_acc: 0.7408 - pred_f1_m: 0.5903 - pred_precision_m: 0.6242 - pred_recall_m: 0.5600
# Epoch 00018: val_pred_acc did not improve from 0.73333
# 400/400 [==============================] - 186s 466ms/sample - loss: 0.5378 - decoded_mean_loss: 0.0103 - pred_loss: 0.5276 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9311 - decoded_mean_precision_m: 0.9742 - decoded_mean_recall_m: 0.8917 - pred_acc: 0.7408 - pred_f1_m: 0.5903 - pred_precision_m: 0.6242 - pred_recall_m: 0.5600 - val_loss: 0.5692 - val_decoded_mean_loss: 0.0093 - val_pred_loss: 0.5633 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9308 - val_decoded_mean_precision_m: 0.9751 - val_decoded_mean_recall_m: 0.8904 - val_pred_acc: 0.6920 - val_pred_f1_m: 0.4970 - val_pred_precision_m: 0.5405 - val_pred_recall_m: 0.4600
# Epoch 19/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5441 - decoded_mean_loss: 0.0087 - pred_loss: 0.5354 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9319 - decoded_mean_precision_m: 0.9767 - decoded_mean_recall_m: 0.8911 - pred_acc: 0.7242 - pred_f1_m: 0.5497 - pred_precision_m: 0.6033 - pred_recall_m: 0.5050
# Epoch 00019: val_pred_acc did not improve from 0.73333
# 400/400 [==============================] - 190s 476ms/sample - loss: 0.5441 - decoded_mean_loss: 0.0087 - pred_loss: 0.5354 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9319 - decoded_mean_precision_m: 0.9767 - decoded_mean_recall_m: 0.8911 - pred_acc: 0.7242 - pred_f1_m: 0.5497 - pred_precision_m: 0.6033 - pred_recall_m: 0.5050 - val_loss: 0.5599 - val_decoded_mean_loss: 0.0081 - val_pred_loss: 0.5605 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9323 - val_decoded_mean_precision_m: 0.9745 - val_decoded_mean_recall_m: 0.8937 - val_pred_acc: 0.7253 - val_pred_f1_m: 0.5502 - val_pred_precision_m: 0.5844 - val_pred_recall_m: 0.5200
# Epoch 20/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5479 - decoded_mean_loss: 0.0083 - pred_loss: 0.5396 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9341 - decoded_mean_precision_m: 0.9754 - decoded_mean_recall_m: 0.8961 - pred_acc: 0.7208 - pred_f1_m: 0.5523 - pred_precision_m: 0.5925 - pred_recall_m: 0.5175
# Epoch 00020: val_pred_acc did not improve from 0.73333
# 400/400 [==============================] - 187s 468ms/sample - loss: 0.5479 - decoded_mean_loss: 0.0083 - pred_loss: 0.5396 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9341 - decoded_mean_precision_m: 0.9754 - decoded_mean_recall_m: 0.8961 - pred_acc: 0.7208 - pred_f1_m: 0.5523 - pred_precision_m: 0.5925 - pred_recall_m: 0.5175 - val_loss: 0.5585 - val_decoded_mean_loss: 0.0080 - val_pred_loss: 0.5536 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9335 - val_decoded_mean_precision_m: 0.9752 - val_decoded_mean_recall_m: 0.8952 - val_pred_acc: 0.7293 - val_pred_f1_m: 0.5650 - val_pred_precision_m: 0.6140 - val_pred_recall_m: 0.5233
# Epoch 21/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5395 - decoded_mean_loss: 0.0082 - pred_loss: 0.5313 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9356 - decoded_mean_precision_m: 0.9767 - decoded_mean_recall_m: 0.8978 - pred_acc: 0.7242 - pred_f1_m: 0.5498 - pred_precision_m: 0.6034 - pred_recall_m: 0.5050
# Epoch 00021: val_pred_acc did not improve from 0.73333
# 400/400 [==============================] - 194s 485ms/sample - loss: 0.5395 - decoded_mean_loss: 0.0082 - pred_loss: 0.5313 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9356 - decoded_mean_precision_m: 0.9767 - decoded_mean_recall_m: 0.8978 - pred_acc: 0.7242 - pred_f1_m: 0.5498 - pred_precision_m: 0.6034 - pred_recall_m: 0.5050 - val_loss: 0.5572 - val_decoded_mean_loss: 0.0085 - val_pred_loss: 0.5501 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9352 - val_decoded_mean_precision_m: 0.9766 - val_decoded_mean_recall_m: 0.8972 - val_pred_acc: 0.7173 - val_pred_f1_m: 0.5383 - val_pred_precision_m: 0.5833 - val_pred_recall_m: 0.5000
# Epoch 22/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5311 - decoded_mean_loss: 0.0088 - pred_loss: 0.5223 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9368 - decoded_mean_precision_m: 0.9781 - decoded_mean_recall_m: 0.8989 - pred_acc: 0.7317 - pred_f1_m: 0.5642 - pred_precision_m: 0.6136 - pred_recall_m: 0.5225
# Epoch 00022: val_pred_acc improved from 0.73333 to 0.74400, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 207s 518ms/sample - loss: 0.5311 - decoded_mean_loss: 0.0088 - pred_loss: 0.5223 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9368 - decoded_mean_precision_m: 0.9781 - decoded_mean_recall_m: 0.8989 - pred_acc: 0.7317 - pred_f1_m: 0.5642 - pred_precision_m: 0.6136 - pred_recall_m: 0.5225 - val_loss: 0.5612 - val_decoded_mean_loss: 0.0106 - val_pred_loss: 0.5462 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9369 - val_decoded_mean_precision_m: 0.9760 - val_decoded_mean_recall_m: 0.9008 - val_pred_acc: 0.7440 - val_pred_f1_m: 0.5884 - val_pred_precision_m: 0.6249 - val_pred_recall_m: 0.5567
# Epoch 23/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5324 - decoded_mean_loss: 0.0098 - pred_loss: 0.5226 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9379 - decoded_mean_precision_m: 0.9779 - decoded_mean_recall_m: 0.9011 - pred_acc: 0.7300 - pred_f1_m: 0.5701 - pred_precision_m: 0.6072 - pred_recall_m: 0.5375
# Epoch 00023: val_pred_acc did not improve from 0.74400
# 400/400 [==============================] - 189s 473ms/sample - loss: 0.5324 - decoded_mean_loss: 0.0098 - pred_loss: 0.5226 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9379 - decoded_mean_precision_m: 0.9779 - decoded_mean_recall_m: 0.9011 - pred_acc: 0.7300 - pred_f1_m: 0.5701 - pred_precision_m: 0.6072 - pred_recall_m: 0.5375 - val_loss: 0.5472 - val_decoded_mean_loss: 0.0084 - val_pred_loss: 0.5330 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9369 - val_decoded_mean_precision_m: 0.9797 - val_decoded_mean_recall_m: 0.8977 - val_pred_acc: 0.7213 - val_pred_f1_m: 0.5651 - val_pred_precision_m: 0.6009 - val_pred_recall_m: 0.5333
# Epoch 24/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5154 - decoded_mean_loss: 0.0084 - pred_loss: 0.5070 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9385 - decoded_mean_precision_m: 0.9814 - decoded_mean_recall_m: 0.8993 - pred_acc: 0.7433 - pred_f1_m: 0.5865 - pred_precision_m: 0.6359 - pred_recall_m: 0.5450
# Epoch 00024: val_pred_acc did not improve from 0.74400
# 400/400 [==============================] - 189s 471ms/sample - loss: 0.5154 - decoded_mean_loss: 0.0084 - pred_loss: 0.5070 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9385 - decoded_mean_precision_m: 0.9814 - decoded_mean_recall_m: 0.8993 - pred_acc: 0.7433 - pred_f1_m: 0.5865 - pred_precision_m: 0.6359 - pred_recall_m: 0.5450 - val_loss: 0.5446 - val_decoded_mean_loss: 0.0095 - val_pred_loss: 0.5336 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9392 - val_decoded_mean_precision_m: 0.9801 - val_decoded_mean_recall_m: 0.9016 - val_pred_acc: 0.7427 - val_pred_f1_m: 0.5775 - val_pred_precision_m: 0.6166 - val_pred_recall_m: 0.5433
# Epoch 25/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5047 - decoded_mean_loss: 0.0112 - pred_loss: 0.4935 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9410 - decoded_mean_precision_m: 0.9801 - decoded_mean_recall_m: 0.9048 - pred_acc: 0.7442 - pred_f1_m: 0.5982 - pred_precision_m: 0.6297 - pred_recall_m: 0.5700
# Epoch 00025: val_pred_acc did not improve from 0.74400
# 400/400 [==============================] - 180s 449ms/sample - loss: 0.5047 - decoded_mean_loss: 0.0112 - pred_loss: 0.4935 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9410 - decoded_mean_precision_m: 0.9801 - decoded_mean_recall_m: 0.9048 - pred_acc: 0.7442 - pred_f1_m: 0.5982 - pred_precision_m: 0.6297 - pred_recall_m: 0.5700 - val_loss: 0.5459 - val_decoded_mean_loss: 0.0111 - val_pred_loss: 0.5337 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9397 - val_decoded_mean_precision_m: 0.9805 - val_decoded_mean_recall_m: 0.9021 - val_pred_acc: 0.7227 - val_pred_f1_m: 0.5687 - val_pred_precision_m: 0.5968 - val_pred_recall_m: 0.5433
# Epoch 26/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5027 - decoded_mean_loss: 0.0107 - pred_loss: 0.4919 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9411 - decoded_mean_precision_m: 0.9832 - decoded_mean_recall_m: 0.9024 - pred_acc: 0.7492 - pred_f1_m: 0.6015 - pred_precision_m: 0.6403 - pred_recall_m: 0.5675
# Epoch 00026: val_pred_acc improved from 0.74400 to 0.74933, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 201s 503ms/sample - loss: 0.5027 - decoded_mean_loss: 0.0107 - pred_loss: 0.4919 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9411 - decoded_mean_precision_m: 0.9832 - decoded_mean_recall_m: 0.9024 - pred_acc: 0.7492 - pred_f1_m: 0.6015 - pred_precision_m: 0.6403 - pred_recall_m: 0.5675 - val_loss: 0.5369 - val_decoded_mean_loss: 0.0100 - val_pred_loss: 0.5205 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9386 - val_decoded_mean_precision_m: 0.9847 - val_decoded_mean_recall_m: 0.8967 - val_pred_acc: 0.7493 - val_pred_f1_m: 0.5849 - val_pred_precision_m: 0.6638 - val_pred_recall_m: 0.5233
# Epoch 27/100
# 400/400 [==============================] - ETA: 0s - loss: 0.5132 - decoded_mean_loss: 0.0109 - pred_loss: 0.5024 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9396 - decoded_mean_precision_m: 0.9854 - decoded_mean_recall_m: 0.8979 - pred_acc: 0.7475 - pred_f1_m: 0.5822 - pred_precision_m: 0.6497 - pred_recall_m: 0.5275
# Epoch 00027: val_pred_acc did not improve from 0.74933
# 400/400 [==============================] - 209s 522ms/sample - loss: 0.5132 - decoded_mean_loss: 0.0109 - pred_loss: 0.5024 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9396 - decoded_mean_precision_m: 0.9854 - decoded_mean_recall_m: 0.8979 - pred_acc: 0.7475 - pred_f1_m: 0.5822 - pred_precision_m: 0.6497 - pred_recall_m: 0.5275 - val_loss: 0.5341 - val_decoded_mean_loss: 0.0106 - val_pred_loss: 0.5298 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9401 - val_decoded_mean_precision_m: 0.9853 - val_decoded_mean_recall_m: 0.8988 - val_pred_acc: 0.7467 - val_pred_f1_m: 0.5619 - val_pred_precision_m: 0.6476 - val_pred_recall_m: 0.4967
# Epoch 28/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4922 - decoded_mean_loss: 0.0114 - pred_loss: 0.4808 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9434 - decoded_mean_precision_m: 0.9850 - decoded_mean_recall_m: 0.9051 - pred_acc: 0.7825 - pred_f1_m: 0.6529 - pred_precision_m: 0.6997 - pred_recall_m: 0.6125
# Epoch 00028: val_pred_acc did not improve from 0.74933
# 400/400 [==============================] - 181s 453ms/sample - loss: 0.4922 - decoded_mean_loss: 0.0114 - pred_loss: 0.4808 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9434 - decoded_mean_precision_m: 0.9850 - decoded_mean_recall_m: 0.9051 - pred_acc: 0.7825 - pred_f1_m: 0.6529 - pred_precision_m: 0.6997 - pred_recall_m: 0.6125 - val_loss: 0.5505 - val_decoded_mean_loss: 0.0109 - val_pred_loss: 0.5434 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9426 - val_decoded_mean_precision_m: 0.9851 - val_decoded_mean_recall_m: 0.9037 - val_pred_acc: 0.7253 - val_pred_f1_m: 0.5552 - val_pred_precision_m: 0.5798 - val_pred_recall_m: 0.5333
# Epoch 29/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4841 - decoded_mean_loss: 0.0102 - pred_loss: 0.4738 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9439 - decoded_mean_precision_m: 0.9890 - decoded_mean_recall_m: 0.9027 - pred_acc: 0.7683 - pred_f1_m: 0.6329 - pred_precision_m: 0.6698 - pred_recall_m: 0.6000
# Epoch 00029: val_pred_acc did not improve from 0.74933
# 400/400 [==============================] - 186s 465ms/sample - loss: 0.4841 - decoded_mean_loss: 0.0102 - pred_loss: 0.4738 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9439 - decoded_mean_precision_m: 0.9890 - decoded_mean_recall_m: 0.9027 - pred_acc: 0.7683 - pred_f1_m: 0.6329 - pred_precision_m: 0.6698 - pred_recall_m: 0.6000 - val_loss: 0.5426 - val_decoded_mean_loss: 0.0093 - val_pred_loss: 0.5191 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9424 - val_decoded_mean_precision_m: 0.9885 - val_decoded_mean_recall_m: 0.9004 - val_pred_acc: 0.7360 - val_pred_f1_m: 0.5993 - val_pred_precision_m: 0.6367 - val_pred_recall_m: 0.5667
# Epoch 30/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4866 - decoded_mean_loss: 0.0099 - pred_loss: 0.4767 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9446 - decoded_mean_precision_m: 0.9888 - decoded_mean_recall_m: 0.9042 - pred_acc: 0.7625 - pred_f1_m: 0.6250 - pred_precision_m: 0.6620 - pred_recall_m: 0.5925
# Epoch 00030: val_pred_acc did not improve from 0.74933
# 400/400 [==============================] - 183s 458ms/sample - loss: 0.4866 - decoded_mean_loss: 0.0099 - pred_loss: 0.4767 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9446 - decoded_mean_precision_m: 0.9888 - decoded_mean_recall_m: 0.9042 - pred_acc: 0.7625 - pred_f1_m: 0.6250 - pred_precision_m: 0.6620 - pred_recall_m: 0.5925 - val_loss: 0.5400 - val_decoded_mean_loss: 0.0094 - val_pred_loss: 0.5351 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9456 - val_decoded_mean_precision_m: 0.9883 - val_decoded_mean_recall_m: 0.9064 - val_pred_acc: 0.7440 - val_pred_f1_m: 0.5945 - val_pred_precision_m: 0.6253 - val_pred_recall_m: 0.5667
# Epoch 31/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4815 - decoded_mean_loss: 0.0096 - pred_loss: 0.4719 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9467 - decoded_mean_precision_m: 0.9891 - decoded_mean_recall_m: 0.9077 - pred_acc: 0.7692 - pred_f1_m: 0.6317 - pred_precision_m: 0.6736 - pred_recall_m: 0.5950
# Epoch 00031: val_pred_acc did not improve from 0.74933
# 400/400 [==============================] - 190s 475ms/sample - loss: 0.4815 - decoded_mean_loss: 0.0096 - pred_loss: 0.4719 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9467 - decoded_mean_precision_m: 0.9891 - decoded_mean_recall_m: 0.9077 - pred_acc: 0.7692 - pred_f1_m: 0.6317 - pred_precision_m: 0.6736 - pred_recall_m: 0.5950 - val_loss: 0.5331 - val_decoded_mean_loss: 0.0100 - val_pred_loss: 0.5112 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9465 - val_decoded_mean_precision_m: 0.9875 - val_decoded_mean_recall_m: 0.9087 - val_pred_acc: 0.7480 - val_pred_f1_m: 0.6057 - val_pred_precision_m: 0.6505 - val_pred_recall_m: 0.5667
# Epoch 32/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4684 - decoded_mean_loss: 0.0121 - pred_loss: 0.4563 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9493 - decoded_mean_precision_m: 0.9873 - decoded_mean_recall_m: 0.9141 - pred_acc: 0.7875 - pred_f1_m: 0.6663 - pred_precision_m: 0.6985 - pred_recall_m: 0.6375
# Epoch 00032: val_pred_acc improved from 0.74933 to 0.76267, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 217s 542ms/sample - loss: 0.4684 - decoded_mean_loss: 0.0121 - pred_loss: 0.4563 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9493 - decoded_mean_precision_m: 0.9873 - decoded_mean_recall_m: 0.9141 - pred_acc: 0.7875 - pred_f1_m: 0.6663 - pred_precision_m: 0.6985 - pred_recall_m: 0.6375 - val_loss: 0.5402 - val_decoded_mean_loss: 0.0129 - val_pred_loss: 0.5224 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9500 - val_decoded_mean_precision_m: 0.9863 - val_decoded_mean_recall_m: 0.9163 - val_pred_acc: 0.7627 - val_pred_f1_m: 0.6189 - val_pred_precision_m: 0.6637 - val_pred_recall_m: 0.5800
# Epoch 33/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4687 - decoded_mean_loss: 0.0134 - pred_loss: 0.4553 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9512 - decoded_mean_precision_m: 0.9887 - decoded_mean_recall_m: 0.9164 - pred_acc: 0.7808 - pred_f1_m: 0.6623 - pred_precision_m: 0.6806 - pred_recall_m: 0.6450
# Epoch 00033: val_pred_acc did not improve from 0.76267
# 400/400 [==============================] - 181s 452ms/sample - loss: 0.4687 - decoded_mean_loss: 0.0134 - pred_loss: 0.4553 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9512 - decoded_mean_precision_m: 0.9887 - decoded_mean_recall_m: 0.9164 - pred_acc: 0.7808 - pred_f1_m: 0.6623 - pred_precision_m: 0.6806 - pred_recall_m: 0.6450 - val_loss: 0.5488 - val_decoded_mean_loss: 0.0106 - val_pred_loss: 0.5598 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9498 - val_decoded_mean_precision_m: 0.9913 - val_decoded_mean_recall_m: 0.9115 - val_pred_acc: 0.7467 - val_pred_f1_m: 0.5891 - val_pred_precision_m: 0.6220 - val_pred_recall_m: 0.5600
# Epoch 34/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4504 - decoded_mean_loss: 0.0101 - pred_loss: 0.4403 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9504 - decoded_mean_precision_m: 0.9920 - decoded_mean_recall_m: 0.9122 - pred_acc: 0.7975 - pred_f1_m: 0.6813 - pred_precision_m: 0.7159 - pred_recall_m: 0.6500
# Epoch 00034: val_pred_acc did not improve from 0.76267
# 400/400 [==============================] - 193s 481ms/sample - loss: 0.4504 - decoded_mean_loss: 0.0101 - pred_loss: 0.4403 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9504 - decoded_mean_precision_m: 0.9920 - decoded_mean_recall_m: 0.9122 - pred_acc: 0.7975 - pred_f1_m: 0.6813 - pred_precision_m: 0.7159 - pred_recall_m: 0.6500 - val_loss: 0.5382 - val_decoded_mean_loss: 0.0108 - val_pred_loss: 0.5083 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9518 - val_decoded_mean_precision_m: 0.9899 - val_decoded_mean_recall_m: 0.9166 - val_pred_acc: 0.7547 - val_pred_f1_m: 0.6328 - val_pred_precision_m: 0.6736 - val_pred_recall_m: 0.5967
# Epoch 35/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4539 - decoded_mean_loss: 0.0124 - pred_loss: 0.4415 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9530 - decoded_mean_precision_m: 0.9898 - decoded_mean_recall_m: 0.9188 - pred_acc: 0.7850 - pred_f1_m: 0.6665 - pred_precision_m: 0.6901 - pred_recall_m: 0.6450
# Epoch 00035: val_pred_acc did not improve from 0.76267
# 400/400 [==============================] - 182s 455ms/sample - loss: 0.4539 - decoded_mean_loss: 0.0124 - pred_loss: 0.4415 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9530 - decoded_mean_precision_m: 0.9898 - decoded_mean_recall_m: 0.9188 - pred_acc: 0.7850 - pred_f1_m: 0.6665 - pred_precision_m: 0.6901 - pred_recall_m: 0.6450 - val_loss: 0.5642 - val_decoded_mean_loss: 0.0120 - val_pred_loss: 0.5576 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9521 - val_decoded_mean_precision_m: 0.9896 - val_decoded_mean_recall_m: 0.9174 - val_pred_acc: 0.7333 - val_pred_f1_m: 0.5784 - val_pred_precision_m: 0.5981 - val_pred_recall_m: 0.5600
# Epoch 36/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4594 - decoded_mean_loss: 0.0106 - pred_loss: 0.4488 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9528 - decoded_mean_precision_m: 0.9917 - decoded_mean_recall_m: 0.9168 - pred_acc: 0.8058 - pred_f1_m: 0.6951 - pred_precision_m: 0.7316 - pred_recall_m: 0.6625
# Epoch 00036: val_pred_acc improved from 0.76267 to 0.76800, saving model to /content/drive/MyDrive/Models_a_ameliorer/Test_4.h5
# 400/400 [==============================] - 191s 476ms/sample - loss: 0.4594 - decoded_mean_loss: 0.0106 - pred_loss: 0.4488 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9528 - decoded_mean_precision_m: 0.9917 - decoded_mean_recall_m: 0.9168 - pred_acc: 0.8058 - pred_f1_m: 0.6951 - pred_precision_m: 0.7316 - pred_recall_m: 0.6625 - val_loss: 0.5395 - val_decoded_mean_loss: 0.0092 - val_pred_loss: 0.5467 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9513 - val_decoded_mean_precision_m: 0.9909 - val_decoded_mean_recall_m: 0.9148 - val_pred_acc: 0.7680 - val_pred_f1_m: 0.6046 - val_pred_precision_m: 0.6523 - val_pred_recall_m: 0.5633
# Epoch 37/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4413 - decoded_mean_loss: 0.0103 - pred_loss: 0.4310 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9531 - decoded_mean_precision_m: 0.9922 - decoded_mean_recall_m: 0.9169 - pred_acc: 0.8075 - pred_f1_m: 0.6964 - pred_precision_m: 0.7340 - pred_recall_m: 0.6625
# Epoch 00037: val_pred_acc did not improve from 0.76800
# 400/400 [==============================] - 207s 517ms/sample - loss: 0.4413 - decoded_mean_loss: 0.0103 - pred_loss: 0.4310 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9531 - decoded_mean_precision_m: 0.9922 - decoded_mean_recall_m: 0.9169 - pred_acc: 0.8075 - pred_f1_m: 0.6964 - pred_precision_m: 0.7340 - pred_recall_m: 0.6625 - val_loss: 0.5542 - val_decoded_mean_loss: 0.0107 - val_pred_loss: 0.5414 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9525 - val_decoded_mean_precision_m: 0.9917 - val_decoded_mean_recall_m: 0.9163 - val_pred_acc: 0.7520 - val_pred_f1_m: 0.6024 - val_pred_precision_m: 0.6307 - val_pred_recall_m: 0.5767
# Epoch 38/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4416 - decoded_mean_loss: 0.0117 - pred_loss: 0.4299 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9533 - decoded_mean_precision_m: 0.9925 - decoded_mean_recall_m: 0.9171 - pred_acc: 0.8092 - pred_f1_m: 0.6999 - pred_precision_m: 0.7357 - pred_recall_m: 0.6675
# Epoch 00038: val_pred_acc did not improve from 0.76800
# 400/400 [==============================] - 186s 466ms/sample - loss: 0.4416 - decoded_mean_loss: 0.0117 - pred_loss: 0.4299 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9533 - decoded_mean_precision_m: 0.9925 - decoded_mean_recall_m: 0.9171 - pred_acc: 0.8092 - pred_f1_m: 0.6999 - pred_precision_m: 0.7357 - pred_recall_m: 0.6675 - val_loss: 0.5470 - val_decoded_mean_loss: 0.0102 - val_pred_loss: 0.5502 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9528 - val_decoded_mean_precision_m: 0.9929 - val_decoded_mean_recall_m: 0.9159 - val_pred_acc: 0.7453 - val_pred_f1_m: 0.5822 - val_pred_precision_m: 0.6274 - val_pred_recall_m: 0.5433
# Epoch 39/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4346 - decoded_mean_loss: 0.0115 - pred_loss: 0.4231 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9529 - decoded_mean_precision_m: 0.9930 - decoded_mean_recall_m: 0.9159 - pred_acc: 0.8033 - pred_f1_m: 0.6916 - pred_precision_m: 0.7236 - pred_recall_m: 0.6625
# Epoch 00039: val_pred_acc did not improve from 0.76800
# 400/400 [==============================] - 183s 458ms/sample - loss: 0.4346 - decoded_mean_loss: 0.0115 - pred_loss: 0.4231 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9529 - decoded_mean_precision_m: 0.9930 - decoded_mean_recall_m: 0.9159 - pred_acc: 0.8033 - pred_f1_m: 0.6916 - pred_precision_m: 0.7236 - pred_recall_m: 0.6625 - val_loss: 0.5750 - val_decoded_mean_loss: 0.0131 - val_pred_loss: 0.5588 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9526 - val_decoded_mean_precision_m: 0.9918 - val_decoded_mean_recall_m: 0.9163 - val_pred_acc: 0.7560 - val_pred_f1_m: 0.6163 - val_pred_precision_m: 0.6337 - val_pred_recall_m: 0.6000
# Epoch 40/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4401 - decoded_mean_loss: 0.0129 - pred_loss: 0.4272 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9529 - decoded_mean_precision_m: 0.9933 - decoded_mean_recall_m: 0.9157 - pred_acc: 0.7975 - pred_f1_m: 0.6873 - pred_precision_m: 0.7086 - pred_recall_m: 0.6675
# Epoch 00040: val_pred_acc did not improve from 0.76800
# 400/400 [==============================] - 193s 484ms/sample - loss: 0.4401 - decoded_mean_loss: 0.0129 - pred_loss: 0.4272 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9529 - decoded_mean_precision_m: 0.9933 - decoded_mean_recall_m: 0.9157 - pred_acc: 0.7975 - pred_f1_m: 0.6873 - pred_precision_m: 0.7086 - pred_recall_m: 0.6675 - val_loss: 0.5503 - val_decoded_mean_loss: 0.0108 - val_pred_loss: 0.5481 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9524 - val_decoded_mean_precision_m: 0.9934 - val_decoded_mean_recall_m: 0.9145 - val_pred_acc: 0.7653 - val_pred_f1_m: 0.6247 - val_pred_precision_m: 0.6401 - val_pred_recall_m: 0.6100
# Epoch 41/100
# 400/400 [==============================] - ETA: 0s - loss: 0.4267 - decoded_mean_loss: 0.0111 - pred_loss: 0.4155 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9528 - decoded_mean_precision_m: 0.9936 - decoded_mean_recall_m: 0.9151 - pred_acc: 0.8075 - pred_f1_m: 0.6957 - pred_precision_m: 0.7357 - pred_recall_m: 0.6600
# Epoch 00041: val_pred_acc did not improve from 0.76800
# 400/400 [==============================] - 183s 458ms/sample - loss: 0.4267 - decoded_mean_loss: 0.0111 - pred_loss: 0.4155 - decoded_mean_acc: 0.9321 - decoded_mean_f1_m: 0.9528 - decoded_mean_precision_m: 0.9936 - decoded_mean_recall_m: 0.9151 - pred_acc: 0.8075 - pred_f1_m: 0.6957 - pred_precision_m: 0.7357 - pred_recall_m: 0.6600 - val_loss: 0.5443 - val_decoded_mean_loss: 0.0097 - val_pred_loss: 0.5409 - val_decoded_mean_acc: 0.9310 - val_decoded_mean_f1_m: 0.9520 - val_decoded_mean_precision_m: 0.9932 - val_decoded_mean_recall_m: 0.9140 - val_pred_acc: 0.7547 - val_pred_f1_m: 0.6021 - val_pred_precision_m: 0.6428 - val_pred_recall_m: 0.5667
# Epoch 00041: early stopping

# %%
autoencoder.evaluate(x=X_test, y={'decoded_mean': Conversion_X_test, 'pred': y_test})
# Out:
# [0.5444989314079285,
#  0.009536584,
#  0.5348305,
#  0.93096,
#  0.952147,
#  0.99364305,
#  0.9139784,
#  0.756,
#  0.61080873,
#  0.64512527,
#  0.5811298]

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.show()

plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# test 5 avec 1000 unite

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/Models_a_ameliorer'
MODEL_FILE_NAME = 'Test_5.h5'
LR=0.0001
batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500
encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)
def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(900,return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Dense(300, activation='relu', name='dense_1')(h)
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])
    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    return (fct_loss, z) 
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()
def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)

encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()
def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h = Bidirectional(  LSTM(900, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 

autoencoder.compile(optimizer=Adam(learning_rate=LR), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_1 (Embedding)        (None, 100, 100)     2281400     ['input_3[0][0]']
#
#  bidirectional_3 (Bidirectional  (None, 100, 1800)   7207200     ['embedding_1[0][0]']
#  )
#
#  attention_couche_1 (AttentionC  (None, 1800)        1900        ['bidirectional_3[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          540300      ['attention_couche_1[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 10,151,200
# Trainable params: 10,151,200
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 200)]             0
#
#  dense_4 (Dense)             (None, 100)               20100
#
#  pred (Dense)                (None, 3)                 303
#
# =================================================================
# Total params: 20,403
# Trainable params: 20,403
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 200)]             0
#
#  repeat_vector_4 (RepeatVect  (None, 100, 200)         0
#  or)
#
#  bidirectional_4 (Bidirectio  (None, 100, 1800)        7927200
#  nal)
#
#  decoded_mean (TimeDistribut  (None, 100, 22814)       41088014
#  ed)
#
# =================================================================
# Total params: 49,015,214
# Trainable params: 49,015,214
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100)]        0           []
#
#  embedding_1 (Embedding)        (None, 100, 100)     2281400     ['input_3[0][0]']
#
#  bidirectional_3 (Bidirectional  (None, 100, 1800)   7207200     ['embedding_1[0][0]']
#  )
#
#  attention_couche_1 (AttentionC  (None, 1800)        1900        ['bidirectional_3[0][0]']
#  ouche)
#
#  dense_1 (Dense)                (None, 300)          540300      ['attention_couche_1[0][0]']
#
#  z_mean (Dense)                 (None, 200)          60200       ['dense_1[0][0]']
#
#  z_log_var (Dense)              (None, 200)          60200       ['dense_1[0][0]']
#
#  z (Lambda)                     (None, 200)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  repeat_vector_5 (RepeatVector)  (None, 100, 200)    0           ['z[0][0]']
#
#  bidirectional_5 (Bidirectional  (None, 100, 1800)   7927200     ['repeat_vector_5[0][0]']
#  )
#
#  dense_7 (Dense)                (None, 100)          20100       ['z[0][0]']
#
#  decoded_mean (TimeDistributed)  (None, 100, 22814)  41088014    ['bidirectional_5[0][0]']
#
#  pred (Dense)                   (None, 3)            303         ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 59,186,817
# Trainable params: 59,186,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])

# %%
autoencoder.evaluate(x=X_test, y={'decoded_mean': Conversion_X_test, 'pred': y_test})

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.show()

plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# # **Test_5** :
# Deux couches cachés avec 1024 et 500 Neurones pour chaqu'une

# %%
MODEL_FILE_PATH = '/content/drive/MyDrive/dossier_de_travail/'
MODEL_FILE_NAME = 'Test_6.h5'
LR=0.0001

batch_size = 100
vocab_size=vocab_size
max_length=100 
dim_latent=200
intermediate_dim=500

encoder = None
decoder = None
predicter_opinion = None
autoencoder = None

x = Input(shape=(max_length,))
x_embed = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length)(x)


def Encodeur(x, dim_latent=200, max_length=100, epsilon_std=0.01):
    h = Bidirectional(LSTM(975, return_sequences=True,dropout=0.25),merge_mode='concat')(x)
    h = AttentionCouche()(h) 
    h = Bidirectional(LSTM(500, return_sequences=False,dropout=0.25),merge_mode='concat')(h)
    h = Dense(300, activation='relu', name='dense_1')(h)
    
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        # by default, random_normal has mean=0 and std=1.0
        epsilon = K.random_normal(shape=(batch, dim_latent), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon
    
    
    z_mean = Dense(dim_latent, name='z_mean', activation='linear')(h)
    z_log_var = Dense(dim_latent, name='z_log_var', activation='linear')(h)
    z = Lambda(sampling, output_shape=(dim_latent,), name='z')([z_mean, z_log_var])


    def fct_loss(x, x_decoded_mean):
        x = K.flatten(x)
        x_decoded_mean = K.flatten(x_decoded_mean)
        xent_loss = max_length * metrics.binary_crossentropy(x, x_decoded_mean)
        kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return xent_loss + kl_loss
    
    return (fct_loss, z)
    
     
fct_loss, encoded = Encodeur(x_embed, dim_latent=dim_latent, max_length=max_length)
encoder = Model(inputs=x, outputs=encoded)
encoder.summary()


def Codage_opinion(encoded):
    h = Dense(100, activation='linear')(encoded)     
    return Dense(3, activation='softmax', name='pred')(h)


encoded_input = Input(shape=(dim_latent,))
opinion_lab = Codage_opinion(encoded_input)
predicter_opinion = Model(encoded_input, opinion_lab)
predicter_opinion.summary()


def Decodeur(encoded, vocab_size, max_length):
    repeated_context = RepeatVector(max_length)(encoded)
    h = Bidirectional(LSTM(1024, return_sequences=True, name='dec_lstm_1',dropout=0.25))(repeated_context)
    h = Bidirectional(LSTM(500, return_sequences=True, name='dec_lstm_1',dropout=0.25))(h)
    decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)        
    return decoded


decoded = Decodeur(encoded_input, vocab_size, max_length)
decoder = Model(encoded_input, decoded)
decoder.summary()
autoencoder = Model(inputs=x, outputs=[Decodeur(encoded, vocab_size, max_length), Codage_opinion(encoded)])
tf.config.run_functions_eagerly(False)
#tf.compat.v1.disable_eager_execution()


early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

save_best = ModelCheckpoint(os.path.join(MODEL_FILE_PATH,MODEL_FILE_NAME), 
                     monitor='val_pred_acc', 
                     mode='max', 
                     verbose=1, 
                     save_best_only=True) 
autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss=[fct_loss, 'binary_crossentropy'], metrics=['accuracy',f1_m,precision_m, recall_m])
autoencoder.summary()

# %%
history = autoencoder.fit(x=X_train, y={'decoded_mean': Conversion_X_train, 'pred': y_train}, batch_size=100, epochs=100, validation_data=(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test}),callbacks=[early_stopping, save_best])

# %%
autoencoder.evaluate(X_test, {'decoded_mean': Conversion_X_test, 'pred':  y_test})

# %%
plt.plot(history.history['pred_acc'])
plt.plot(history.history['val_pred_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Plot of loss in each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.plot(history.history['pred_loss'])
plt.plot(history.history['val_pred_loss'])
plt.title('model pred_loss')
plt.ylabel('pred_loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

plt.plot(history.history['pred_f1_m'])
plt.plot(history.history['val_pred_f1_m'])

plt.title('model F1_score')
plt.ylabel('f1_m')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()
